# %% [markdown]
# # 1. IMPORT LIBRARIES AND DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import string
import re

# %%
df = pd.read_excel('../data/vietnamworks.xlsx')
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344 entries, 0 to 1343
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_name         1344 non-null   object
#  1   company          1335 non-null   object
#  2   salary           1344 non-null   object
#  3   location         1342 non-null   object
#  4   skill_1          1336 non-null   object
#  5   skill_2          1325 non-null   object
#  6   skill_3          1124 non-null   object
#  7   job_des          1337 non-null   object
#  8   job_requirement  1337 non-null   object
#  9   other            1338 non-null   object
#  10  Unnamed: 10      1 non-null      object
# dtypes: object(11)
# memory usage: 115.6+ KB
# None
#           job_name                  company        salary location  \
# count         1344                     1335          1344     1342
# unique        1229                      771           257      128
# top     Kỹ Sư Điện  Navigos Search's Client  Thương lượng   Hà Nội
# freq            10                       42           835      502
#
#                     skill_1               skill_2 skill_3  \
# count                  1336                  1325    1124
# unique                  702                   787     698
# top     Công Nghệ Thông Tin  Communication Skills    Java
# freq                     19                    17      13
#
#                                                   job_des  \
# count                                                1337
# unique                                               1284
# top     Mô tả công việc\n\nMô tả công việc:\n\n1. Bảo ...
# freq                                                    3
#
#                                           job_requirement  \
# count                                                1337
# unique                                               1285
# top     Yêu cầu công việc\n\n• Có kiến thức về thiết b...
# freq                                                    3
#
#                                                     other  \
# count                                                1338
# unique                                               1293
# top     Thông tin việc làm\nNGÀY ĐĂNG\n\n22/04/2025\n\...
# freq                                                    2
#
#                                               Unnamed: 10
# count                                                   1
# unique                                                  1
# top     Thông tin việc làm\nNGÀY ĐĂNG\n25/04/2025\n\nC...
# freq                                                    1
# job_name              0
# company               9
# salary                0
# location              2
# skill_1               8
# skill_2              19
# skill_3             220
# job_des               7
# job_requirement       7
# other                 6
# Unnamed: 10        1343
# dtype: int64

# %% [markdown]
# # PREPROCESS - TÁCH CỘT

# %% [markdown]
# ## CỘT other
# tách các trường từ cột này

# %%
print(df.head())
# Out:
#                                             job_name  \
# 0       Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 1                   Technical Documentation Engineer
# 2  Automation Software Tester (Selenium/java/appium)
# 3  Product Manager (Global Market) - Lương Upto $...
# 4      Professional Electrical Installation Designer
#
#                                              company                salary  \
# 0                       Công Ty Cổ Phần Xây Dựng TEG      Tới 20tr ₫/tháng
# 1     CÔNG TY TNHH SPECIALTY BOLT AND SCREW VIỆT NAM          Thương lượng
# 2  Bosch Global Software Technologies Company Lim...          Thương lượng
# 3                            MISA Jointstock Company  $ 1,000-2,000 /tháng
# 4        Danieli – Industrielle Beteiligung Co., Ltd          Thương lượng
#
#       location                  skill_1                 skill_2  \
# 0       Hà Nội         Thiết Kế Cơ Điện       Thiết Kế Hệ Thống
# 1  Hồ Chí Minh                  Autocad  Mechanical Engineering
# 2  Hồ Chí Minh       Automation Testing                    Java
# 3       Hà Nội  Lập Kế Hoạch Kinh Doanh       Phân Tích Dữ Liệu
# 4  Hồ Chí Minh        Electrical Design           ISO Standards
#
#                    skill_3                                            job_des  \
# 0                      BIM  Mô tả công việc\n\n- Triển khai tính toán, thi...
# 1       Quality Management  Mô tả công việc\n\n1. Job Summary\n\nWe are lo...
# 2                   Appium  Mô tả công việc\n\n- Develop, maintain and exe...
# 3    Nghiên Cứu Thị Trường  Mô tả công việc\n\nMô tả công việc\n\n• Định h...
# 4  Electrical Installation  Mô tả công việc\n\n• Read and decode block dia...
#
#                                      job_requirement  \
# 0  Yêu cầu công việc\n\n2. YÊU CẦU ỨNG VIÊN\n\n- ...
# 1  Yêu cầu công việc\n\nEducation: Bachelor degre...
# 2  Yêu cầu công việc\n\n- 1-2 years of experience...
# 3  Yêu cầu công việc\n\nYêu cầu công việc\n\n• Tố...
# 4  Yêu cầu công việcQualifications and experience...
#
#                                                other Unnamed: 10
# 0  Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 1  Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 2  Thông tin việc làm\nNGÀY ĐĂNG\n\n18/04/2025\n\...         NaN
# 3  Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
# 4  Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN

# %% [markdown]
# ### CỘT EXPERIENCE_REQUIRE

# %%
def extract_job_info(text):
    if pd.isnull(text):
        return pd.Series([np.nan]*5, index=['level', 'category', 'skills', 'field', 'min_experience'])

    text = text.strip()

    def extract_field(label):
        pattern = rf"{label.upper()}\s*\n(.*?)(?:\n[A-Z]|$)"
        match = re.search(pattern, text, re.DOTALL)
        if match:
            return match.group(1).strip()
        return np.nan

    level = extract_field("CẤP BẬC")
    category = extract_field("NGÀNH NGHỀ")
    skills = extract_field("KỸ NĂNG")
    field = extract_field("LĨNH VỰC")

    # Xử lý SỐ NĂM KINH NGHIỆM TỐI THIỂU
    exp_raw = extract_field("SỐ NĂM KINH NGHIỆM TỐI THIỂU")
    min_experience = np.nan

    

    if isinstance(exp_raw, str):
        exp_raw_lower = exp_raw.lower()
        if "không yêu cầu" in exp_raw_lower:
            min_experience = 0
        else:
            match = re.search(r'(\d+)', exp_raw_lower)
            if match:
                min_experience = int(match.group(1))
    return pd.Series([level, category, skills, field, min_experience],
                     index=['level', 'category', 'skills', 'field', 'min_experience'])

# %%
info_cols = ['level', 'category', 'skills', 'field', 'min_experience']
df[info_cols] = df['other'].apply(extract_job_info)

# %%
df.head()
# Out:
#                                             job_name  \
# 0       Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 1                   Technical Documentation Engineer
# 2  Automation Software Tester (Selenium/java/appium)
# 3  Product Manager (Global Market) - Lương Upto $...
# 4      Professional Electrical Installation Designer
#
#                                              company                salary  \
# 0                       Công Ty Cổ Phần Xây Dựng TEG      Tới 20tr ₫/tháng
# 1     CÔNG TY TNHH SPECIALTY BOLT AND SCREW VIỆT NAM          Thương lượng
# 2  Bosch Global Software Technologies Company Lim...          Thương lượng
# 3                            MISA Jointstock Company  $ 1,000-2,000 /tháng
# 4        Danieli – Industrielle Beteiligung Co., Ltd          Thương lượng
#
#       location                  skill_1                 skill_2  \
# 0       Hà Nội         Thiết Kế Cơ Điện       Thiết Kế Hệ Thống
# 1  Hồ Chí Minh                  Autocad  Mechanical Engineering
# 2  Hồ Chí Minh       Automation Testing                    Java
# 3       Hà Nội  Lập Kế Hoạch Kinh Doanh       Phân Tích Dữ Liệu
# 4  Hồ Chí Minh        Electrical Design           ISO Standards
#
#                    skill_3                                            job_des  \
# 0                      BIM  Mô tả công việc\n\n- Triển khai tính toán, thi...
# 1       Quality Management  Mô tả công việc\n\n1. Job Summary\n\nWe are lo...
# 2                   Appium  Mô tả công việc\n\n- Develop, maintain and exe...
# 3    Nghiên Cứu Thị Trường  Mô tả công việc\n\nMô tả công việc\n\n• Định h...
# 4  Electrical Installation  Mô tả công việc\n\n• Read and decode block dia...
#
#                                      job_requirement  \
# 0  Yêu cầu công việc\n\n2. YÊU CẦU ỨNG VIÊN\n\n- ...
# 1  Yêu cầu công việc\n\nEducation: Bachelor degre...
# 2  Yêu cầu công việc\n\n- 1-2 years of experience...
# 3  Yêu cầu công việc\n\nYêu cầu công việc\n\n• Tố...
# 4  Yêu cầu công việcQualifications and experience...
#
#                                                other Unnamed: 10  \
# 0  Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 1  Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 2  Thông tin việc làm\nNGÀY ĐĂNG\n\n18/04/2025\n\...         NaN
# 3  Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
# 4  Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
#
#                      level                                           category  \
# 0                Nhân viên           Khoa Học & Kỹ Thuật > Cơ Khí & Điện Lạnh
# 1           Mới Tốt Nghiệp           Khoa Học & Kỹ Thuật > Cơ Khí & Điện Lạnh
# 2                Nhân viên  Công Nghệ Thông Tin/Viễn Thông > QA/QC/Softwar...
# 3  Giám Đốc và Cấp Cao Hơn  Công Nghệ Thông Tin/Viễn Thông > Quản Lý Dự Án...
# 4                Nhân viên        Khoa Học & Kỹ Thuật > Kỹ Thuật Điện/Điện Tử
#
#                                               skills  \
# 0  Thiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều...
# 1  Autocad, Mechanical Engineering, Quality Manag...
# 2  Automation Testing, Java, Appium, Selenium, AP...
# 3  Lập Kế Hoạch Kinh Doanh, Phân Tích Dữ Liệu, Ng...
# 4  Electrical Design, ISO Standards, Electrical I...
#
#                                  field  min_experience
# 0      Kỹ thuật xây dựng/Cơ sở hạ tầng             1.0
# 1                                 Ô tô             0.0
# 2       Phần Mềm CNTT/Dịch vụ Phần mềm             0.0
# 3       Phần Mềm CNTT/Dịch vụ Phần mềm             3.0
# 4  Cơ khí/Máy móc/Thiết bị công nghiệp             0.0

# %%
# delete all if salary = Thương lượng
df = df[df['salary'] != 'Thương lượng']

# %%
df.head()
# Out:
#                                             job_name  \
# 0       Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 3  Product Manager (Global Market) - Lương Upto $...
# 5          Facility Officer (Aeon Mall Ha Dong- 459)
# 6  C / C++ Software Engineer - Relocation Bonus -...
# 7  Android Devevloper (Relocation Bonus - Hybrid ...
#
#                                              company                salary  \
# 0                       Công Ty Cổ Phần Xây Dựng TEG      Tới 20tr ₫/tháng
# 3                            MISA Jointstock Company  $ 1,000-2,000 /tháng
# 5                         AEONMALL Vietnam Co., Ltd.       300-550 ₫/tháng
# 6  LG Electronics Development Vietnam Company Lim...    $ 800-2,500 /tháng
# 7  LG Electronics Development Vietnam Company Lim...    $ 800-2,500 /tháng
#
#   location                  skill_1                skill_2  \
# 0   Hà Nội         Thiết Kế Cơ Điện      Thiết Kế Hệ Thống
# 3   Hà Nội  Lập Kế Hoạch Kinh Doanh      Phân Tích Dữ Liệu
# 5   Hà Nội      Building Management  Facilities Management
# 6  Đà Nẵng                      C++                  C/C++
# 7  Đà Nẵng                     Java  Java Spring Framework
#
#                  skill_3                                            job_des  \
# 0                    BIM  Mô tả công việc\n\n- Triển khai tính toán, thi...
# 3  Nghiên Cứu Thị Trường  Mô tả công việc\n\nMô tả công việc\n\n• Định h...
# 5   Facility Maintenance  Mô tả công việc\n\nAEONMALL Vietnam Co., Ltd. ...
# 6   Software Development  Mô tả công việc\n\nLG Electronics Development ...
# 7   Software Engineering  Mô tả công việc\n\nLG Electronics Development ...
#
#                                      job_requirement  \
# 0  Yêu cầu công việc\n\n2. YÊU CẦU ỨNG VIÊN\n\n- ...
# 3  Yêu cầu công việc\n\nYêu cầu công việc\n\n• Tố...
# 5  Yêu cầu công việc\n\n1. Bachelor’s degree, pre...
# 6  Yêu cầu công việc\n\n1. Requirement:\n\n- Basi...
# 7  Yêu cầu công việc\n\n1. General Requirement:\n...
#
#                                                other Unnamed: 10  \
# 0  Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 3  Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
# 5  Thông tin việc làm\nNGÀY ĐĂNG\n\n18/04/2025\n\...         NaN
# 6  Thông tin việc làm\nNGÀY ĐĂNG\n\n22/04/2025\n\...         NaN
# 7  Thông tin việc làm\nNGÀY ĐĂNG\n\n22/04/2025\n\...         NaN
#
#                      level                                           category  \
# 0                Nhân viên           Khoa Học & Kỹ Thuật > Cơ Khí & Điện Lạnh
# 3  Giám Đốc và Cấp Cao Hơn  Công Nghệ Thông Tin/Viễn Thông > Quản Lý Dự Án...
# 5                Nhân viên          Khoa Học & Kỹ Thuật > Điện/Nước/Chất Thải
# 6                Nhân viên  Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
# 7                Nhân viên  Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
#
#                                               skills  \
# 0  Thiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều...
# 3  Lập Kế Hoạch Kinh Doanh, Phân Tích Dữ Liệu, Ng...
# 5  Building Management, Facilities Management, Fa...
# 6              C++, C/C++, Software Development, OOP
# 7  Java, Java Spring Framework, Software Engineer...
#
#                              field  min_experience
# 0  Kỹ thuật xây dựng/Cơ sở hạ tầng             1.0
# 3   Phần Mềm CNTT/Dịch vụ Phần mềm             3.0
# 5            Bất Động Sản/Cho thuê             1.0
# 6   Phần Mềm CNTT/Dịch vụ Phần mềm             1.0
# 7   Phần Mềm CNTT/Dịch vụ Phần mềm             0.0

# %%
# delete other	Unnamed: 10	
df = df.drop(columns=['other', 'Unnamed: 10'])

# %%
experience_counts = df['min_experience'].value_counts()
print("Experience Requirements (from 'min_experience') Counts:")
print(experience_counts)
# Out:
# Experience Requirements (from 'min_experience') Counts:
# min_experience
# 1.0     130
# 0.0     106
# 2.0      96
# 3.0      86
# 5.0      44
# 4.0      17
# 10.0     10
# 8.0       7
# 7.0       6
# 6.0       5
# Name: count, dtype: int64

# %%
USD_TO_VND = 25_000
VND_TR = 1_000_000

# %%
def _clean(num_txt: str) -> float:
    """Loại bỏ dấu , . rồi trả về float."""
    return float(re.sub(r"[,.]", "", num_txt))

def parse_salary(text):
    """Trả về Series(min_salary, max_salary) (đơn vị: VND)."""
    if pd.isnull(text):
        return pd.Series([np.nan, np.nan], index=['min_salary', 'max_salary'])

    txt = str(text).lower().strip()
    txt = txt.replace('–', '-').replace('—', '-')     # chuẩn hóa dấu gạch

    # -------- 1) Khoảng lương a - b --------
    m = re.search(r'(\d[\d,\.]*)\s*(?:tr|triệu)?\s*-\s*(\d[\d,\.]*)', txt)
    if m:
        n1, n2 = map(_clean, m.groups())
        if 'tr' in txt or 'triệu' in txt:           # ưu tiên “tr”
            factor = VND_TR
        elif '$' in txt or 'usd' in txt:
            factor = USD_TO_VND
        else:
            factor = 1                              # giả sử đã là VND đầy đủ
        return pd.Series([n1*factor, n2*factor], index=['min_salary', 'max_salary'])

    # -------- 2) “Từ …”  → min = max --------
    m = re.search(r'\btừ\b\s*\$?\s*(\d[\d,\.]*)\s*(?:tr|triệu)?', txt)
    if m:
        val = _clean(m.group(1))
        if 'tr' in txt or 'triệu' in txt:
            val *= VND_TR
        elif '$' in txt or 'usd' in txt:
            val *= USD_TO_VND
        return pd.Series([val, val], index=['min_salary', 'max_salary'])

    # -------- 3) “Tới/Lên đến …”  → min = max --------
    m = re.search(r'\b(tới|lên đến|đến)\b\s*\$?\s*(\d[\d,\.]*)\s*(?:tr|triệu)?', txt)
    if m:
        val = _clean(m.group(2))
        if 'tr' in txt or 'triệu' in txt:
            val *= VND_TR
        elif '$' in txt or 'usd' in txt:
            val *= USD_TO_VND
        return pd.Series([val, val], index=['min_salary', 'max_salary'])

    # -------- 4) “Trên …”  → min = X, max = NaN --------
    m = re.search(r'\btrên\b\s*\$?\s*(\d[\d,\.]*)\s*(?:tr|triệu)?', txt)
    if m:
        val = _clean(m.group(1))
        if 'tr' in txt or 'triệu' in txt:
            val *= VND_TR
        elif '$' in txt or 'usd' in txt:
            val *= USD_TO_VND
        return pd.Series([val, np.nan], index=['min_salary', 'max_salary'])

    # -------- 5) Một số giá trị đơn lẻ có “tr” --------
    m = re.search(r'\$?\s*(\d[\d,\.]*)\s*(?:tr|triệu)', txt)
    if m:
        val = _clean(m.group(1)) * VND_TR
        return pd.Series([val, val], index=['min_salary', 'max_salary'])

    # -------- 6) Mọi trường hợp còn lại (đơn lẻ, $ …) --------
    m = re.search(r'\$?\s*(\d[\d,\.]*)', txt)
    if m:
        val = _clean(m.group(1))
        if '$' in txt or 'usd' in txt:
            val *= USD_TO_VND
        return pd.Series([val, val], index=['min_salary', 'max_salary'])
    
    return pd.Series([np.nan, np.nan], index=['min_salary', 'max_salary'])

# %%
# apply to df
df[['min_salary', 'max_salary']] = df['salary'].apply(parse_salary)

# %%
# if min_salary or mmaxsalry = nan, print salary
def check_salary(row):
    if pd.isnull(row['min_salary']) or pd.isnull(row['max_salary']):
        print(f"{row['salary']}")
        return True
    return False

# Check for missing salaries
missing_salaries = df.apply(check_salary, axis=1)

# %%
# if in salary find 'năm', devide by 12 for min and max
def adjust_salary_for_yearly(row):
    if pd.isnull(row['min_salary']) or pd.isnull(row['max_salary']):
        return row
    if 'năm' in row['salary'].lower():
        row['min_salary'] /= 12
        row['max_salary'] /= 12
    return row
# Apply the adjustment
df = df.apply(adjust_salary_for_yearly, axis=1)

# %%
# if min_salary > 100000000, print salary
def check_high_salary(row):
    if row['min_salary'] > 100_000_000 or row['max_salary'] > 100_000_000:
        print(f"High salary: {row['salary']}")
        return True
    return False
# Check for high salaries
high_salaries = df.apply(check_high_salary, axis=1)
# Out:
# High salary: $ 2,500-5,000 /tháng
# High salary: Tới $ 100,000 /năm
# High salary: $ 2,000-5,000 /tháng
# High salary: $ 20,000-60,000 /năm
# High salary: $ 3,000-5,000 /tháng
# High salary: $ 25,000-35,000 /tháng
# High salary: $ 8,000-12,000 /tháng
# High salary: $ 2,500-6,000 /tháng
# High salary: $ 2,800-5,000 /tháng
# High salary: $ 2,500-30,000 /tháng
# High salary: $ 4,000-4,500 /tháng
# High salary: $ 6,000-7,000 /tháng
# High salary: $ 3,000-5,000 /tháng
# High salary: $ 4,000-5,000 /tháng
# High salary: $ 4,000-5,000 /tháng
# High salary: $ 3,000-5,000 /tháng
# High salary: $ 3,000-5,000 /tháng

# %%
# if min_salary < 1000000, print salary
def check_low_salary(row):
    if row['min_salary'] < 1_000_000 or row['max_salary'] < 1_000_000:
        print(f"Low salary: {row['salary']}")
        return True
    return False
# Check for low salaries
low_salaries = df.apply(check_low_salary, axis=1)
# delete all rows
df = df[~low_salaries]
# Out:
# Low salary: 300-550 ₫/tháng
# Low salary: 10,000-20,000 ₫/tháng
# Low salary: 500-800 ₫/tháng
# Low salary: Tới 2,000 ₫/tháng
# Low salary: 450-550 ₫/tháng
# Low salary: 700-1,500 ₫/tháng
# Low salary: 650-1,000 ₫/tháng
# Low salary: 400-600 ₫/tháng
# Low salary: 700-1,500 ₫/tháng
# Low salary: 1,000-1,500 ₫/tháng
# Low salary: 900-1,200 ₫/tháng
# Low salary: 900-1,300 ₫/tháng
# Low salary: ¥ 300,000-700,000 /tháng
# Low salary: Tới 500 ₫/tháng
# Low salary: Tới 1,200 ₫/tháng
# Low salary: 30-40 ₫/tháng

# %%
df.head()
# Out:
#                                              job_name  \
# 0        Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 3   Product Manager (Global Market) - Lương Upto $...
# 6   C / C++ Software Engineer - Relocation Bonus -...
# 7   Android Devevloper (Relocation Bonus - Hybrid ...
# 14                                      Data Engineer
#
#                                               company                salary  \
# 0                        Công Ty Cổ Phần Xây Dựng TEG      Tới 20tr ₫/tháng
# 3                             MISA Jointstock Company  $ 1,000-2,000 /tháng
# 6   LG Electronics Development Vietnam Company Lim...    $ 800-2,500 /tháng
# 7   LG Electronics Development Vietnam Company Lim...    $ 800-2,500 /tháng
# 14                                        Techcombank  $ 1,000-2,500 /tháng
#
#    location                  skill_1                skill_2  \
# 0    Hà Nội         Thiết Kế Cơ Điện      Thiết Kế Hệ Thống
# 3    Hà Nội  Lập Kế Hoạch Kinh Doanh      Phân Tích Dữ Liệu
# 6   Đà Nẵng                      C++                  C/C++
# 7   Đà Nẵng                     Java  Java Spring Framework
# 14   Hà Nội                  Banking          Data Engineer
#
#                   skill_3                                            job_des  \
# 0                     BIM  Mô tả công việc\n\n- Triển khai tính toán, thi...
# 3   Nghiên Cứu Thị Trường  Mô tả công việc\n\nMô tả công việc\n\n• Định h...
# 6    Software Development  Mô tả công việc\n\nLG Electronics Development ...
# 7    Software Engineering  Mô tả công việc\n\nLG Electronics Development ...
# 14       Computer Science  Mô tả công việc\n\n• Lead the team technically...
#
#                                       job_requirement  \
# 0   Yêu cầu công việc\n\n2. YÊU CẦU ỨNG VIÊN\n\n- ...
# 3   Yêu cầu công việc\n\nYêu cầu công việc\n\n• Tố...
# 6   Yêu cầu công việc\n\n1. Requirement:\n\n- Basi...
# 7   Yêu cầu công việc\n\n1. General Requirement:\n...
# 14  Yêu cầu công việc\n\n1. Must have:\n\n• Bachel...
#
#                       level  \
# 0                 Nhân viên
# 3   Giám Đốc và Cấp Cao Hơn
# 6                 Nhân viên
# 7                 Nhân viên
# 14                Nhân viên
#
#                                              category  \
# 0            Khoa Học & Kỹ Thuật > Cơ Khí & Điện Lạnh
# 3   Công Nghệ Thông Tin/Viễn Thông > Quản Lý Dự Án...
# 6   Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
# 7   Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
# 14  Công Nghệ Thông Tin/Viễn Thông > Data Engineer...
#
#                                                skills  \
# 0   Thiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều...
# 3   Lập Kế Hoạch Kinh Doanh, Phân Tích Dữ Liệu, Ng...
# 6               C++, C/C++, Software Development, OOP
# 7   Java, Java Spring Framework, Software Engineer...
# 14  Banking, Data Engineer, Computer Science, Info...
#
#                               field  min_experience  min_salary  max_salary
# 0   Kỹ thuật xây dựng/Cơ sở hạ tầng             1.0  20000000.0  20000000.0
# 3    Phần Mềm CNTT/Dịch vụ Phần mềm             3.0  25000000.0  50000000.0
# 6    Phần Mềm CNTT/Dịch vụ Phần mềm             1.0  20000000.0  62500000.0
# 7    Phần Mềm CNTT/Dịch vụ Phần mềm             0.0  20000000.0  62500000.0
# 14                        Ngân hàng             3.0  25000000.0  62500000.0

# %%
# thêm 2 cột tên exp_2, education, toàn bộ đều là NaN
df['exp_2'] = np.nan
df['education'] = np.nan

# %%
def normalize_text(text):
    text = text.lower()
    text = text.replace("’", "'").replace("‘", "'").replace("“", '"').replace("”", '"')
    return text

def parse_job_require(text):
    if pd.isnull(text):
        return pd.Series([np.nan, np.nan], index=['degree', 'experience'])

    txt = normalize_text(str(text))

    # -------- 1. Degree detection --------
    degrees = []
    degree = np.nan  # ✅ Khởi tạo để phòng lỗi NameError

    degree_patterns = {
        'phd': r'(tiến sĩ|doctorate|ph\.?\s*d)',
        'master': r"(thạc sĩ|master'?s?\s+degree|msc)",
        'bachelor': r"(đại\s*học|đh|bachelor'?s?\s+degree|bachelor\s+degree|graduated\s+from\s+university|university\s+degree)",
        'college': r"(cao\s*đẳng|college\s+degree)",
        'associate': r"(trung\s*cấp|associate\s+degree|trung\s*cấp\s*nghề)",
        'highschool': r"(thpt|trung học phổ thông|high\s*school)",
        'secondary': r"(thcs|trung học cơ sở|secondary\s*school)"
    }

    for key, pattern in degree_patterns.items():
        if re.search(pattern, txt, flags=re.IGNORECASE):
            degrees.append(key)

    # ➕ Bắt bằng keyword nếu chưa tìm được degree rõ ràng
    if not degrees:
        soft_bachelor_keywords = [
            r"sinh\s*viên",
            r"năm\s*cuối",
            r"final\s*year",
            r"tốt\s*nghiệp\s+đại\s*học",
            r"graduate(d)?\s+from\s+university",
            r"graduated\s+university",
            r"graduated",
            r"tốt\s*nghiệp",
            r"cử\s*nhân"
        ]
        if any(re.search(pat, txt, flags=re.IGNORECASE) for pat in soft_bachelor_keywords):
            degrees.append('bachelor')

    if degrees:
        degree = ', '.join(sorted(set(degrees)))

    # -------- 2. Experience detection --------
    experience = np.nan
    matches = re.findall(
        r'(?:at least|min(?:imum)? of|ít nhất|tối thiểu|khoảng|~)?\s*(\d+)(?:\s*[-–]\s*(\d+)|\+)?\s*(?:năm|years?)',
        txt, flags=re.IGNORECASE
    )

    if matches:
        numbers = []
        for a, b in matches:
            numbers.append(int(a))
            if b:
                numbers.append(int(b))
        experience = round(np.mean(numbers), 1)

    return pd.Series([degree, experience], index=['degree', 'experience'])

# %%
df[['education', 'exp_2']] = df['job_requirement'].apply(parse_job_require)

# %%
# print require if education is NaN
def check_exp_2(row):
    if pd.isnull(row['exp_2']):
        print(f"Missing exp_2 for job: {row['job_requirement']}")
        return True
    return False
# Check for missing exp_2
missing_exp_2 = df.apply(check_exp_2, axis=1)
# Out:
# Missing exp_2 for job: Yêu cầu công việc
#
# Yêu cầu công việc
#
# • Tốt nghiệp đại học chuyên ngành quản trị kinh doanh, kinh tế từ các trường ĐH Ngoại thương, ĐH Kinh tế Quốc dân, hoặc các trường tương đương.
#
# • Có khả năng nghiên cứu thị trường và khách hàng một cách hệ thống; có kỹ năng phân tích dữ liệu để đưa ra quyết định; khả năng lập kế hoạch kinh doanh và phát triển sản phẩm hiệu quả.
#
# • Kỹ năng giao tiếp, trình bày và thuyết phục tốt.
#
# • Khả năng làm việc nhóm và giải quyết vấn đề hiệu quả.
#
# • Trình độ tiếng Anh: Nghe, Nói, Đọc, Viết từ mức Khá trở lên; có khả năng giao tiếp thành thạo bằng tiếng Anh với đối tác và khách hàng quốc tế.
#
# • Đam mê và có định hướng lâu dài trong lĩnh vực phát triển sản phẩm công nghệ; quan tâm đến việc ứng dụng công nghệ để nâng cao hiệu quả công việc; mong muốn tạo ra sản phẩm mang lại giá trị cho xã hội.
#
# • Ưu tiên ứng viên có kinh nghiệm làm việc ở vị trí Senior BA/PO/PM trong các công ty phần mềm có sản phẩm/dịch vụ liên quan đến lĩnh vực F&B.
#
# • Ưu tiên ứng viên tốt nghiệp MBA
#
#
#
#
# CHẾ ĐỘ ĐÃI NGỘ MISA DÀNH CHO BẠN:
#
# - Lương cứng khởi điểm hấp dẫn, xem xét tăng lương 6 tháng/lần vào tháng 4 và tháng 10 hàng năm
#
# - Thưởng cuối năm theo năng suất làm việc tương đương 2-3 tháng lương
#
# - Ăn trưa miễn phí tại công ty; quà lễ tết, sinh nhật, hiếu hỉ, thăm hỏi…
#
# - Nghỉ phép 12 ngày/năm, nghỉ ốm/nghỉ chế độ thai sản/hiếu hỉ… theo luật lao động
#
# - Khám sức khỏe hàng năm, teambuilding hàng quý, nghỉ mát hấp dẫn, các CLB thể thao, nhiều sự kiện và hoạt động văn thể mỹ…
#
# - Làm việc tại công ty quy mô lớn, quy trình làm việc chuyên nghiệp, được khuyến khích sáng tạo và phát triển các ý tưởng mới
#
# - Môi trường trẻ, năng động, chuyên nghiệp, sếp trẻ tâm lý, đồng nghiệp thân thiện, văn hóa trao đổi thẳng thắn, cởi mở trên tinh thần hỗ trợ và cạnh tranh lành mạnh
#
# - Được tham gia các khóa đào tạo chuyên môn, đào tạo kỹ năng mềm, Cán bộ nguồn, chương trình Hổ tướng cho các cá nhân xuất sắc…
#
# - Không gian làm việc mới, hiện đại, rộng thoáng; đầy đủ cơ sở vật chất và các trang thiết bị phục vụ công việc; nhiều tiện ích giải trí: quầy bar, sân golf mini, khu leo núi…
#
# - Khuôn viên xung quanh văn phòng thoáng mát & văn minh, đối diện có công viên hồ điều hoà, đường xá thoáng, đẹp, giao các trục đường chính thuận tiện giao thông (Nguyễn Văn Huyên, Phạm Văn Đồng, Võ Chí Công)
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tuổi từ 22 đến 45.
#
# • Tốt nghiệp Đại học, cao đẳng chuyên ngành Điện/ Tự động hóa/ Điều hòa thông gió/ Cơ khí/ Phòng cháy chữa cháy/ Cấp thoát nước.
#
# • Sử dụng word và Excel thành thạo đủ phục vụ công việc.
#
# • Thái độ làm việc tích cực, trung thực, hợp tác, chuyên nghiệp, trách nhiệm, khả năng giải quyết vấn đề và kỹ năng giao tiếp tốt;
#
# • Có khả năng làm việc độc lập và dưới áp lực cao, sẵn sàng đi công tác nếu cần thiết.
#
#
#
#
# *** Quyền Lợi Được Hưởng:
#
# • Thưởng tháng 13, thưởng dự án
#
# • Đánh giá tăng lương và vị trí hàng năm
#
# • Bảo hiểm và các quyền lợi khác theo quy định của Luật Lao động Việt Nam
#
# • Bảo hiểm con người 24/24
#
# • Trợ cấp điện thoại
#
# • Cấp phát máy tính
#
# • Trợ cấp ăn trưa
#
# • Chế độ công đoàn
#
# • Có nhà ở cho kỹ sư ở xa
#
# • Nghỉ mát
#
#
#
#
# Ưu tiên ứng viên nộp hồ sơ sớm. Ứng viên đủ tiêu chuẩn tuyển dụng sẽ được liên hệ phỏng vấn ngay
# Missing exp_2 for job: Yêu cầu công việc
#
# Quyền lợi được hưởng
#
# - Công việc ổn định, môi trường làm việc năng động, chuyên nghiệp
#
# - Có cơ hội thăng tiến.
#
# - Lương, trợ cấp, bảo hiểm theo quy định
#
# - Thưởng tháng lương 13.
#
#
#
#
# Yêu cầu khác
#
# - Tốt nghiệp đại học chuyên ngành điện hoặc tự động hóa các trường đại học kỹ thuật.
#
# - Có khả năng đọc hiểu tài liệu tiếng anh chuyên ngành.
#
# - Ưu tiên ứng viên có kinh nghiệm trong lĩnh vực sản xuất tủ bảng điện hoặc lập trình PLC, SCADA.
#
# - Sử dụng thành thạo các phần mềm: Auto CAD, MS-Office.
#
# - Có khả năng làm việc độc lập và làm việc theo nhóm.
#
# - Chịu được áp lực công việc và có thể đi công tác xa.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp CĐ trở lên các chuyên ngành Điện, Điện tử, CNTT...
#
# - Có kinh nghiệm lập trình chương trình test, test sản phẩm, sửa chữa máy test tại công ty điện tử
#
# - Ưu tiên biết lập trình một trong các ngôn ngữ: C#, C++, Python…
#
# - Kỹ năng tiếng Anh hoặc tiếng Trung trình độ khá trở lên
# Missing exp_2 for job: Yêu cầu công việc
#
# Detail Requirements: Knowledge, experiences, skills:
#
# • Bachelor's degree in Thermal Engineering, Air Conditioning or related fields
#
# • Experience in designing, constructing or supervising HVAC
#
#
#
#
# The specific requirement
#
# • Proficiency in design software: Cad, Revit or other tools
#
# • Team work, can work at holiday and willing overtime
#
#
#
#
# BENEFIT:
#
# Salary and bonus regime:
#
# • Salary: Competitive
#
# • 13th month salary
#
# • Seniority bonus and bonus on holidays and year-end.
#
#
#
#
# Other modes:
#
# • When candidates become company employees, they will enjoy full employee benefits according to the provisions of Vietnam Labor Law.
#
# • The company provides industrial meal services and uniform distribution.
#
# • Shuttle bus according to company policy in surrounding areas.
#
# • 12 days leave/year.
#
# • Health insurance according to law.
#
# • Participate in trade unions and many meaningful activities
#
# • Company travel, Year-end party, men's/women's soccer tournament, ... once a year.
#
# • 24/7 accident insurance
# Missing exp_2 for job: Yêu cầu công việc
#
# Detail Requirements: Knowledge, experiences, skills:
#
# • Bachelor's degree in Thermal Engineering, Air Conditioning or related fields
#
# • Experience in designing, constructing or supervising HVAC
#
#
#
#
# The specific requirement
#
# • Proficiency in design software: Cad, Revit or other tools
#
# • Team work, can work at holiday and willing overtime
#
#
#
#
# BENEFIT:
#
# Salary and bonus regime:
#
# • Salary: Competitive
#
# • 13th month salary
#
# • Seniority bonus and bonus on holidays and year-end.
#
#
#
#
# Other modes:
#
# • When candidates become company employees, they will enjoy full employee benefits according to the provisions of Vietnam Labor Law.
#
# • The company provides industrial meal services and uniform distribution.
#
# • Shuttle bus according to company policy in surrounding areas.
#
# • 12 days leave/year.
#
# • Health insurance according to law.
#
# • Participate in trade unions and many meaningful activities
#
# • Company travel, Year-end party, men's/women's soccer tournament, ... once a year.
#
# • 24/7 accident insurance
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Trung cấp, Cao đẳng, Đại học các chuyên ngành kỹ thuật
#
# - Có thể làm việc theo ca/kíp
#
# - Có kinh nghiệm làm việc với máy móc, tự động hoá, phân tích, sửa chữa, thay thế, bảo trì,… là một điểm cộng
#
# - Chấp nhận sinh viên mới ra trường
#
# - Chưa có kinh nghiệm sẽ được đào tạo
# Missing exp_2 for job: Yêu cầu công việc
#
# - Không yêu cầu ngoại ngữ
#
# - Tốt nghiệp trung cấp nghề trở lên liên quan tới điện, điện tử…
#
# - Biết qua về máy móc, ưu tiên những ứng viên đã có kinh nghiệm trong lĩnh vực tương đương.
#
# - Có thể tăng ca hoặc làm ca khi yêu cầu
#
#
#
#
# Phúc lợi công ty
#
# - Tăng lương hàng năm
#
# - Thưởng tháng 13
#
# - Chế độ bảo hiểm tai nạn thanh toán 100% viện phí, tham gia bảo hiểm xã hội, tham gia công đoàn , các chế độ hiếu , hỷ, ốm đau, sinh nhật, con cái và nhiều phúc lợi khác…
#
# - Cơ hội thăng tiến và phát triển nghề nghiệp.
#
#
#
#
# Địa điểm làm việc
#
# Lô M, KCN Tràng Duệ, P. Lê Lợi, Q. An Dương, TP. Hải Phòng
#
# Thời gian làm việc
#
# Thứ 2 - Thứ 6 và hai thứ 7 trong tuần (từ 08:00 đến 17:00). Nghỉ hai thứ 7 và chủ nhật ( Nếu đi làm sẽ tính tăng ca theo luật )
# Missing exp_2 for job: Yêu cầu công việc
#
# Bằng cấp chuyên môn
#
#
#
#
# - Tốt nghiệp THCS, THPT, Trung cấp nghề trở lên, ưu tiên về các ngành sửa chữa ô tô, thợ điện, máy gầm hoặc có tay nghề về sửa chữa ô tô
#
#
#
#
# Kinh nghiệm
#
#
#
#
# - Am hiểu về lĩnh vực BDSC ô tô
#
#
#
#
# Kỹ năng
#
#
#
#
# - Kỹ năng quản lý công việc tốt, sắp xếp thời gian hợp lý.
#
#
#
#
# - Có kỹ năng làm việc theo nhóm.
#
#
#
#
# Phẩm chất
#
#
#
#
# - Chuyên nghiệp
#
#
#
#
# - Trách nhiệm
#
#
#
#
# - Hợp tác
#
#
#
#
# Yêu cầu khác (nếu có)
#
#
#
#
# - Chăm chỉ, có sức khỏe tốt
#
#
#
#
# - Có khả năng làm việc độc lập, làm việc nhóm, chịu được áp lực công việc cao
# Missing exp_2 for job: Yêu cầu công việc
#
# • Là sinh viên năm cuối hoặc đã tốt nghiệp Đại học vào năm 2023, 2024 hoặc 2025.
#
# • Thành thạo ít nhất một trong các ngôn ngữ lập trình: C, C++, Java hoặc Python.
#
# • Có tư duy logic, kỹ năng giải thuật tốt, yêu thích thử thách lập trình.
#
# • Có khả năng tham gia vòng chung kết offline tại Hà Nội hoặc Đà Nẵng (ngày 28/06/2025).
# Missing exp_2 for job: Yêu cầu công việc
#
# + Educational Background:
#
# - Graduated with a degree in related fields such as Mechanical Engineering, Automation, Chemistry, or other relevant fields.
#
# + Specialized Knowledge:
#
# - Solid understanding of mechanical principles, electronics, and operating techniques.
#
# - In-depth knowledge of the production processes and principles in the metallurgy industry.
#
#
#
#
# - From May to September, 2025: Work at VOV Building, no. 7 Nguyen Thi Minh Khai, Dist. 1, HCMC
#
# - After September, 2025: Work at the factory in KCN Chuyen Sau, Phu My 3, Ba Ria Vung Tau
# Missing exp_2 for job: Yêu cầu công việc
#
# • Là sinh viên năm cuối hoặc đã tốt nghiệp Đại học vào năm 2023, 2024 hoặc 2025.
#
# • Thành thạo ít nhất một trong các ngôn ngữ lập trình: C, C++, Java hoặc Python.
#
# • Có tư duy logic, kỹ năng giải thuật tốt, yêu thích thử thách lập trình.
#
# • Có khả năng tham gia vòng chung kết offline tại Hà Nội hoặc Đà Nẵng (ngày 28/06/2025).
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Đại học/Cao đẳng chuyên ngành Cơ khí, Cơ điện tử, Chế tạo máy hoặc các ngành liên quan;
#
# - Thành thạo các phần mềm thiết kế kỹ thuật AutoCAD, SolidWorks...;
#
# - Có kinh nghiệm trong lĩnh vực sản xuất gia công cơ khí, máy đột dập, máy cắt, máy khoan taro là một lợi thế, đặc biệt trong lĩnh vực gia công kim loại nhôm định hình, nhôm tấm;
#
# - Hiểu biết về quy trình sản xuất, đặc biệt là công nghệ đột dập, khuôn dập và cắt thanh, cắt đoạn trong ngành nhôm;
#
# - Khả năng đọc hiểu bản vẽ kỹ thuật, hiểu về vật liệu, công nghệ gia công;
#
# - Có tư duy cải tiến liên tục, kỹ năng phân tích và giải quyết vấn đề tốt;
#
# - Khả năng làm việc độc lập và làm việc nhóm hiệu quả;
#
# - Tiếng Anh đọc hiểu tài liệu kỹ thuật.
# Missing exp_2 for job: Yêu cầu công việc
#
# •Trung cấp trở lên chuyên ngành Điện, đọc được bản vẽ điện, am hiểu về các thiết bị điện như Biến tần, các loại cảm biến, relay, contactor, timer…
#
# • Có khả năng đọc các tài liệu kỹ thuật.
#
# • Kỹ năng làm việc nhóm tốt, làm việc độc lập, cẩn thận, trung thực, nhiệt tình, xử lý tình huống, giao tiếp tốt.
#
# • Chịu được áp lực cao trong công việc.
#
# - Ưu tiên có kinh nghiệm trong ngành thực phẩm.
#
# - Có thể làm việc theo ca.
#
#
#
#
# • Giới tính: Nam.
#
# • Cơ hội huấn luyện: Cơ hội phát triển và thăng tiến.
#
# • Độ tuổi: Không giới hạn tuổi.
#
# • Thời gian làm việc: 08:00 - 16:30 từ Thứ 2 - Thứ 7 hoặc đi ca sản xuất.
#
# • Đồng nghiệp: Môi trường trẻ, cởi mở, hòa đồng, thân thiện.
#
# ***Phúc lợi:
#
# • Nhận 85% lương chính thức trong thời gian thử việc.
#
# • Đóng BHXH, BHYT, BHTN đầy đủ, theo quy định của pháp luật.
#
# • Lương: 12-14tr.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Degree in mechanical engineering or similar majors
#
# - English: 4 skills
#
# - Advanced knowledge of Microsoft Office programs and Auto Cad software.
#
# - Experience managing installation of process equipment / industrial machinery
#
# - Experience in design of process lines (pump, valve, Heat exchanger, AHU…) and services piping, process piping.
#
# - Knowledge of Process & Instrument diagrams, Equipment Layout design, Project Management procedures
#
# - Ability to work under time pressure is required due to challenging timing of project.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp cao đẳng trở lên chuyên ngành , điện công nghiệp, cơ điện tử, tự động hoá, hệ thống truyền động điện và các ngành liên quan.
#
# - Thành thạo tin học văn phòng..
#
# - Chăm chỉ, cẩn thận, nhanh nhẹn. Đọc hiểu các bản vẽ kỹ thuật, am hiểu các loai máy móc trong ngành xây dựng.
#
# - Có ít nhất năm kinh nghiệm làm việc tại vị trí tương đương. Ưu tiên các ứng viên có kinh nghiệm làm việc trong lĩnh vực lắp đặt dây truyền sản xuất trạm bê tông và trạm asphalt...
#
# - Luôn luôn sẵn sàng thực hiện công việc, có thể đi công tác
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp cao đẳng trở lên chuyên ngành , điện công nghiệp, cơ điện tử, tự động hoá, hệ thống truyền động điện và các ngành liên quan.
#
# - Thành thạo tin học văn phòng..
#
# - Chăm chỉ, cẩn thận, nhanh nhẹn. Đọc hiểu các bản vẽ kỹ thuật, am hiểu các loai máy móc trong ngành xây dựng.
#
# - Có ít nhất năm kinh nghiệm làm việc tại vị trí tương đương. Ưu tiên các ứng viên có kinh nghiệm làm việc trong lĩnh vực lắp đặt dây truyền sản xuất trạm bê tông và trạm asphalt...
#
# - Luôn luôn sẵn sàng thực hiện công việc, có thể đi công tác
# Missing exp_2 for job: Yêu cầu công việc
#
# • Ưu tiên ứng viên có kinh nghiệm
#
# • Chấp nhận ứng viên mới ra trường, chưa có kinh nghiệm sẽ được đào tạo
#
# • Tốt nghiệp cao đẳng trở lên chuyên ngành cơ điện hoặc các ngành liên quan.
#
# • Có khả năng làm việc độc lập và theo nhóm.
#
# • Thích ứng nhanh với công nghệ và quy trình mới.
#
# • Sẵn sàng làm việc theo ca và đi làm ngoài giờ khi cần thiết.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Ứng viên từ 24 tuổi trở lên
#
# • Tốt nghiệp Cao đẳng, Đại học các ngành Cơ-Điện tử, Điện điện tử, Điện tử viễn thông, Tự động hóa;
#
# • Thành thạo Autocad 2D;
#
# • Sử dụng được 1 trong các phần mềm 3D: Skechup, Autocad 3D, Inventor....;
#
# • Kỹ năng đọc hiểu và nghiên cứu tài liệu;
#
# • Có phương tiện di chuyển;
#
# • Năng động, nhiệt tình trung thực, cẩn thận, làm việc có kế hoạch và có tinh thần trách nhiệm cao;
#
# • Tinh thần làm việc hăng hái, có trách nhiệm, thái độ cầu tiến trong công việc.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Ứng viên có kinh nghiệm về hệ thống cơ điện, không biết thiết kế, vẽ có thể được đào tạo (CAD hoặc BIM)
#
# - Ưu tiên biết về điều hòa, nhà xưởng
#
# - Có thể đi công tác dài ngày hay ngắn ngày theo yêu cầu công việc
#
# - Chấp nhận sinh viên mới ra trường
#
# - Chăm chỉ, nhiệt huyết, ham học hỏi
#
# - Lương trả theo năng lực, kinh nghiệm, thỏa thuận khi phỏng vấn
# Missing exp_2 for job: Yêu cầu công việc
#
# - Có kinh nghiệm về thiết kế trong lĩnh vực môi trường hoặc cơ khí.
#
# - Sử dụng tốt AutoCAD (hoặc phần mềm thiết kế 3D), Word, Excel.
#
# - Tốt nghiệp Đại học trở lên.
#
# - Dưới 35 tuổi.
#
#
#
#
# Đãi ngộ
#
# - Lương: 12 - 30 triệu VND.
#
# - Tăng lương: Năm 1 lần. Thưởng: Năm 1 lần.
#
#
#
#
# Thời gian làm việc: 08:00~17:00.
#
# - Ngày nghỉ: Thứ 7, Chủ nhật và các ngày lễ theo lịch công ty.
# Missing exp_2 for job: Yêu cầu công việc
#
# 1. 毕业于信息技术专业的大学。
#
# 2、有2-5年信息安全工作经验，良好的沟通协调能力，能起草文件。
#
# 3. 了解信息安全管理系统 （ISO27001），识别、评估、监督、响应和处理风险的过程，并建立风险清单。
#
# 4、掌握系统、网络和终端安全知识，使用和作常见的安全产品（如杀毒软件、防火墙、安全监控系统、网络访问控制、备份系统等）。
#
# 5. 对信息安全相关领域有全面的了解，有能力制定 SOP 并执行安全检查、风险识别、事件处理、培训和准备客户/第三方的安全审计等任务。
#
# 6. 能够听和说中文。
# Missing exp_2 for job: Yêu cầu công việc- Tuổi và giới tính: 	Nam, dưới 30 tuổi				- Trình độ: Cao đẳng (Chuyên nghành Điên, Điện tử)- Ngoại ngữ: Tiếng Anh hoặc Tiếng Nhật (được ưu tiên)- Thành thạo tin học văn phòng: MS-office-Kỹ năng : Lập trình PLC, HMI								Có kiến thức về thiết bị điện, điện tử (sensor, motor, biến tần, Rơ le, hệ thống khí nén…)
# Missing exp_2 for job: Yêu cầu công việc
#
# Yêu cầu:
#
# - Tốt nghiệp Đại học, Cao đẳng
#
# - Có nghiệp vụ và kinh nghiệm một trong các nội dung sau (Ưu tiên các ứng viên đáp ứng nhiều nội dung):
#
# • Có kiến thức lập trình, am hiểu cơ sở dữ liệu SQL
#
# • Có kiến thức về Kế toán tài chính, Quản trị doanh nghiệp
#
# • Có kinh nghiệm công tác trong lĩnh vực triển khai phần mềm
#
# - Khả năng giao tiếp tốt.
#
#
#
#
# Quyền lợi:
#
# - Mức thu nhập cơ bản (từ 12,000,000 - 25,000,000 đồng/ tháng hoặc thỏa thuận với nhân sự có kinh nghiệm). Trong đó:
#
# • Xét tăng lương định kỳ từ 2 lần/năm
#
# • Phụ cấp ăn trưa ~ 990,000 đồng / tháng
#
# • Phụ cấp chuyên cần 500,000 đồng / tháng.
#
# - Thu nhập mở rộng:
#
# • Thưởng giao việc, thưởng doanh số theo giá trị các hợp đồng triển khai.
#
# • Phụ cấp trách nhiệm (nếu là cấp cán bộ quản lý).
#
# - Công việc thách thức, môi trường làm việc chuyên nghiệp.
#
# - Ký hợp đồng lao động chính thức và hưởng các quyền lợi đúng luật lao động, hưởng các chính sách đãi ngộ xứng đáng, phù hợp với năng lực và kinh nghiệm
#
# - Được đào tạo tại công ty hoặc tham gia các khóa học bên ngoài.
#
# - Cơ hội tham gia nhiều hoạt động văn hóa, thể dục thể thao, giải trí (Liên hoan, nghỉ mát,
#
# văn thể mỹ,..)
#
# - Có cơ hội mở rộng kiến thức về hệ thống quản trị doanh nghiệp ERP và hệ thống kế toán
#
# doanh nghiệp.
#
#
#
#
# Xem thêm thông tin về BRAVO tại Website: https://www.bravo.com.vn
#
#
#
#
# Lưu ý:
#
# - Ưu tiên các ứng viên nộp hồ sơ trực tiếp.
#
# - Công ty nhận hồ sơ các ứng viên mới tốt nghiệp và đang chờ bằng.
#
# - Công ty không hoàn lại hồ sơ và chỉ gọi phỏng vấn những hồ sơ đạt yêu cầu
#
# - Khi được hẹn đến phỏng vấn các ứng viên cần mang theo các giấy tờ sau:
#
# • Sơ yếu lý lịch
#
# • Đơn xin việc (viết tay hoặc đánh máy)
#
# • Bảng điểm (photo)
#
# • Bằng tốt nghiệp đại học, cao đẳng (photo)
#
# • Chứng minh nhân dân (photo).
#
# • Các chứng chỉ văn bằng khác (nếu có).
#
# • Bản tóm tắt quá trình học tập, kinh nghiệm công tác, kĩ năng chuyên môn... của cá nhân (CV)
# Missing exp_2 for job: Yêu cầu công việc
#
# Tốt nghiệp chuyên ngành điệm công nghiệp, tự động hóa, không cần kinh nghiệm
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Đại học
#
# - Biết ngôn ngữ lập trình C# hoặc Python
#
# - Không yêu cầu kinh nghiệm
#
# - Tiếng Anh giao tiếp cơ bản hoặc tiếng Nhật N4 trở lên
#
# - Kỹ năng giao tiếp, báo cáo tốt
#
#
#
#
# Chế độ phúc lợi :
#
# - Chế độ làm việc làm việc tốt nhất Khu công nghiệp: Chỉ làm việc từ thứ 2 đến thứ 6, nghỉ tất cả thứ 7 và chủ nhật.
#
# - Chính sách lương hấp dẫn, lộ trình thăng tiến rõ ràng.
#
# - Thưởng cuối năm hấp dẫn lên đến trên > 2 tháng lương/ năm, Chế độ Thưởng vào các ngày Lễ, Tết, ngày sinh nhật, Chế độ thăm hỏi, quà tặng...
#
# - Nhiều tuyến xe đưa đón CNV từ Hà Nội – Hưng Yên – Hải Dương.
#
# - Có bảo hiểm 24/7 cho toàn bộ CNV, Bảo hiểm sức khỏe cho cấp quản lý.
#
# - Văn hóa công ty tôn trọng con người, môi trường làm việc trẻ năng động, đa quốc gia như Nhật, Hàn, Mỹ, Trung, Thái..
#
# - Có chế độ đào tạo và phát triển nhân tài, đội ngũ kế nhiệm: công nhân viên được tham gia các khóa đào tạo nâng cao trình độ chuyên môn, nâng cao kỹ năng để phát triển sự nghiệp và bản thân ( Các Khóa kỹ năng mềm, kỹ năng quản lý, excel, Tiếng Anh, Tiếng Nhật...) đa nền tảng: Trực tiếp, online, Tư vấn (Mentoring), Khai vấn ( Coaching).
#
# - Thư viện công ty với trên 1000 đầu sách nhiều lĩnh vực dành cho gia đình công nhân viên mượn, tham khảo.
#
# - Cơ sở vật chất văn phòng, nhà máy, khu nghỉ dành cho công nhân viên sạch sẽ, hiện đại, tiện nghi bậc nhất khu công nghiệp, thường xuyên được đón tiếp khách cấp tỉnh, trung ương đến thăm.
#
# - Công ty có nhiều hoạt động gắn kết cho công nhân viên: Du lịch hè, liên hoan cuối năm, ngày hội gia đình, nhiều hoạt động, hội thi sôi nổi: Ngày hội thể thao, Hội xuân, Khéo tay 8/3.
#
# - Được phát huy sở thích, thể mạnh ở các hoạt động câu lạc bộ: Câu lạc bộ Truyền thông, câu lạc bộ Tiếng Anh, Văn nghệ, Thể thao.
#
# - Có hoạt động thăm hỏi, hỗ trợ công nhân viên công ty và dân cư khu vực lân cận có hoàn cảnh khó khăn hàng năm.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp đại học chính quy chuyên ngành điện tử viễn thông/công nghệ thông tin/An toàn thông tin các trường Bách Khoa, Quốc Gia, Quân sự, Mật Mã ….
#
# • Có kiến thức, kinh nghiệm làm việc với các thiết bị mạng của Cisco/Juniper/HP...
#
# • Tiếng Anh: đủ khả năng giao tiếp và trao đổi qua thư điện tử với các đối tác nước ngoài.
#
# • Có chứng chỉ Cisco CCNA Security, CCNP là một lợi thế.
#
# Ưu tiên:
#
# • Ứng viên đã có kinh nghiệm triển khai hệ thống WiFi Ruckus/Aruba/Cisco…
#
# • Ứng viên đã có kiến thức, kinh nghiệm làm việc với thiết bị mạng Mikrotik.
#
# • Ứng viên có tiếng Anh tốt, có khả năng giao tiếp bằng tiếng Anh.
#
#
#
#
# PHÚC LỢI:
#
# • Thu nhập: 14tr– 25tr
#
# - Mức lương cạnh tranh, tối thiểu 13,5 tháng lương mỗi năm.
#
# - Mức lương có thể thương lượng dựa trên năng lực ứng viên.
#
# • Chính sách chung:
#
# - Thưởng lễ, Tết
#
# - Phụ cấp ăn trưa 50.000đ/ngày
#
# - BHXH, BHYT, BHTN
#
# - Khám sức khỏe định kỳ tại bệnh viện cao cấp
#
# - Du lịch, teambuilding trong và ngoài nước (2-3 chuyến/năm)
#
# • Thông tin bổ sung:
#
# - Thời gian làm việc: 8 giờ/ngày - 5 ngày/tuần; nghỉ cuối tuần
#
# - Địa điểm làm việc: Chi nhánh Hà Nội, Công ty CP NetNam, Tầng 2 – Tòa nhà HITC, 239 Xuân Thủy, Cầu Giấy, Hà Nội
#
# - Môi trường làm việc: Thân thiện, năng động, khuyến khích sáng tạo và thay đổi
#
# - Các CLB thể thao như bóng đá, yoga, chạy bộ được công ty hỗ trợ
#
# - Cơ hội đào tạo, hướng dẫn từ các chuyên gia công nghệ có kinh nghiệm
#
# - Đào tạo về sản phẩm/dịch vụ và công nghệ mới; công ty tài trợ các khóa CEH, CCNP, CCIE, JNCIE, ITIL, LPI nếu nhân viên cần và mong muốn nâng cao chuyên môn
#
# - Tham gia các khóa học quốc tế về CNTT và Internet tại khu vực Châu Á - Thái Bình Dương (Apricot/APNIC, v.v.)
#
# Phòng Nhân sự - Công ty CP NetNam
#
# Tầng 2, Tòa nhà HITC, số 239 Xuân Thủy, Cầu Giấy, Hà Nội.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Cao đẳng, Đại học chuyên ngành: điện tử; tự động hóa, Cơ khí, cơ điện tử, điện, Công nghệ thông tin
#
# - Am hiểu về mạch điện tử, PCB/ PCB'A, kaizen, 7 tools, innovation, lean.
#
# - Ưu tiên có kinh nghiệm làm việc tại các công ty điện tử vị trí kỹ sư NPI, PE, SMT (chưa có kinh nghiệm được đào tạo)
#
# - Kinh nghiệm làm các báo cáo chất lượng 8D; 4M
#
# - Sử dụng được tiếng Anh trong công việc là một lợi thế
#
# - Ưu tiên ứng viên ở Hà Nam hoặc các vùng lân cận
#
# *** Quyền lợi:
#
# • Trợ cấp Con nhỏ
#
# • Tham gia đóng BHXH ngay tháng thử việc, đóng BH trên tổng lương
#
# • Nghỉ 2 thứ 7 và 4 chủ nhật
#
# • Xét tăng lương hàng năm
#
# • Thưởng các ngày lễ tết, sinh nhật
#
# • Chế độ hiếu hỷ cho CBCNV
#
# • Tăng lương đặc biệt cho các TH có thành tích xuất sắc
#
# • Tham gia các khóa đào tạo kỹ năng mềm, đào tạo nước ngoài hoàn toàn miễn phí
#
# • Công ty chú trọng tuyển dụng nội bộ nên có cơ hội thăng tiến tốt
#
# • Tổ chức khám sức khỏe cho CBCNV hàng năm
# Missing exp_2 for job: Yêu cầu công việc
#
# ✨Yêu cầu✨
#
# • Yêu cầu năng lực thẩm mĩ và năng lực đạo diễn video
#
# • Biết cách xây dựng tư thế của nhân vật, và có hiểu biết nhất định về chuyển động của cơ thể.
#
# • Khả năng thu thập những xu hướng thời trang mới nhất
#
# • Có khả năng tự quản lý công việc và tích cực giải quyết vấn đề, hoàn thành công việc được giao.
#
# • Có đạo đức nghề nghiệp để đảm bảo triệt để sự bảo mật thông tin từ công việc.
#
# • Ưu tiên ứng viên có khả năng tiếng Anh hoặc tiếng Hàn
#
#
#
#
# Lưu ý: Yêu cầu bắt buộc nộp Portfolio video (Các hồ sơ thiếu Portfolio sẽ tự động bị loại)
#
# Công ty chỉ liên hệ với các ứng viên có hồ sơ phù hợp và đáp ứng yêu cầu tuyển dụng.
# Missing exp_2 for job: Yêu cầu công việc
#
# ✨Yêu cầu✨
#
# ● Ứng viên có kinh nghiệm trong lĩnh vực character design, tô màu webtoon và animation (ứng viên yêu thích webtoon Hàn Quốc, animation Nhật Bản)
#
# ● Ứng viên thành thạo các phần mềm graphic và công cụ vẽ digital (Adobe Photoshop ,Clip Studio, bảng vẽ Wacom Intuos)
#
# ● Bắt buộc có hình vẽ bằng tay trong Portfolio ứng tuyển (chấp nhận Digital Painting)
#
#
#
#
# Lưu ý: Yêu cầu bắt buộc nộp Portfolio (Các hồ sơ thiếu Portfolio sẽ tự động bị loại)
#
#
#
#
# Công ty chỉ liên hệ với các ứng viên có hồ sơ phù hợp và đáp ứng yêu cầu tuyển dụng.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Male/ Female, Fresh/Experience All are acceptable
#
# - Bachelor’s degree in Information Technology
#
# - Honest and eager to learn
#
# - Must be good at programming ( coding)
#
# - Web application development (C#, .NET or Java) good knowledge is required
#
# - Good Knowledge of SQL, Oracle, MariaDB or another database is an advantage
#
# - Good communication skill/ Teamwork
#
# - Ability to work Overtime/ High Pressure
#
# - English fluently
#
#
#
#
# BENEFITS:
#
# - Competitive salary; 13rd salary payment; R&D allowance monthly; Performance bonus
#
# - Chance to train and business trip internally and in foreign countries
#
# - Professional, comfortable, convenient, stable working environment
#
# - Supplied Laptop to work, free lunch, bus to pick up employees from Hai Phong and Ha Noi.
#
# - Good culture/team building activities
#
# - Some special holidays: summer holiday and winter holiday
#
# - 5 working days/week
# Missing exp_2 for job: Yêu cầu công việc
#
# Yêu cầu:
#
# - Trình độ:
#
# + Tốt nghiệp Cao đẳng, Đại học các chuyên ngành về Cơ / Điện (Điện - Điện tử, Tự động hóa, HVAC, cấp thoát nước, PCCC, Cơ khí, Năng lượng tái tạo,…) hoặc tương đương.
#
# + Sử dụng được phần mềm chuyên ngành Autocad và các phần mềm văn phòng Word, Excel, Powerpoint.
#
# - Kinh nghiệm:
#
# + Đối với kỹ sư mới ra trường (chỉ tuyển khu vực miền Bắc), được tham gia chương trình đào tạo kỹ sư trẻ của Công ty (20 bạn).
#
# - Kiến thức:
#
# + Có kiến thức niền tảng về hệ thống Cơ Điện
#
# - Thái độ:
#
# + Thái độ ham học hỏi, chủ động, có tinh thần trách nhiệm cao trong công việc
#
# + Ưu tiên Kỹ sư có khả năng đi công tác
#
#
#
#
# Quyền lợi được hưởng:
#
# - Mức lương hấp dẫn dựa trên năng lực và kinh nghiệm, cạnh tranh so với các Công ty cùng lĩnh vực (trao đổi trực tiếp trong buổi phỏng vấn). Được đánh giá điều chỉnh lương định kỳ hàng năm.
#
# - Phụ cấp khác: Lương tháng 13 & thưởng hấp dẫn theo kết quả doanh thu của Công ty. thưởng các ngày Lễ lớn.
#
# - Được hưởng các chế độ BHXH, BHYT, BHTN, khám sức khỏe theo quy định.
#
# - Được đi du lịch, nghỉ phép năm (12 ngày), nghỉ lễ theo quy định của Luật lao động hiện hành và theo quy định của Công ty.
#
# - Được làm việc trong môi trường năng động và hiện đại với nhiều chế độ đãi ngộ, phúc lợi hấp dẫn.
#
# - Đào tạo, bồi dưỡng & phát triển nghề nghiệp: tham gia các khóa huấn luyện kỹ năng mềm hoặc chuyên môn theo nhu cầu của công ty.
#
# - Tiếp cận với các tiêu chuẩn và công nghệ cao tiên tiến trên thế giới.
#
# - Có chỗ ở cho Kỹ sư
#
#
#
#
# Ưu tiên ứng viên nộp hồ sơ sớm.
#
#
#
#
# Văn phòng công ty: Tầng 21, Tòa nhà IDMC Mỹ Đình, số 18 Tôn Thất Thuyết, Mỹ Đình II, Nam Từ Liêm, Hà Nội
# Missing exp_2 for job: Yêu cầu công việc
#
# Requirements:
#
# • Education: University degree in IT with a focus on security; Computer Networks, Network Security, or Information Security.
#
# • Certifications: Preferred certifications include:
#
# o CEH (Certified Ethical Hacker)
#
# o CompTIA Security+
#
# o OSCP (Offensive Security Certified Professional)
#
# o CISSP (Certified Information Systems Security Professional)
#
# • Knowledge: Strong understanding of Network Security, System Security, Information Security, and Application Security.
#
# • Experience: Experience in the Finance or Banking sector is highly desirable.
#
# • Skills: Proficiency in teamwork, self-directed learning, organization, and coordination.
#
#
#
#
# Benefits:
#
# • Salary range: $1000 - $2000, can be negotiated during the interview
#
# • Compliance with labor laws and regulations.
#
# • Team-building activities and employee bonding events.
#
# • Salary and benefits in accordance with company policies and the position held.
#
# • Support for travel expenses and participation in training courses, seminars, and workshops related to finance and investment.
#
#
#
#
# Working time and location:
#
# • Time: Mon to Fri, 8AM-5PM
#
# • Location: Level 3, TNR building, 180-192 Nguyen Cong Tru, Nguyen Thai Binh Ward, Dist.1, HCMC
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp Trung cấp/Cao đẳng chuyên ngành: Điện, Cơ điện, Kỹ thuật, Bảo trì...
#
# • Có kinh nghiệm làm việc ở vị trí kỹ thuật tòa nhà là một lợi thế.
#
# • Siêng năng, trung thực, có tinh thần trách nhiệm và kỷ luật cao.
#
# • Sẵn sàng làm việc theo ca:
#
# - Ca sáng: 06h00 – 14h00
#
# - Ca chiều: 14h00 – 22h00
#
# - Ca đêm: 22h00 – 06h00
#
# • Tuần nghỉ 1 ngày, xoay ca theo lịch đăng ký.
# Missing exp_2 for job: Yêu cầu công việc
#
# Yêu cầu :
#
# • Bắt buộc là Sinh viên đại học năm thứ 3, sẽ tốt nghiệp vào năm 2026
#
# • Chuyên ngành Kỹ thuật Cơ khí, Kỹ thuật công nghiệp hoặc các chuyên ngành Kỹ thuật có liên quan.
#
# • Biết sử dụng Autocad
#
# • Có tư duy định hướng chi tiết, có phương pháp, định hướng quy trình
#
# • Quản lý thời gian hiệu quả - có thể thực hiện nhiều nhiệm vụ
#
# • Có khả năng làm việc độc lập hiệu quả hoặc theo nhóm
#
# • Có hiểu biết về cơ khí, có thể đưa ra các giải pháp đơn giản hóa trang thiết bị, tư duy sáng tạo và khả năng xử lý sự cố
#
# • Khả năng tiếp thu và vận dụng hiệu quả
#
# • Khả năng xử lý tình huống
#
# • Nghe và nói tiếng Anh khá. Tiếng Anh viết tốt. Có thể nói tiếng Trung cơ bản là một lợi thế..
#
#
#
#
# Quyền lợi:
#
# • Thu nhập từ 10-15 triệu/tháng
#
# • 5 ngày làm việc/tuần (Nghỉ thứ 7, Chủ nhật)
#
# • Thời gian làm việc linh động, làm việc tại nhà
#
# • Bảo hiểm chăm sóc sức khỏe trong suốt thời gian thực tập
#
# • Được trang bị Laptop làm việc
#
# • Được làm việc trong môi trường đa văn hóa, làm việc với các chuyên gia từ khắp nơi trên thế giới: Mỹ, Mexico, Ấn Độ, Úc, Hồng Kông ….
#
#
#
#
# • Địa điểm làm việc: Tầng 15, tòa nhà Bạch Đằng, số 268 Trần Nguyên Hãn, Lê Chân, Hải Phòng
# Missing exp_2 for job: Yêu cầu công việc
#
# • Ability to effectively communicate both orally and in writing in English.
#
# • The ability to interact with all levels of management both internally and within customer/vendor base.
#
# • Computer literate with strong knowledge of SolidWorks and Microsoft office.
#
# • Knowledge of GD&T and drafting practices is a MUST
#
# • Proficient with large assemblies, configurations, properties and drawing attributes.
#
# • Understanding of revision control and design process.
#
# • Must have strong organizational skills and attention to detail.
#
# • Ability to plan, organize and work successfully on simultaneous projects.
#
# • Finish requirements and tolerances for manufacturing knowledge.
#
# • General knowledge of machine shop and welding process helpful.
#
# • Ability to design workflows, BOM’s and procedures.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Nam, độ tuổi từ 22 - 35
#
# - Tốt nghiệp Cao đẳng trở lên chuyên ngành Điện tự động hóa hoặc các chuyên ngành khác có liên quan.
#
# - Am hiểu về lập trình, cài đặt máy.
#
# - Ưu tiên ứng viên đã có kinh nghiệm ở vị trí nhân viên cơ điện tại các nhà máy sản xuất thực phẩm bánh kẹo.
#
# - Nhanh nhẹn, nhiệt tình, có khả năng làm việc dưới áp lực công việc.
#
# - Trung thực, cẩn thận, siêng năng, chịu khó, hòa đồng.
#
#
#
#
# * Quyền lợi được hưởng:
#
# - Chế độ lương: Thoả thuận phù hợp với từng vị trí
#
# - Công ty hỗ trợ bữa ăn trưa;
#
# - Được đảm bảo các chế độ về Bảo hiểm xã hội, Bảo hiểm y tế, ... theo đúng quy định của Luật lao động. Được hưởng các chế độ phúc lợi theo quy định chung của Công ty.
#
# - Thời giờ làm việc: 8h/ca. Làm thêm giờ khi nhận được yêu cầu từ Công ty.
#
# - Thưởng theo hiệu quả kinh doanh và quy định của Công ty.
#
#
#
#
# Địa điểm làm việc: Lô B2-3-3A Khu công nghiệp Nam Thăng Long (khu B) – P. Thụy Phương – Q. Bắc Từ Liêm - TP. Hà Nội.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Nam/ nữ, dưới 35 tuổi
#
# • Tốt nghiệp Đại học, chuyên ngành công nghệ thông tin, phần mềm, hoặc các ngành liên quan
#
# • Có kiến thức sâu về ngôn ngữ lập trình: PHP, Javascript, CSS, HTML, hệ quản trị cơ sở dữ liệu MySQL, PostgreSQ, công cụ Xamp … biết về ngôn ngữ ASP.Net, SQL server là một lợi thế.
#
# • Thành thạo một trong hai Framework lập trình web Lavavel hoặc Wordpress (Yêu cầu Có sản phẩm demo)
#
# • Hiểu biết về phần mềm, thành thạo sử dụng các ứng dụng văn phòng, sử dụng hệ điều hành Windows.
#
# • Tiếng Anh khá (chủ yếu về kỹ năng đọc hiểu)
#
# • Có đam mê và định hướng nghề nghiệp chuyên sâu về lĩnh vực phát triển phần mềm
#
# • Sức khỏe tốt, chăm chỉ, trung thực, sáng tạo, trách nhiệm cao trong công việc
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp THPT trở lên
#
# - Hiểu và nắm được nguyên lý hoạt động của máy móc, thiết bị cơ điện phục vụ công việc
#
# - Nắm vững các quy định về sửa chữa, bảo dưỡng máy móc thiết bị, các quy định về an toàn lao động, bảo hộ lao động trong công ty.
#
# - Sửa chữa được các hư hỏng thông thường của máy móc thiết bị cơ điện.
#
# - Biết sử dụng các loại máy công cụ (khoan, hàn, tiện, búa máy, mài...) và các dụng cụ lao động thường dùng trong cơ khí sửa chữa, bảo dưỡng.
#
#
#
#
# *** Quyền lợi
#
# - Lương thưởng hấp dẫn thỏa thuận trực tiếp, từ 12Tr - 15Tr trở lên.
#
# - Du lịch hàng năm, ăn trưa miễn phí.
#
# - Có chế độ BHXH + BHYT + BHTN và các chế độ phúc lợi khác.
#
# - Cơ hội làm việc trong một môi trường chuyên nghiệp, ổn định lâu dài.
#
#
#
#
# * Địa điểm làm việc: Số 903 Nguyễn Đức Thuận, Trâu Quỳ, Gia Lâm, Hà Nội
#
# * Thời gian làm việc: Thứ 2 - Thứ 7 (từ 08:00 đến 17:30)
# Missing exp_2 for job: Yêu cầu công việc
#
# • Nam (Độ tuổi từ 22 đến 35);
#
# • Tốt nghiệp Trung cấp trở lên;
#
# • Có kinh nghiệm sửa chữa máy;
#
# • Có khả năng đọc hiểu bản vẽ;
#
# • Chấp nhận sinh viên mới ra trường, ưu tiên ứng viên có kinh nghiệm.
#
#
#
#
# Chế độ đãi ngộ:
#
# - Môi trường làm việc sạch sẽ, an toàn và chuyên nghiệp;
#
# - Tặng quà các ngày lễ, thưởng Tết lên đến 4 tháng lương;
#
# - Du lịch, liên hoan, các sự kiện giải trí quanh năm;
#
# - Tiêm vacxin cúm mùa hàng năm cho toàn bộ CBCNV;
#
# - Xe đưa đón các tuyến Thanh Hà – Nam Sách – TP.Hải Dương – Thanh Miện – Gia Lộc – Tứ Kỳ - Ninh Giang.
# Missing exp_2 for job: Yêu cầu công việc
#
# SKILL & EXPERIENCE REQUIREMENTS:
#
# - Experience Project Management or experience leading projects (PL, BrSE, IT comm etc...) within the past few years.
#
# - Experience in programming with any programming language is a plus.
#
# - Communication smoothly in Japanese (N2〜 level)
#
# - Communication skills in simple English (Chatting & Talking)
#
# - Having a sense of recognizing the issue & suggesting Kaizen plan.
#
# - Experience in creating System Design Documents, Development and Testing Plans is a plus.
#
# - Logical thinking & explanation skill based on factual data or numbers
#
# - Passion to learn hard, and become a high-level BPM, PMO, PM Specialist in short-term
#
#
#
#
# WORKING ENVIRONMENT
#
# - PC: Macbook Pro / Air for all employees
#
# - Process: Agile / Waterfall / Hybrid
#
# - Method: DevOps
#
# - Group Ware (Email/Storage/Docs): Google Workspace
#
# - Communication Tools: Chatwork / Slack / Etc..
#
# - Online MTG Tools: Zoom / Google Meet / Etc..
#
# - PJ Task Management: Redmine / Jira / Backlog / Etc..
#
# - Employee Evaluation Policy: We evaluate your growth, & We will adjust your salary to market value or more
#
# - Testing Device (Smart Phone): A lot of the latest
#
# - Check in/out Time Management: Own System (Apps)
#
# - Certification Allowance: Many kinds, salary base up
#
# - Salary Review: Every 6 months
#
# - Party & Event: A lot
#
# - Career path: We define two main paths. Organizational management or expert (Specific Tech, PJ Management, UX
#
# design, Sales, Marketing, etc.). Even becoming Director, CTO, and also CEO of us is possible.
#
#
#
#
# OFFICE ENVIRONMENT
#
# - Office Type: Individual French Villa with Garden
#
# - Commute Type: Office & Remote (Hybrid)
#
# - Desk: Free desk or fixed desk, with a lot of free space
#
# - Parking: Ready & Free at office garden area
#
# - Office Wifi: Very fast! (Individual Line)
#
# - Crowded Elevator: Never happen!
#
# - Refrigerator: x4
#
# - Water Server: x5 Drink water forever!
#
# - Personal Locker: One per person
#
# - MTG Room & Space: 9 rooms & a lot of free space
#
# - Co-worker: Nice!
#
# - Cafe Area: Have a break!
#
# - Dresscode: None
#
# - Office Gym & Zen space: Yes! let's work out!
#
# - Chill Spot: Many!
#
# - Sound System: Yes! Let's Play M.U.S.I.C
#
# - Music Instrument: Guitar x3 , Cajon x1
#
# - Restroom:x4 male room & x3 woman room
#
#
#
#
# RECRUITMENT POLICY
#
# - Commitment to equal opportunities and personal growth
#
# - We welcome applicants of any nationality/ethnicity, regardless of age, gender, religion, background, or disability.
#
# - We strive to put employees in the best position for their abilities and growth, and offer a salary that is competitive and
#
# appealing.
#
#
#
#
# MESSAGE TO CANDIDATES
#
# Vietnam is in a period of significant growth, and our company continues to develop and grow accordingly. Why not join the team and grow with us?
#
# If you sympathize with our VISION and do your best here, we promise that your market value in the IT field will improve dramatically.
# Missing exp_2 for job: Yêu cầu công việc
#
# 8. Yêu cầu
#
# - Ứng viên dưới 30 tuổi.
#
# - Tốt nghiệp chuyên ngành Công nghệ thông tin, Điện tử viễn thông, Toán Tin hoặc tương đương;
#
# - Ngoại ngữ tiếng Anh: đọc - hiểu - nói trình độ khá trở lên;
#
# - Khả năng tìm kiếm tổng hợp thông tin, trình bày và viết tài liệu kỹ thuật;
#
# - Có tinh thần cầu tiến, chủ động, chịu áp lực cao, làm việc nhóm.
#
# - Ưu tiên các ứng viên đáp ứng tiêu chí:
#
# • Từng đảm trách vị trí: Senior software/SI engineer, Solution Architect;
#
# • Kinh nghiệm thiết kế, tích hợp, triển khai các dịch vụ CNTT hoặc Viễn thông quy mô vừa/lớn
#
# • Tham gia triển khai các hệ thống viễn thông lớn: gồm nhiều phần tử và hãng cung cấp
#
# • Có chứng chỉ về mạng IP, mạng viễn thông, cloud, an toàn thông tin.
#
#
#
#
# 09. Địa điểm làm việc:
#
# - Hà Nội: 124 Hoàng Quốc Việt, Nghĩa Tân, Cầu Giấy, Hà Nội.
#
#
#
#
# 10. Yêu cầu hồ sơ:
#
# 01 bản Tiếng Việt hoặc tiếng Anh nêu khả năng, kinh nghiệm, quá trình công tác, mức lương mong muốn, bảng điểm và các bằng cấp chứng chỉ photo (nếu có).
# Missing exp_2 for job: Yêu cầu công việc
#
# Basic Qualification
#
# - N2相当以上の流暢な日本語スキル
#
# - CEFR B1, IELTS 5.5程度以上の英語スキル（開発チームの共通言語は英語です）
#
# - ビジネス要件からシステムの仕様を定義する、または説明する能力
#
# - ClickUp, Jira などのツールを使用した、2週間以上にわたるタスクとスケジュール管理経験
#
# - Notion, Google Docs, スプレッドシートなどのツールを使用したドキュメント作成スキル
#
# - BizDev, SWEs, PdMとのタスクの優先度付け
#
# - 厳格なスケジュール管理能力
#
# Preferred Experience
#
# - KPI設定による開発チームの生産性の可視化やプロダクトの効果測定とその改善
#
# - Conversion Rate, Retention Rateなどのリリース後のプロダクトの各種KPIのモニタリング
#
# - アジャイルスクラムマスター
#
# - SWE、UI/UXデザイナーなどの経験
#
# - SQLを使ったデータ分析やテーブル定義
#
# - ジュニアプロジェクトマネジャー、ITコミュニケーターなどのメンタリング経験
#
# Screening Criteria
#
# - 担当チーム、ユーザーの課題を自ら見つけて解決する力
#
# - プロジェクトに関わるメンバーと協力し、チームワークを好む
#
# - 新しいテクノロジーの学習や適用に対する関心
#
# Compensation & Benefits
#
# - 条件付きフレックスタイム、ならびにWFH
#
# - MacBook 支給
#
# - 英語レッスン、その他複数教育費用サポート
#
# - プレミアムヘルスケア
#
# - 年間15日以上の有給
#
# - 月一懇親会、フリードリンク、社員旅行
#
# - 年2回の評価、ならびに給与見直し
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Đại học chuyên nghành điện hoặc điện tự động.
#
# - Sử dụng thành thạo phần mềm lập trình PLC (Keyence, Omron, Mitsubishi…)
#
# - Sử dụng thành thạo phần mềm văn phòng (Word, Excel, Powerpoint…)
#
# - Sử dụng thành thạo phần mềm AutoCad hoặc GstarCad
#
# - Ngoại ngữ: Có kỹ năng nghe, nói, đọc, viết tiếng Anh hoặc tiếng Nhật (ưu tiên tiếng Nhật)
#
# - Năng động, nhiệt tình, ham học hỏi.
#
# - Ưu tiên có kinh nghiệm tham gia sửa chữa máy (phần cơ khí và điện) là quản lý sản xuất hoặc quản lý ISO9001 là lợi thế.
#
#
#
#
# QUYỀN LỢI:
#
# - Lương cơ bản: Tối thiểu 9.850.000 đồng. (Thỏa thuận theo năng lực)
#
# - Phụ cấp chuyên cần: 200.000 đồng/tháng
#
# - Trợ cấp đi lại: Theo số Km thực tế.
#
# - Trợ cấp nhà trọ: Độc thân (360.000 đồng/tháng), ở cùng vợ/chồng và con được trợ cấp 70%
#
# tiền thuê nhà nhưng tối đa không quá 1.000.000 đồng/tháng).
#
# -. Chế độ BHXH, BHYT, BHTN & các quyền lợi khác theo quy định của Luật lao động hiện hành.
#
# - Được cấp phát đồng phục và các bảo hộ lao động khác.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp trình độ Đại học trở lên các chuyên ngành thuộc khối Công nghệ thông tin (Khoa học máy tính, Kĩ thuật phần mềm, Hệ thống thông tin, Điện tử - Viễn thông,...)
#
# - Có kiến thức chuyên môn tốt, am hiểu hoặc thông thạo một trong những lĩnh vực sau: Ngôn ngữ lập trình (Java, C#, Javascript, PHP, Python, HTML CSS, Android,…); các nền tảng (NodeJS, ReactJS, Angular, Laravel,...); CSDL (các hệ quản trị CSDL) hoặc quản trị hệ thống mạng (kiến trúc mạng, windows server, tường lửa, bảo mật,...)
#
# - Ưu tiên ứng viên có kinh nghiệm làm việc trong dự án thực tế hoặc từng tham gia giảng dạy về CNTT
#
# - Ưu tiên ứng viên có kĩ năng sư phạm, tư duy sáng tạo, cởi mở
#
# - Ưu tiên ứng viên có chứng chỉ nghiệp vụ sư phạm hoặc có kinh nghiệm về lập trình hoặc triển khai các các dự án CNTT
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp Đại học Bách Khoa, Đại học Quốc gia và các trường Đại học có ngành nghề liên quan.
#
#
#
#
# • Khả năng sử dụng thành thạo phần mềm thiết kế: NX, Autocad, Solidworks.
#
#
#
#
# • Hiểu nguyên lý hoạt động, phương pháp tính, chọn các thiết bị tiêu chuẩn.
#
#
#
#
# • Kỹ năng lập kế hoạch, triển khai thực tế theo tiến độ.
#
#
#
#
# • Kỹ năng làm việc nhóm và làm việc độc lập.
#
#
#
#
# • Chịu được áp lực công việc.
#
#
#
#
# • Có thể đi công tác theo yêu cầu công việc.
#
#
#
#
# • Làm việc sáng tạo, có đam mê nghiên cứu về sản phẩm tự động hóa
#
#
#
#
# • Có kinh nghiệm thực tế giữa thiết kế - gia công.
#
#
#
#
# • Chấp nhận những ứng viên chưa có kinh nghiệm nhưng phải có óc sáng tạo và tinh thần tự nghiên cứu, học hỏi.
# Missing exp_2 for job: nan
# Missing exp_2 for job: nan
# Missing exp_2 for job: Yêu cầu công việc
#
# 1. Experience:
#
# • Tốt nghiệp chuyên ngành Điện tử viễn thông hoặc CNTT
#
# • Graduated from University with major in Electronics and Telecommunications or IT
#
# 2. Language:
#
# • Có khả năng đọc các tài liệu kỹ thuật chuyên ngành bằng tiếng Anh
#
# • Ability to read specialized technical documents in English
#
# 3. Skill:
#
# • Có kinh nghiệm trực giám sát lĩnh vực IDC
#
# • Có kiến thức tổng quan về IT;
#
# • Có hiểu biết về một trong các lĩnh vực sau là một lợi thế: mạng lưới, thiết bị truyền dẫn viễn thông, hạ tầng máy chủ, hạ tầng trung tâm dữ liệu;
#
# • Ability in supervising duty in the field of IDC.
#
# • Have knowledge of IT;
#
# • Understanding in one of fields is advantage as: telecommunications networks and equipment, servers, facility of Data Center;
#
# 4. Acknowledgments:
#
# • Có chứng chỉ CCNA hoặc tương đương là một lợi thế;
#
# • Having certificates in network administration (CCNA) ... is an advantage;
# Missing exp_2 for job: Yêu cầu công việc
#
# • Nam - Nữ, tốt nghiệp Đại học chính quy trở lên chuyên ngành Điện tử viễn thông, Điện, Cơ khí
#
# • Sử dụng thành thạo tiếng Anh (đặc biệt là đọc và viết)
#
# • Ưu tiên những người đã làm việc trong lĩnh vực Sở hữu trí tuệ, hoặc đã có bằng Luật
#
# • Có sức khỏe tốt.
#
# Quyền lợi
#
# - Thu nhập 13 - 20 Triệu/ tháng trở lên
#
# - Được đào tạo bài bản; có nhiều cơ hội học hỏi và tham gia các hoạt động nâng cao chuyên môn
#
# - Môi trường làm việc mở, thân thiện, tôn trọng và phát triển bản thân
#
# - Cơ hội được sử dụng và nâng cao tiếng Anh thường xuyên
#
# - Được tham gia BHXH, thưởng các ngày lễ, nghỉ hè, thưởng cuối năm, thưởng theo doanh số do hỗ trợ phòng chuyên môn.
# Missing exp_2 for job: Yêu cầu công việc
#
# WHAT WE ARE LOOKING FOR
#
# - Background in Data Science, Data Engineering, Data Analysis, or Product Management
#
# - Knowledge of statistical modeling and machine learning techniques
#
# - Proficiency in data analysis tools like Excel, SQL, Python, and data visualization software
#
# - Strong problem-solving skills and ability to think analytically
#
# - Strong verbal and stakeholder-facing communication skillset
#
# -Solid documentation writing skills
#
# - English proficiency
#
# - Knowledge of Agile methodologies and experience working in Agile environments
#
#
#
#
# Preferred (but not required)
#
# - Strong business acumen and understanding of e-commerce operations
#
# - Experience with inventory management systems and software
#
# - Experience in managing projects, including setting timelines, milestones, and deliverables
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp Cao đẳng/Đại học chuyên ngành Công nghệ thông tin, Khoa học máy tính, Hệ thống thông tin, Điện tử viễn thông, hoặc lĩnh vực liên quan.
#
# • Có kinh nghiệm quản trị, triển khai/nâng cấp hệ thống Active Directory (AD).
#
# • Có kiến thức và kinh nghiệm triển khai, chuyển đổi hệ thống M365.
#
# • Có kiến thức về hạ tầng đám mây Microsoft Azure.
#
# • Hiểu biết chung về các gói sản phẩm M365
#
# • Có kiến thức về hệ thống email, kinh nghiệm triển khai & troubleshooting Exchange là một lợi thế.
#
# • Có kinh nghiệm triển khai các giải pháp bảo mật của Microsoft (EMS, Intune, DLP, Defender...) là một lợi thế
#
# • Có tìm hiểu và ứng dụng công cụ AI vào công việc là một lợi thế
#
# • Có kinh nghiệm/kiến thức tổng quan về hệ thống máy chủ, lưu trữ, network là một lợi thế
#
# *Quyền lợi
#
# • Review lương theo năng lực và kết quả công việc định kỳ hàng năm
#
# • Thưởng vinh danh nhân viên xuất sắc hàng quý, năm
#
# • Thưởng vào các dịp Lễ/Tết hàng năm
#
# • Hỗ trợ 100% chi phí tham gia các khóa học và thi chứng chỉ liên quan đến công việc, tạo điều kiện để học hỏi và phát triển cùng các chuyên gia trong ngành.
#
# • Được trang bị laptop làm việc hiện đại
#
# • Có đầy đủ các chế độ phúc lợi theo quy định nhà nước
#
# • Khám sức khỏe định kỳ
#
# • Tổ chức nhiều hoạt động teambuilding, nghỉ hè hàng năm hấp dẫn
# Missing exp_2 for job: Yêu cầu công việc
#
# - Trình độ học vấn/chuyên môn: Tốt nghiệp CĐ, ĐH (ưu tiên chuyên ngành kỹ thuật)
#
# - Chủ động học hỏi, nghiên cứu và đưa ra các giải pháp công nghệ nhằm phục vụ cho công việc.
#
# - Đảm bảo tiến độ triển khai công việc, báo cáo thường xuyên cho cấp trên và các phòng ban liên quan.
#
# - Team work tốt, xử lý sự cố phát sinh nhanh nhạy.
#
# - Có thể đi công tác khi có yêu cầu.
#
# - Chịu được áp lực công việc.
#
# - Kinh nghiệm, kỹ năng: sẽ được đào tạo thông qua công việc
#
# - Thành thạo word, excel
#
# - Độ tuổi từ 23-30.
#
# QUYỀN LỢI ĐƯỢC HƯỞNG
#
# - Thu nhập 7.5tr – 12tr tùy theo năng lực.
#
# - Hỗ trợ ăn trưa, xăng xe.
#
# - Thưởng theo đầu sự kiện tham dự và phục vụ (sẽ trao đổi kỹ hơn khi phỏng vấn).
#
# - Làm việc với các nhà cung cấp hàng đầu về thiết bị kỹ thuật, phòng họp.
#
# - Đóng các loại bảo hiểm (BHYT, BHXH, BHTN) ngay sau khi ký hợp đồng chính thức.
# Missing exp_2 for job: Yêu cầu công việc
#
# YÊU CẦU CÔNG VIỆC
#
# - Nam hoặc nữ tuổi
#
# Trình độ: Cao đẳng hoặc đại học
#
# - Ngoại ngữ: Tiếng anh cơ bản
#
# - Computer: Biết sử dụng office mail cơ bản
#
#
#
#
# ***CƠ HỘI VÀ QUYỀN LỢI:
#
# - Tham gia bảo hiểm theo quy định của luật bảo hiểm
#
# - Làm việc tại môi trường chuyên nghiệp, năng động, an toàn
#
# - Có cơ hội được học tập và đào tạo tại Nhật Bản
#
# - Thu nhập thỏa đáng theo năng lực làm việc.
#
# - Hỗ trợ đi lại cho nhân viên
#
# - Được nghỉ các thứ 7 và chủ nhật
# Missing exp_2 for job: Yêu cầu công việc
#
# • Trình độ học vấn: Đại học
#
# • Chuyên ngành: Cơ khí, cơ điện tử, điện tử, tự động hoá, tiếng Anh, tiếng Trung
#
# • Có kinh nghiệm trên một năm ở vị trí liên quan
#
# • Tiếng Anh/ tiếng Trung giao tiếp tốt
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp Đại học, chuyên ngành Kỹ thuật ô tô/ Cơ khí ô tô/ Chế tạo máy
#
# - Giao tiếp tiếng Anh thành thạo
#
# - Có niềm đam mê ô tô
#
# - Sáng tạo, say mê tìm tòi, học hỏi
#
# - Có khả năng tự nghiên cứu và làm việc độc lập
#
# - Có kỹ năng giao tiếp và làm việc nhóm
#
# - Sẵn sàng đi công tác (trong và ngoài nước)
#
# - Làm việc chăm chỉ, cường độ cao
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp Đại học trở lên các chuyên ngành Điện, Cơ khí thuộc ĐH Bách khoa Hà Nội, ĐH Công nghiệp Hà Nội, ĐH Công nghiệp Thái nguyên,…
#
# • Sử dụng thành thạo ít nhất 01 phần mềm thiết kế (Ansys maxwell, Orcad, AutoCad, SolidWorks, Inventor…) các chương trình mô phỏng, phần mềm văn phòng.
#
# • Đạo đức tốt, tác phong nhanh nhẹn, có sức khỏe tốt, hòa đồng với tập thể;
#
# • Có kinh nghiệm trong thiết kế máy điện, đọc hiểu tài liệu tiếng Anh chuyên môn là lợi thế
#
# * Ưu tiên ứng viên có kinh nghiệm trong ngành Thiết bị điện
#
# * Quyền lợi
#
# - Thu nhập hấp dẫn từ 15-20tr theo năng lực, công tác phí, ăn ca,...
#
# - Đóng BHXH đầy đủ, phúc lợi, nghỉ mát, thưởng,...
#
# - Có xe đưa đón CBCNV hàng ngày từ Cầu Diễn sang Đông Anh
# Missing exp_2 for job: Yêu cầu công việc
#
# • A degree in electrical engineering, computer engineering, or a related field.
#
# • Knowledge of System-On-Chip or ASIC design, and understanding of SoC or ASIC tools/flows.
#
# • Design/Verification skills, System Verilog, UVM.
#
# • RTL Synthesis Coding Solid experience in designing hardware accelerators, including FPGA/ ASIC development.
#
# • Proficiency in hardware description languages (e.g., VHDL, Verilog) and EDA tools.
#
# • Understanding of system level architecture, such as interconnects, memory hierarchy, interrupts, and memory-mapped IO.
#
# • In-depth knowledge of ML/DL Technologies.
#
# • Problem-solving skills and a passion for innovation.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Tốt nghiệp đại học chuyên ngành Điện tử Y Sinh, Y, Dược lâm sàng, vật lý y sinh
#
# • Ưu tiên ứng viên có kinh nghiệm làm App hoặc PS về thiết bị nội soi, thiết bị y tế. Chưa có kinh nghiệm được đào tạo
#
# • Thành thạo tiếng Anh
#
# • Kỹ năng giao tiếp, thuyết trình tốt
#
# • Kiên trì, có trách nhiệm, ham học hỏi
#
# • Có khả năng làm việc độc lập, theo nhóm, chịu được áp lực công việc, có thể đi công tác theo yêu cầu của dự án
# Missing exp_2 for job: Yêu cầu công việc
#
# - Sinh viên năm cuối (có thể làm fulltime) hoặc đã tốt nghiệp chuyên ngành Hệ thống thông tin (Ưu tiên), Công nghệ thông tin hoặc các bạn chuyên ngành Kinh doanh đã học qua khóa học về IT/Hệ thống thông tin. (MUST HAVE)
#
# - Có tư duy logic, khả năng phân tích tốt.
#
# - Kỹ năng giao tiếp và truyền đạt tốt, có khả năng làm việc nhóm.
#
# ...
#
# - Xét tăng lương mỗi mỗi năm 2 kì ( T6 , T12) theo thang KPI đánh giá mức độ năng lực công việc đáp ứng tiêu chuẩn Công ty.
#
# - Hưởng đây đủ các chế độ BHXH, BHYT, BHTN theo quy định nhà nước.
#
# Chế độ làm việc: Từ thứ Hai đến thứ Bảy: 8h00-17h30 tại Trụ sở chính
# Missing exp_2 for job: Yêu cầu công việc
#
#
#
#
# - Tốt nghiệp Đại học chuyên ngành hóa
#
# - Ưu tiên ứng viên có kinh nghiệm ngành nhựa
# Missing exp_2 for job: Yêu cầu công việc
#
# - High school graduate or higher
#
# - Electronics Engineering, Mechatronics Telecommunications or any other related majors
#
# - Circuit and RF technical knowledge is preferred
#
# - PCB and PBA repair experience is preferred
#
# - Process JIG setup experience is preferred
#
# - Electronics defect analysis experience is preferred
#
# - Experience in event response in electronics development model preferred
# Missing exp_2 for job: Yêu cầu công việc
#
# Yêu cầu chuyên môn:
#
# - Bằng cử nhân hoặc kỹ sư chuyên ngành Điện tử, Viễn thông, Kỹ thuật máy tính hoặc các ngành liên quan.
#
# - Kinh nghiệm làm việc trong lĩnh vực kiểm tra phần cứng, đặc biệt là kiểm tra các thiết bị điện tử, mạch in, hệ thống nhúng.
#
# - Kinh nghiệm sử dụng các thiết bị đo lường và kiểm tra phần cứng như oscilloscope, logic analyzer, đồng hồ đo.
#
# - Hiểu biết sâu về các nguyên lý hoạt động của phần cứng điện tử.
#
# - Khả năng đọc và hiểu các sơ đồ mạch điện.
#
# - Khả năng phân tích và giải quyết các vấn đề về phần cứng.
#
# - Kiến thức về các tiêu chuẩn kiểm tra chất lượng phần cứng.
#
# Yêu cầu bổ sung:
#
# - Tính cẩn thận, tỉ mỉ và trách nhiệm cao.
#
# - Kỹ năng làm việc nhóm.
#
# - Kỹ năng giao tiếp tốt.
#
# - Khả năng chịu áp lực công việc.
#
# - Kinh nghiệm làm việc với các hệ thống nhúng.
#
# - Kinh nghiệm làm việc với các giao thức truyền thông (ví dụ: UART, SPI, I2C).
#
# - Khả năng đọc hiểu tài liệu tiếng Anh chuyên ngành.
#
# - Có kiến thức về các tiêu chuẩn kiểm tra IEC, ISO, FCC.
#
# Quyền lợi:
#
# - Cơ hội làm việc với các công nghệ và nền tảng hiện đại.
#
# - Môi trường hỗ trợ học tập và phát triển chuyên môn liên tục.
#
# - Mức lương và chế độ phúc lợi cạnh tranh (trao đổi thêm khi PV)
# Missing exp_2 for job: Yêu cầu công việc
#
# - Học vấn: Tốt nghiệp đại học chính quy trở lên các ngành Kế toán, Kiểm toán, Tài chính, Ngân hàng, Phân tích dữ liệu…
#
# - Kỹ năng công nghệ:
#
# - Thành thạo Power BI, Tableau.
#
# - Ưu tiên có khả năng lập trình Python/R là một lợi thế lớn.
#
# - Hiểu biết về cơ sở dữ liệu SQL/Oracle và quản trị dữ liệu.
#
# - Kinh nghiệm: Có kinh nghiệm trong ngành tài chính, ngân hàng, bảo hiểm hoặc đầu tư là một điểm cộng.
#
# - Kiến thức chuyên môn: Am hiểu sâu về tài chính, quản trị rủi ro ngân hàng, hoặc quản trị danh mục tín dụng.
# Missing exp_2 for job: Yêu cầu công việc
#
# We ask
#
# • Someone with several years of relevant work experience
#
# • You have a completed a relevant education, preferably ICT or Electrical Engineering
#
# • Knowledge of one or more of these programming languages: C / C++ / C# (C-sharp)
#
# • Knowledge of programming with Visual Studio
#
# • Knowledge and interest in electrical products and solutions
#
# • Someone who is communicative
#
# • That you work independently, result-oriented and accurately
#
# • Good analytical ability
#
#
#
#
# We offer
#
# • An independent position in a flexible and highly international high-tech environment
#
# • An informal, collegial working atmosphere
#
# • A market-based salary
#
# • A good secondary employment package
#
# • Study opportunities to further deepen you in the field.
#
#
#
#
# We look forward to your application letter with interest. Only applications consisting of a CV and motivation letter will be processed.
#
# For more information, you can contact Mrs. Tran Bich Phuong (Assistant Manager Praxis Automation Technology, Vietnam)
#
# PRAXIS AUTOMATION VIETNAM CO., LTD
#
# Room 501, 508, 510, 511 – 5th floor – Taiyo Building - No.97 Bach Dang
#
# Ha Ly Ward, Hong Bang District, Hai Phong City
# Missing exp_2 for job: Yêu cầu công việc
#
# • Bachelor’s degree with a specialty in electronics or electrical engineering
#
# • Several years of relevant work or hobby experience
#
# • Interested in working with automation systems
#
# • Customer-oriented attitude
#
# • Good communications skills
#
# • Independent, result-oriented, accurate, and positive attitude
#
# • Good knowledge of English
#
# • Knowledge of design tools (Schematic and PCB layout)
#
# • Good analytical skills
#
# • Teamwork and positive attitude
#
# Work Conditions:
#
# • An international, informal, and collegial working atmosphere.
#
# • Enthusiastic colleagues who are always ready to help you
#
# • Competitive salary
#
# • Good secondary employment package
#
# • Training and personal development opportunities
#
# • Pension
#
# • You will start with a 3-month training course in the Netherlands with a salary and a daily allowance.
#
#
#
#
# For more information, you can contact Ms. Tran Bich Phuong (HR manager)
#
# PRAXIS AUTOMATION VIETNAM CO., LTD
#
# Room 501, 508, 510, 511 Taiyo Building, No.97 Bach Dang, Thuong Ly Ward, Hong Bang District, Hai Phong City, Vietnam
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp đại học chuyên ngành có liên quan (điện, tự động hóa, nhiệt lạnh, cấp thoát nước, cơ khí, môi trường, v.v.);
#
# - Nhanh nhẹn, có trách nhiệm với công việc, ý thức chấp hành kỷ luật tốt; Chịu được áp lực công việc;
#
# - Sử dụng thành thạo các phần mềm Autocad, Ms Excel, Ms Word;
#
# - Có khả năng đi công tác;
#
# - Ứng viên đã có kinh nghiệm làm việc (Thiết kế, thi công, bảo trì, vận hành các hệ thống cơ điện lạnh) sẽ có lợi thế ưu tiên.
#
# - Ứng viên sử dụng được tiếng Anh sẽ có lợi thế ưu tiên trong xét tuyển, thêm các ưu đãi và cơ hội thăng tiến.
#
#
#
#
# Quyền lợi
#
# - Cơ hội thăng tiến cao cho những người có ý thức trách nhiệm và có đủ năng lực.
#
# - Mức thu nhập phù hợp với khả năng, đảm bảo mức độ ưu đãi cạnh tranh so với mặt bằng chung;
#
# - Được hưởng đầy đủ các chế độ dành cho người lao động theo các quy định hiện hành (BHXH, BHYT, BHTN,…);
#
# - Được làm việc trong một môi trường năng động, thân thiện, ổn định, nhiều cơ hội thăng tiến;
#
# - Được cấp máy tính (Sau thời gian thử việc);
#
# - Được đào tạo thêm để nâng cao nghiệp vụ chuyên nghiệp;
#
# - Được hưởng các chế độ, quyền lợi khác theo quy định của Công ty.
#
#
#
#
# Nộp hồ sơ: Ấn nút nộp đơn trên VIETNAMWORKS hoặc nộp trực tiếp tại VP Công ty tại: Tầng 5, Số 27, Phố Hàng Đậu, Hoàn Kiếm, Hà Nội
# Missing exp_2 for job: Yêu cầu công việc
#
# • Proven experience in Golang development and ability to write clean, maintainable code.
#
# • Strong knowledge of Google Cloud Platform (GCP) services and infrastructure.
#
# • Hands-on experience with Elastic databases and optimizing search and analytics operations.
#
# • Proficiency in Grafana for system monitoring and performance visualization.
#
# • Expertise in Kubernetes and containerized application deployment.
#
# • Experience with Ansible and other automation tools for configuration management and infrastructure as code.
#
# • Understanding of CI/CD pipelines and DevOps best practices.
#
# • Familiarity with networking, security, and Linux system administration.
#
# • Strong problem-solving skills and ability to work in a fast-paced, collaborative environment.
#
# • Excellent communication and documentation skills.
# Missing exp_2 for job: Yêu cầu công việc
# 1. Thành thạo phần mềm tạo mẫu codesoft/BarTender
# 2. Ưu tiên biết tiếng Trung, yêu cầu tối thiểu là có thể giao tiếp bằng tiếng Anh
# 3. Khả năng làm việc ca đêm
# Missing exp_2 for job: Yêu cầu công việc
#
# Nhân viên công nghệ thông tin.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp CĐ,ĐH chuyên ngành: Cơ điện tử, Điện, Điện tử,...
#
# - TUYỀN DỤNG SINH VIÊN MỚI TỐT NGHIỆP/ KHÔNG YÊU CẦU KINH NGHIỆM
#
# - Am hiểu về bản mạch điện tử và các thiết bị điện tử
#
# - Có kiến thức về phân tích lỗi sản phẩm, đọc bản mạch, nhận biết linh kiện.
#
# ***QUYỀN LỢI
#
# - Thu nhập hấp dẫn (Ứng viên có thể thỏa thuận trong quá trình phỏng vấn).
#
# - Tham gia đầy đủ BHXH, BHYT, BHTN
#
# - Thưởng hè 50% tháng lương
#
# - Nghỉ 3 thứ 7 và 4 chủ nhật ( Nếu đi làm tính lương 200%)
#
# - Tham gia các khóa đào tạo nâng cao tay nghề của công ty
#
# - Tham gia bảo hiểm tai nạn nhóm của Hanwha Life
#
# - Du lịch hàng năm theo quy định
# Missing exp_2 for job: Yêu cầu công việc
#
# - Tốt nghiệp CĐ,ĐH các chuyên ngành liên quan
#
# - Sinh viên mới tốt nghiệp không yêu cầu kinh nghiệm
#
# - Ưu tiên có hiểu biết về sửa chữa linh kiện điện tử, bản mạch trong công ty chế xuất nước ngoài
#
# - Ưu tiên biết phân tích mạch lỗi, sửa mạch, biết đọc bản vẽ .. có kinh nghiệm về sửa hàng Camera là lợi thế
#
# ***QUYỀN LỢI
#
# - Thu nhập hấp dẫn (Ứng viên có thể thỏa thuận trong quá trình phỏng vấn) => Lương cơ bản + OT
#
# - Tham gia đầy đủ BHXH, BHYT, BHTN
#
# - Thưởng hè 50% tháng lương
#
# - Nghỉ 3 thứ 7 và 4 chủ nhật ( Nếu đi làm tính lương 200%)
#
# - Tham gia các khóa đào tạo nâng cao tay nghề của công ty
#
# - Tham gia bảo hiểm tai nạn nhóm của Hanwha Life
#
# - Du lịch hàng năm theo quy định
# Missing exp_2 for job: Yêu cầu công việc
#
# * Nam, tốt nghiệp Đại Học các chuyên ngành sau : Điện tử / Tự động hóa /Công nghệ chế tạo máy /Quản trị doanh nghiệp.
#
# * Ưu tiên ứng viên tốt nghiệp các ngành khối quản lý công nghiệp hoặc quản trị doanh nghiệp.
#
# * Có kỹ năng quản lý, lập kế hoạch, đàm phán,kỹ năng phân tích và giải quyết vấn đề ,kỹ năng giao tiếp , thuyết trình , dẫn dắt đội nhóm.
#
# * Có kiến thức ngành nghề liên quan Quản lý sản xuất -Knowledgeable industry related production management
#
#
#
#
#
#
#
# ***Khi trở thành một thành viên của UMCVN, bạn sẽ được hưởng những quyền lợi sau:
#
# 1. Cơ hội thăng tiến cao:Tổ chức đánh giá, xét duyệt tăng chức hàng năm.
#
#
#
#
# 2. Lương
#
# - Lương từ 400 đến 600 USD. Ngoài lương, còn được hưởng thêm các trợ cấp khác: trợ cấp xăng xe, trợ cấp chuyên cần, trợ cấp tăng ca....
#
# - Tăng lương ít nhất mỗi năm 1 lần
#
#
#
#
# 3. Thưởng
#
# - Thưởng tết âm lịch : Ít nhất 1 tháng lương.
#
# - Hỗ trợ tiền đi lại vào các dịp Lễ: 30/4 - 1/5, 2/9.
#
# - Tặng quà vào các dịp Tết trung thu, 08/03...
#
#
#
#
# 4. Chế độ phúc lợi
#
# - Công ty trả tiền bữa ăn chính, ăn phụ.
#
# - Khám sức khỏe định kỳ miễn phí
#
# - Tham gia BHXH, BHYT, BHTN
#
# - Ngày nghỉ: Ít nhất 6 ngày/ tháng + 12 ngày phép/ năm và các ngày nghỉ Lễ, Tết
#
# - Chất lượng bữa ăn ngon. Suất ăn đặc biệt vào thứ 2 hàng tuần và ngày 15 hàng tháng. Bữa ăn chính được lấy đồ ăn thêm. Suất ăn đặc biệt dành cho người đang mang bầu.
#
# - Tổ chức các hoạt động ngoại khóa: du lịch 2 ngày 1 đêm, bốc thăm trúng thưởng với nhiều phần quà hấp dẫn: xe máy, tivi, tủ lạnh, máy giặt.......
#
#
#
#
# 5. Môi trường làm việc
#
# - Môi trường làm việc sạch sẽ, không tiếng ồn, an toàn và chuyên nghiệp
#
# - Trang bị hệ thống điều hòa làm mát 2 chiều
#
# - Trang bị phòng nghỉ, có siêu thị UMC, phòng trà UMC.
#
# - Tất cả nhân viên đều thân thiện, giúp đỡ nhau trong công việc.
#
#
#
#
# ***Ghi chú: Ứng viên ứng tuyển bằng cách ấn nút "NỘP ĐƠN" trên góc bên phải và gửi CV đến chúng tôi qua Vietnamworks.
#
#
#
#
# Khi gửi CV ứng viên vui lòng cung cấp đầy đủ số CCCD.
# Missing exp_2 for job: Yêu cầu công việc
#
# - Giới tính: Nam
#
# - Tốt nghiệp Cao đẳng trở lên các chuyên ngành: Điện, Tự động hóa,...
#
# - Sử dụng thành thạo AutoCad Electrical.
#
# - Lập trình thành thạo PLC, HMI, Servo một số hãng Mitsubishi, Keyence, Omron, Siemen ...
#
# - Có thể đi công tác.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Trình độ cao đẳng, đại học các ngành: hóa học, môi trường, sinh học, thổ nhưỡng, vật lý hạt nhân, phóng xạ…
#
# • Có khả năng sử dụng thiết bị quan trắc hiện trường, lấy mẫu phân tích
#
# • Có kinh nghiệm từ 1 đo đạc, lấy mẫu ngoài hiện trường
#
# • Sức khỏe tốt, chấp nhận đi công tác dài ngày ở các tỉnh thành trong cả nước
#
# • Sử dụng thành thạo hệ thống Iso Kinetic, testo 350, các thiết bị đo nhanh… là lợi thế lớn
#
# • Giới tính: nam từ 22 đến 35 tuổi.
#
# • Có sức khỏe tốt, siêng năng chăm chỉ, trung thực, chịu được áp lực công việc, có khả năng làm việc độc lập.
#
# • Tin học: Sử dụng thành thạo Word, Excel
#
# • Ngoại ngữ: Tiếng anh cơ bản.
#
#
#
#
# QUYỀN LỢI ỨNG VIÊN
#
# • Lương, phụ cấp từ 10 – 18 triệu hoặc thỏa thuận theo năng lực, kinh nghiệm làm việc và chức vụ
#
# • Nhiều cơ hội thăng tiến, môi trường làm việc chuyên nghiệp, năng động và thân thiện.
#
# • Thường xuyên được đào tạo để nâng cao kỹ năng và nghiệp vụ chuyên môn.
#
# • Hưởng đầy đủ các chế độ bảo hiểm và chính sách phúc lợi khác của công ty.
#
# • Ký hợp đồng lao động sau thời gian thử việc, đóng bảo hiểm đầy đủ.
#
# • Lương thưởng tháng 13, xét thưởng và xét tăng lương định kỳ hàng năm
#
# THÔNG TIN KHÁC
#
# • Số lượng: 8 người
#
# • Hạn nộp hồ sơ: 29/04/2025, ưu tiên những hồ sơ nộp trước
#
# • Hồ sơ bao gồm: đơn xin việc, CV, bảng photo bằng cấp và chứng chỉ
#
# • Trực tiếp tại địa chỉ: 40/7 Đông hưng thuận 14b, Khu phố 4, Đông hưng thuận, Quận 12
# Missing exp_2 for job: Yêu cầu công việc
#
# 日本語：N3～N2・または同等のスキル
#
# Tiếng Nhật tương đương N3~N2, có thể trao đổi trực tiếp với người Nhật.
#
# Đối với ứng viên chưa có kinh nghiệm, chỉ cần yêu thích công việc liên quan đến IT Helpdesk, set up hệ thống, quản lý mạng nội bộ.
# Missing exp_2 for job: Yêu cầu công việc
#
# Qualifications
#
# • Proven UI/UX experience with a strong portfolio.
#
# • Proficient in UI/UX software like Figma, Adobe Xd
#
# • Good visual design skills.
#
# • Good English communication.
#
# • Team management experience.
#
#
#
#
# What We Offer
#
# • Leadership role in UX of digital products.
#
# •Remote and hybrid-friendly work environment.
#
# • Competitive salary and benefits
#
# • Suggested salary: 25,000,000 - 30,000,000VND
#
#
#
#
# Employee benefits
#
# • Attractive bonus and benefits.
#
# • Annual Medical Check-up.
#
# • Device Support: Monthly allowance based on .
#
# • Language Certification Bonus (English or Japanese).
#
# • Annual Company Trip.
#
# • Support professional development program and activities.
# Missing exp_2 for job: Yêu cầu công việc
#
# Sử dụng thành thạo phần mềm thiết kế có khí 3D và 2D
#
# Đọc hiểu tài liệu Kỹ thuật, tìm thông tin của hãng thiết bị
#
# Khả năng giao tiếp, trao đổi ý tưởng, giải thích vấn đề một cách hiệu quả
#
# Đam mê thiết kế cơ khí, hệ thống điều khiển tự động hóa
#
# Tinh thần cởi mở, học hỏi, có thể thích nghi tốt với sự phát triển của công việc
#
# Tính trung thực, cầu tiến.
# Missing exp_2 for job: Yêu cầu công việc
#
# • Trình độ học vấn: Tốt nghiệp Đại học chuyên ngành Điện, Điện tử hoặc các ngành liên quan;
#
# • Kinh nghiệm làm việc: Chấp nhận sinh viên mới ra trường; Ưu tiên có kinh nghiệm làm việc trong lĩnh vực kỹ thuật điện, PE điện hoặc tương đương;
#
# • Yêu cầu chuyên môn: Hiểu biết sâu về các hệ thống điện và quy trình sản xuất điện tử; Thành thạo các công cụ và phần mềm liên quan đến kỹ thuật điện;
#
# • Yêu cầu kỹ năng: Kỹ năng giải quyết vấn đề tốt và khả năng làm việc nhóm; Thành thạo các công cụ và phần mềm liên quan đến kỹ thuật điện; Sẵn sàng làm việc theo ca và tiếp thu công nghệ mới; Có tinh thần trách nhiệm cao và khả năng làm việc dưới áp lực;
#
# • Yêu cầu ngôn ngữ: Thành thạo tiếng Trung hoặc tiếng Anh.
# Missing exp_2 for job: Yêu cầu công việc
#
# Trình độ & Kinh nghiệm :
#
# - Tốt nghiệp ngành Công nghệ thông tin, Khoa học máy tính, Trí tuệ nhân tạo, Kỹ thuật phần mềm hoặc
#
# các lĩnh vực liên quan.
#
# - Có ít nhất 6 tháng kinh nghiệm tại vị trí Developer, hoặc Automation.
#
# - Có kiến thức về ít nhất một ngôn ngữ lập trình: Python, Java, JavaScript, C++…
#
# - Kinh nghiệm triển khai các giải pháp AI
#
#
#
#
# Kỹ năng & Kiến thức chuyên môn:
#
# - Hiểu biết về các AI, các mô hình AI Agent là một lợi thế
#
# - Kinh nghiệm làm việc với các nền tảng Automation như Make, Zapier, N8N hoặc các công cụ tương tự.
#
# - Kỹ năng tư duy lập trình tốt là điểm cộng
#
#
#
#
# Phẩm chất cá nhân:
#
# - Đam mê nghiên cứu và ứng dụng công nghệ AI, Automation vào thực tế.
#
# - Tư duy đổi mới, sáng tạo, chủ động trong công việc.
#
# - Kỹ năng giải quyết vấn đề và tư duy hệ thống tốt.
#
# - Khả năng làm việc độc lập và phối hợp với nhiều phòng ban.
#
#
#
#
# Quyền lợi:
#
# Tổng NET: $1900 - $2350
#
# - Thời gian làm việc 08h/ngày
#
# - Bảo hiểm y tế
#
# - Nghỉ 07 ngày/tháng (có cộng dồn)
#
# - Phụ cấp suất ăn
#
# - Phụ cấp nhà ở
#
# - Phụ cấp đi lại
#
# - Phụ cấp chuyên cần
#
# - Phụ cấp thâm niên
#
# - Phụ cấp giáo dục con cái
#
# - Phụ cấp thu hút người nước ngoài
#
# - Du lịch nước ngoài hàng năm
#
# - Thưởng tháng lương thứ 13
#
# - Thưởng kỳ (6 tháng)
#
# - Thưởng ngày lễ, tết
#
# - Tiệc sinh nhật CBNV, lễ, tết
#
# - Các hoạt động team building, thể thao, ... định kỳ
#
# - Nghỉ việc riêng có hưởng lương
#
# - Nhiều quyền lợi khác ...

# %%
# in job_des and job_requirement, if '\n' in text, replace it with ' ', if multiple ' ' replace by one ' '
def normalize_text(text):
    if pd.isnull(text):
        return text
    text = text.replace('\n', ' ')
    text = re.sub(r'\s+', ' ', text)  # replace multiple spaces with one space
    return text.strip()

# in job_des and job_requirement, if '\n' in text, replace it with ' ', if multiple ' ' replace by one ' '
df['job_des'] = df['job_des'].apply(normalize_text)
df['job_requirement'] = df['job_requirement'].apply(normalize_text)

# %%
# delete salary skill_1	skill_2	skill_3	
df = df.drop(columns=['salary', 'skill_1', 'skill_2', 'skill_3'])

# %%
# delete if min_experience = nan
df = df.dropna(subset=['min_experience'])

# %%
df.head()
# if exp_2 = nan -> continue, else, if exp_2 > min_experience, min exp = exp_2
def adjust_min_experience(row):
    if pd.isnull(row['exp_2']):
        return row
    if row['exp_2'] > row['min_experience']:
        row['min_experience'] = row['exp_2']
    return row

df = df.apply(adjust_min_experience, axis=1)

# %%
df.head()
# Out:
#                                              job_name  \
# 0        Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 3   Product Manager (Global Market) - Lương Upto $...
# 6   C / C++ Software Engineer - Relocation Bonus -...
# 7   Android Devevloper (Relocation Bonus - Hybrid ...
# 14                                      Data Engineer
#
#                                               company location  \
# 0                        Công Ty Cổ Phần Xây Dựng TEG   Hà Nội
# 3                             MISA Jointstock Company   Hà Nội
# 6   LG Electronics Development Vietnam Company Lim...  Đà Nẵng
# 7   LG Electronics Development Vietnam Company Lim...  Đà Nẵng
# 14                                        Techcombank   Hà Nội
#
#                                               job_des  \
# 0   Mô tả công việc - Triển khai tính toán, thiết ...
# 3   Mô tả công việc Mô tả công việc • Định hướng v...
# 6   Mô tả công việc LG Electronics Development Vie...
# 7   Mô tả công việc LG Electronics Development Vie...
# 14  Mô tả công việc • Lead the team technically in...
#
#                                       job_requirement  \
# 0   Yêu cầu công việc 2. YÊU CẦU ỨNG VIÊN - Tốt ng...
# 3   Yêu cầu công việc Yêu cầu công việc • Tốt nghi...
# 6   Yêu cầu công việc 1. Requirement: - Basic Qual...
# 7   Yêu cầu công việc 1. General Requirement: _ Ba...
# 14  Yêu cầu công việc 1. Must have: • Bachelor’s o...
#
#                       level  \
# 0                 Nhân viên
# 3   Giám Đốc và Cấp Cao Hơn
# 6                 Nhân viên
# 7                 Nhân viên
# 14                Nhân viên
#
#                                              category  \
# 0            Khoa Học & Kỹ Thuật > Cơ Khí & Điện Lạnh
# 3   Công Nghệ Thông Tin/Viễn Thông > Quản Lý Dự Án...
# 6   Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
# 7   Công Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy ...
# 14  Công Nghệ Thông Tin/Viễn Thông > Data Engineer...
#
#                                                skills  \
# 0   Thiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều...
# 3   Lập Kế Hoạch Kinh Doanh, Phân Tích Dữ Liệu, Ng...
# 6               C++, C/C++, Software Development, OOP
# 7   Java, Java Spring Framework, Software Engineer...
# 14  Banking, Data Engineer, Computer Science, Info...
#
#                               field  min_experience  min_salary  max_salary  \
# 0   Kỹ thuật xây dựng/Cơ sở hạ tầng             1.0  20000000.0  20000000.0
# 3    Phần Mềm CNTT/Dịch vụ Phần mềm             3.0  25000000.0  50000000.0
# 6    Phần Mềm CNTT/Dịch vụ Phần mềm             1.0  20000000.0  62500000.0
# 7    Phần Mềm CNTT/Dịch vụ Phần mềm             2.0  20000000.0  62500000.0
# 14                        Ngân hàng             3.0  25000000.0  62500000.0
#
#     exp_2 education
# 0     1.0  bachelor
# 3     NaN  bachelor
# 6     1.0  bachelor
# 7     2.0  bachelor
# 14    3.0    master

# %%
# drop exp_2
df = df.drop(columns=['exp_2'])

# %%
# if education = nan, replace it with 'unknown'
df['education'] = df['education'].fillna('unknown')

# %%
# save to xlsx
df.to_excel('../data/vietnamworks_preprocessed.xlsx', index=False)

# %% [markdown]
# ## COMPANY NAME

# %%
# Xóa dấu chấm cuối câu, xóa khoảng trống thừa, chuyển về chữ thường
df['company'] = df['company'].apply(lambda x: x.strip().lower().capitalize() if isinstance(x, str) else x)

# viết hoa đầu mỗi từ
df['company'] = df['company'].apply(lambda x: string.capwords(x) if isinstance(x, str) else x)

# print unique
print(df['company'].nunique())
# Out:
# 758

# %%
print(df['company'].value_counts().head(10))
# Out:
# company
# Navigos Search's Client                               42
# Ngân Hàng Thương Mại Cổ Phần Quân Đội - Mb            28
# Navigos Search                                        22
# Techcombank                                           17
# Bosch Global Software Technologies Company Limited    16
# Công Ty Cổ Phần Tập Đoàn Golden Gate                  10
# Công Ty Cổ Phần Chứng Khoán Ssi                        9
# Vinfast Trading And Production Jsc                     8
# Heineken Vietnam                                       8
# Công Ty Cổ Phần Thanh Toán Quốc Gia Việt Nam           8
# Name: count, dtype: int64

# %% [markdown]
# ## CỘT pther

# %%
# Hàm xử lý từng dòng trong cột 'general_info'
def process_other(text):
    # Loại bỏ '\n' và khoảng trắng thừa
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\s+', ' ', text)
    
    # Lấy đoạn giữa "Cấp bậc" và "Số lượng tuyển"
    # Nếu không tìm thấy thì trả về chuỗi rỗng
    position = text[text.find('Cấp bậc') + len('Cấp bậc:'):text.find('Số lượng tuyển')].strip()

    # Lấy đoạn giữa "Hình thức làm việc" và "Giới tính"
    # Nếu không tìm Giới tính thì in ra chuỗi sau "Hình thức làm việc"
    work_type = text[text.find('Hình thức làm việc') + len('Hình thức làm việc:'):text.find('Giới tính')].strip()

    return position, work_type

# %%
text = df['other'].iloc[0]
print(process_other(text))
# Out:
# ('in việc làmNGÀY ĐĂNG15/05/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGThiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều Hòa Thông Gió, Cơ ĐiệnLĨNH VỰCKỹ thuật xây dựng/Cơ sở hạ tầngNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê', 'NGÀY ĐĂNG15/05/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGThiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều Hòa Thông Gió, Cơ ĐiệnLĨNH VỰCKỹ thuật xây dựng/Cơ sở hạ tầngNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê')

# %%
# Fill NaN values with an empty string
df['other'] = df['other'].fillna('')

# Áp dụng hàm cho toàn bộ cột 'other'
df['position'], df['work_type'] = zip(*df['other'].apply(process_other))

# Kết quả
print(df)
# Out:
#                                                job_name  \
# 0          Kỹ Sư Thiết Kế Cơ Điện (Upto 20 Triệu/tháng)
# 1                      Technical Documentation Engineer
# 2     Automation Software Tester (Selenium/java/appium)
# 3     Product Manager (Global Market) - Lương Upto $...
# 4         Professional Electrical Installation Designer
# ...                                                 ...
# 1339       Chuyên Viên IT Helpdesk _Ưu Tiên Đi Lam Ngay
# 1340            Technical Lead (Nextjs & Nestjs) Remote
# 1341            Technical Lead (Nextjs & Nestjs)_Remote
# 1342    NHÂN VIÊN KỸ THUẬT ĐIỆN (Electrical Technician)
# 1343                Nghiên Cứu Ứng Dụng AI & Automation
#
#                                                 company                salary  \
# 0                          Công Ty Cổ Phần Xây Dựng Teg      Tới 20tr ₫/tháng
# 1        Công Ty Tnhh Specialty Bolt And Screw Việt Nam          Thương lượng
# 2     Bosch Global Software Technologies Company Lim...          Thương lượng
# 3                               Misa Jointstock Company  $ 1,000-2,000 /tháng
# 4           Danieli – Industrielle Beteiligung Co., Ltd          Thương lượng
# ...                                                 ...                   ...
# 1339         Công Ty Cổ Phần Tập Đoàn Phú Thái Holdings      $ 500-600 /tháng
# 1340                            Navigos Search's Client  $ 3,000-5,000 /tháng
# 1341                            Navigos Search's Client  $ 3,000-5,000 /tháng
# 1342  Cty Tnhh Công Nghệ Điện Tử - Nghe Nhìn Boe Việ...     13tr-18tr ₫/tháng
# 1343                                   Azplays Co., Ltd  $ 1,900-2,350 /tháng
#
#                          location                  skill_1  \
# 0                          Hà Nội         Thiết Kế Cơ Điện
# 1                     Hồ Chí Minh                  Autocad
# 2                     Hồ Chí Minh       Automation Testing
# 3                          Hà Nội  Lập Kế Hoạch Kinh Doanh
# 4                     Hồ Chí Minh        Electrical Design
# ...                           ...                      ...
# 1339                       Hà Nội   Quản Trị Hệ Thống CNTT
# 1340              Hà Nội, Đà Nẵng                   Nextjs
# 1341              Hà Nội, Đà Nẵng                   Nextjs
# 1342  Đồng Nai, Bà Rịa - Vũng Tàu            Kỹ Thuật Điện
# 1343         Quốc tế, Hồ Chí Minh            ICT Solutions
#
#                      skill_2                  skill_3  \
# 0          Thiết Kế Hệ Thống                      BIM
# 1     Mechanical Engineering       Quality Management
# 2                       Java                   Appium
# 3          Phân Tích Dữ Liệu    Nghiên Cứu Thị Trường
# 4              ISO Standards  Electrical Installation
# ...                      ...                      ...
# 1339   Cài Đặt Windows Sever                      NaN
# 1340                  NestJS               PostgreSQL
# 1341                  NestJS               PostgreSQL
# 1342                      PE              Tiếng Trung
# 1343   Programning Languages                      NaN
#
#                                                 job_des  \
# 0     Mô tả công việc\n\n- Triển khai tính toán, thi...
# 1     Mô tả công việc\n\n1. Job Summary\n\nWe are lo...
# 2     Mô tả công việc\n\n- Develop, maintain and exe...
# 3     Mô tả công việc\n\nMô tả công việc\n\n• Định h...
# 4     Mô tả công việc\n\n• Read and decode block dia...
# ...                                                 ...
# 1339  Mô tả công việc\n\n• IT phần cứng:\n\n+ Xây dự...
# 1340  Mô tả công việc\nWhat You'll Be Doing\n• Lead ...
# 1341  Mô tả công việc\nWhat You'll Be Doing\n• Lead ...
# 1342  Mô tả công việc\n\nMô tả công việc:\n\n1. Xác ...
# 1343  Mô tả công việc\n\nMô tả công việc:\n\n• Nghiê...
#
#                                         job_requirement  \
# 0     Yêu cầu công việc\n\n2. YÊU CẦU ỨNG VIÊN\n\n- ...
# 1     Yêu cầu công việc\n\nEducation: Bachelor degre...
# 2     Yêu cầu công việc\n\n- 1-2 years of experience...
# 3     Yêu cầu công việc\n\nYêu cầu công việc\n\n• Tố...
# 4     Yêu cầu công việcQualifications and experience...
# ...                                                 ...
# 1339  Yêu cầu công việc\n\n- Ứng viên sinh năm từ 19...
# 1340  Yêu cầu công việc\n• 6+ years of full-stack de...
# 1341  Yêu cầu công việc\n• 6+ years of full-stack de...
# 1342  Yêu cầu công việc\n\n• Trình độ học vấn: Tốt n...
# 1343  Yêu cầu công việc\n\nTrình độ & Kinh nghiệm :\...
#
#                                                   other Unnamed: 10  \
# 0     Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 1     Thông tin việc làm\nNGÀY ĐĂNG\n\n15/05/2025\n\...         NaN
# 2     Thông tin việc làm\nNGÀY ĐĂNG\n\n18/04/2025\n\...         NaN
# 3     Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
# 4     Thông tin việc làm\nNGÀY ĐĂNG\n\n21/04/2025\n\...         NaN
# ...                                                 ...         ...
# 1339  Thông tin việc làm\nNGÀY ĐĂNG\n\n13/04/2025\n\...         NaN
# 1340  Thông tin việc làm\nNGÀY ĐĂNG\n\n12/04/2025\n\...         NaN
# 1341  Thông tin việc làm\nNGÀY ĐĂNG\n\n12/04/2025\n\...         NaN
# 1342  Thông tin việc làm\nNGÀY ĐĂNG\n\n12/04/2025\n\...         NaN
# 1343  Thông tin việc làm\nNGÀY ĐĂNG\n\n12/04/2025\n\...         NaN
#
#      experience_require                                           position  \
# 0                     1  in việc làmNGÀY ĐĂNG15/05/2025CẤP BẬCNhân viên...
# 1                  None  in việc làmNGÀY ĐĂNG15/05/2025CẤP BẬCMới Tốt N...
# 2                  None  in việc làmNGÀY ĐĂNG18/04/2025CẤP BẬCNhân viên...
# 3                     3  in việc làmNGÀY ĐĂNG21/04/2025CẤP BẬCGiám Đốc ...
# 4                  None  in việc làmNGÀY ĐĂNG21/04/2025CẤP BẬCNhân viên...
# ...                 ...                                                ...
# 1339                  2  in việc làmNGÀY ĐĂNG13/04/2025CẤP BẬCNhân viên...
# 1340                  6  in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng ph...
# 1341                  6  in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng ph...
# 1342               None  in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCNhân viên...
# 1343                  1  in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCNhân viên...
#
#                                                  skills  \
# 0     Thiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều...
# 1     Autocad, Mechanical Engineering, Quality Manag...
# 2     Automation Testing, Java, Appium, Selenium, AP...
# 3     Lập Kế Hoạch Kinh Doanh, Phân Tích Dữ Liệu, Ng...
# 4     Electrical Design, ISO Standards, Electrical I...
# ...                                                 ...
# 1339  Quản Trị Hệ Thống CNTT, Cài Đặt Windows Sever,...
# 1340  Nextjs, NestJS, PostgreSQL, Typescript, Englis...
# 1341  Nextjs, NestJS, PostgreSQL, Typescript, Englis...
# 1342  Kỹ Thuật Điện, PE, Tiếng Trung, Điện + Điện tử...
# 1343  ICT Solutions, Programning Languages, Automati...
#
#                                     field  \
# 0         Kỹ thuật xây dựng/Cơ sở hạ tầng
# 1                                    Ô tô
# 2          Phần Mềm CNTT/Dịch vụ Phần mềm
# 3          Phần Mềm CNTT/Dịch vụ Phần mềm
# 4     Cơ khí/Máy móc/Thiết bị công nghiệp
# ...                                   ...
# 1339                        Bán lẻ/Bán sỉ
# 1340       Phần Mềm CNTT/Dịch vụ Phần mềm
# 1341       Phần Mềm CNTT/Dịch vụ Phần mềm
# 1342                         Điện/Điện tử
# 1343       Phần Mềm CNTT/Dịch vụ Phần mềm
#
#                                               work_type
# 0     NGÀY ĐĂNG15/05/2025CẤP BẬCNhân viênNGÀNH NGHỀK...
# 1     NGÀY ĐĂNG15/05/2025CẤP BẬCMới Tốt NghiệpNGÀNH ...
# 2     NGÀY ĐĂNG18/04/2025CẤP BẬCNhân viênNGÀNH NGHỀC...
# 3     NGÀY ĐĂNG21/04/2025CẤP BẬCGiám Đốc và Cấp Cao ...
# 4     NGÀY ĐĂNG21/04/2025CẤP BẬCNhân viênNGÀNH NGHỀK...
# ...                                                 ...
# 1339  NGÀY ĐĂNG13/04/2025CẤP BẬCNhân viênNGÀNH NGHỀC...
# 1340  NGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng phòngNGÀNH NG...
# 1341  NGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng phòngNGÀNH NG...
# 1342  NGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀK...
# 1343  NGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀC...
#
# [1344 rows x 16 columns]

# %%
#delete all in position after "Học vấn"
df['position'] = df['position'].apply(lambda x: x.split('Học vấn')[0])
# delete blank
df['position'] = df['position'].apply(lambda x: x.strip())

# %%
#if position = '', then fill with "Nhân viên"
df['position'] = df['position'].apply(lambda x: 'Nhân viên' if x == '' else x)

# %%
#print unique
print(df['position'].unique())
# Out:
# ['in việc làmNGÀY ĐĂNG15/05/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGThiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều Hòa Thông Gió, Cơ ĐiệnLĨNH VỰCKỹ thuật xây dựng/Cơ sở hạ tầngNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê'
#  'in việc làmNGÀY ĐĂNG15/05/2025CẤP BẬCMới Tốt NghiệpNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGAutocad, Mechanical Engineering, Quality Management, SolidWorks, MechanicalLĨNH VỰCÔ tôNGÔN NGỮ TRÌNH BÀY HỒ SƠTiếng AnhSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  'in việc làmNGÀY ĐĂNG18/04/2025CẤP BẬCNhân viênNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > QA/QC/Software TestingKỸ NĂNGAutomation Testing, Java, Appium, Selenium, API TestingLĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  ...
#  'in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng phòngNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy TínhKỸ NĂNGNextjs, NestJS, PostgreSQL, Typescript, English CommunicationLĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠTiếng AnhSỐ NĂM KINH NGHIỆM TỐI THIỂU6QUỐC TỊCHKhông hiển thịXem thê'
#  'in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Kỹ Thuật Điện/Điện TửKỸ NĂNGKỹ Thuật Điện, PE, Tiếng Trung, Điện + Điện tử, Điện Tự Động HóaLĨNH VỰCĐiện/Điện tửNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  'in việc làmNGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > Data Engineer/Data Analyst/AIKỸ NĂNGICT Solutions, Programning Languages, Automation Software, Creative Thinking, AI, AILĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê']

# %%
#delete all after "Cấp bậc"
df['work_type'] = df['work_type'].apply(lambda x: x.split('Cấp bậc')[0])
df['work_type'] = df['work_type'].apply(lambda x: x.split('Yêu cầu khác')[0])
# delete blank
df['work_type'] = df['work_type'].apply(lambda x: x.strip())
#toàn thời gia -> toàn thời gian
# toàn thời gian -> giữ nguyên
df['work_type'] = df['work_type'].apply(lambda x: 'Toàn thời gian' if x == 'Toàn thời gia' else x)
df['work_type'] = df['work_type'].apply(lambda x: 'Bán thời gian' if x == 'Bán thời gia' else x)
df['work_type'] = df['work_type'].apply(lambda x: 'Thực tập' if x == 'Thực tậ' else x)

# %%
print(df['work_type'].unique())
# Out:
# ['NGÀY ĐĂNG15/05/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGThiết Kế Cơ Điện, Thiết Kế Hệ Thống, BIM, Điều Hòa Thông Gió, Cơ ĐiệnLĨNH VỰCKỹ thuật xây dựng/Cơ sở hạ tầngNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê'
#  'NGÀY ĐĂNG15/05/2025CẤP BẬCMới Tốt NghiệpNGÀNH NGHỀKhoa Học & Kỹ Thuật > Cơ Khí & Điện LạnhKỸ NĂNGAutocad, Mechanical Engineering, Quality Management, SolidWorks, MechanicalLĨNH VỰCÔ tôNGÔN NGỮ TRÌNH BÀY HỒ SƠTiếng AnhSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  'NGÀY ĐĂNG18/04/2025CẤP BẬCNhân viênNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > QA/QC/Software TestingKỸ NĂNGAutomation Testing, Java, Appium, Selenium, API TestingLĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  ...
#  'NGÀY ĐĂNG12/04/2025CẤP BẬCTrưởng phòngNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > Phần Mềm Máy TínhKỸ NĂNGNextjs, NestJS, PostgreSQL, Typescript, English CommunicationLĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠTiếng AnhSỐ NĂM KINH NGHIỆM TỐI THIỂU6QUỐC TỊCHKhông hiển thịXem thê'
#  'NGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀKhoa Học & Kỹ Thuật > Kỹ Thuật Điện/Điện TửKỸ NĂNGKỹ Thuật Điện, PE, Tiếng Trung, Điện + Điện tử, Điện Tự Động HóaLĨNH VỰCĐiện/Điện tửNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂUKhông yêu cầuQUỐC TỊCHKhông hiển thịXem thê'
#  'NGÀY ĐĂNG12/04/2025CẤP BẬCNhân viênNGÀNH NGHỀCông Nghệ Thông Tin/Viễn Thông > Data Engineer/Data Analyst/AIKỸ NĂNGICT Solutions, Programning Languages, Automation Software, Creative Thinking, AI, AILĨNH VỰCPhần Mềm CNTT/Dịch vụ Phần mềmNGÔN NGỮ TRÌNH BÀY HỒ SƠBất kỳSỐ NĂM KINH NGHIỆM TỐI THIỂU1QUỐC TỊCHKhông hiển thịXem thê']

# %%
df['other_info'].head()
# Out:
# 4    Thông tin chung\n    \n        \n    \n       ...
# 5    Thông tin chung\n    \n        \n    \n       ...
# 6    Thông tin chung\n    \n        \n    \n       ...
# 7    Thông tin chung\n    \n        \n    \n       ...
# 8    Thông tin chung\n    \n        \n    \n       ...
# Name: other_info, dtype: object

# %%
df['education'] = df['other_info']

# if \n -> ' ' -> ' ', then strip, lấy đoạn giữa "Học vấn" và "số lượng tuyển"
# if dont find "Học vấn" in other_info, return nan
def extract_education(text):
    if pd.isna(text):
        return np.nan
    text = re.sub(r'\n', ' ', text)  # replace newlines with space
    text = re.sub(r'\s+', ' ', text)  # replace multiple spaces with single space
    text = text.strip()  # remove leading and trailing spaces
    match = re.search(r'Học vấn\s*(.*?)\s*Số lượng tuyển', text)
    if match:
        return match.group(1).strip()
    else:
        return np.nan  # return NaN if "Học vấn" not found
    
# apply the function to education column
df['education'] = df['education'].apply(extract_education)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vthuy\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'other_info'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df['education'] = df['other_info']
#       3 # if \n -> ' ' -> ' ', then strip, lấy đoạn giữa "Học vấn" và "số lượng tuyển"
#       4 # if dont find "Học vấn" in other_info, return nan
#       5 def extract_education(text):
#
# File c:\Users\vthuy\miniconda3\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\vthuy\miniconda3\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'other_info'

# %%
df['education'].unique()
# Out:
# array(['Cao Đẳng trở lên', 'Đại Học trở lên', 'Trung cấp trở lên',
#        'Trung học phổ thông (Cấp 3) trở lên', 'Cao học trở lên',
#        'Trung học cơ sở (Cấp 2) trở lên'], dtype=object)

# %% [markdown]
# ## CỘT LOCATION

# %%
provinces = [
    "Hà Nội",
    "Vĩnh Phúc",
    "Bắc Ninh",
    "Quảng Ninh",
    "Hải Dương",
    "Hải Phòng",
    "Hưng Yên",
    "Thái Bình",
    "Hà Nam",
    "Nam Định",
    "Ninh Bình",
    "Hà Giang",
    "Cao Bằng",
    "Bắc Kạn",
    "Tuyên Quang",
    "Lào Cai",
    "Yên Bái",
    "Thái Nguyên",
    "Lạng Sơn",
    "Bắc Giang",
    "Phú Thọ",
    "Điện Biên",
    "Lai Châu",
    "Sơn La",
    "Hoà Bình",
    "Thanh Hoá",
    "Nghệ An",
    "Hà Tĩnh",
    "Quảng Bình",
    "Quảng Trị",
    "Thừa Thiên Huế",
    "Đà Nẵng",
    "Quảng Nam",
    "Quảng Ngãi",
    "Bình Định",
    "Phú Yên",
    "Khánh Hoà",
    "Ninh Thuận",
    "Bình Thuận",
    "Kon Tum",
    "Gia Lai",
    "Đắk Lắk",
    "Đắk Nông",
    "Lâm Đồng",
    "Bình Phước",
    "Tây Ninh",
    "Bình Dương",
    "Đồng Nai",
    "Bà Rịa - Vũng Tàu",
    "Hồ Chí Minh",
    "Long An",
    "Tiền Giang",
    "Bến Tre",
    "Trà Vinh",
    "Vĩnh Long",
    "Đồng Tháp",
    "An Giang",
    "Kiên Giang",
    "Cần Thơ",
    "Hậu Giang",
    "Sóc Trăng",
    "Bạc Liêu",
    "Cà Mau"
]

# In ra danh sách
for province in provinces:
    print(province)
# Out:
# Hà Nội
# Vĩnh Phúc
# Bắc Ninh
# Quảng Ninh
# Hải Dương
# Hải Phòng
# Hưng Yên
# Thái Bình
# Hà Nam
# Nam Định
# Ninh Bình
# Hà Giang
# Cao Bằng
# Bắc Kạn
# Tuyên Quang
# Lào Cai
# Yên Bái
# Thái Nguyên
# Lạng Sơn
# Bắc Giang
# Phú Thọ
# Điện Biên
# Lai Châu
# Sơn La
# Hoà Bình
# Thanh Hoá
# Nghệ An
# Hà Tĩnh
# Quảng Bình
# Quảng Trị
# Thừa Thiên Huế
# Đà Nẵng
# Quảng Nam
# Quảng Ngãi
# Bình Định
# Phú Yên
# Khánh Hoà
# Ninh Thuận
# Bình Thuận
# Kon Tum
# Gia Lai
# Đắk Lắk
# Đắk Nông
# Lâm Đồng
# Bình Phước
# Tây Ninh
# Bình Dương
# Đồng Nai
# Bà Rịa - Vũng Tàu
# Hồ Chí Minh
# Long An
# Tiền Giang
# Bến Tre
# Trà Vinh
# Vĩnh Long
# Đồng Tháp
# An Giang
# Kiên Giang
# Cần Thơ
# Hậu Giang
# Sóc Trăng
# Bạc Liêu
# Cà Mau

# %%
def process_location(text):
    # Loại bỏ '\n' và khoảng trắng thừa
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text

# %%
# Fill NaN values with an empty string
df['city_text'] = df['city_text'].fillna('')

# áp dụng vào cột Location
df['city_text'] = df['city_text'].apply(process_location)

# Kết quả
print(df['city_text'])
# Out:
# 4            Hà Nội
# 5            Hà Nội
# 6       Hồ Chí Minh
# 7       Hồ Chí Minh
# 8       Hồ Chí Minh
#            ...
# 2364         Hà Nội
# 2365         Hà Nội
# 2366         Hà Nội
# 2367         Hà Nội
# 2368         Hà Nội
# Name: city_text, Length: 2310, dtype: object

# %%
# Hàm tìm các tỉnh thành trong văn bản, các hàng có nhiều hơn 1 tỉnh, ngăn cách nhau bởi dấu ','
def find_provinces(text):
    # Tìm các tỉnh thành trong văn bản
    found_provinces = [province for province in provinces if province in text]
    
    # Nếu không tìm thấy thì trả về chuỗi rỗng
    if len(found_provinces) == 0:
        return ''
    
    # Nếu tìm thấy thì trả về chuỗi các tỉnh thành, ngăn cách nhau bởi dấu ','
    return ', '.join(found_provinces)

# Áp dụng hàm cho toàn bộ cột 'Location'
df['city_text'] = df['city_text'].apply(find_provinces)

# Kết quả
print(df['city_text'])
# Out:
# 4            Hà Nội
# 5            Hà Nội
# 6       Hồ Chí Minh
# 7       Hồ Chí Minh
# 8       Hồ Chí Minh
#            ...
# 2364         Hà Nội
# 2365         Hà Nội
# 2366         Hà Nội
# 2367         Hà Nội
# 2368         Hà Nội
# Name: city_text, Length: 2310, dtype: object

# %%
# print unique
print(df['city_text'].unique())
# Out:
# ['Hà Nội' 'Hồ Chí Minh' 'Hà Nội, Hồ Chí Minh' 'Thái Nguyên' 'Nghệ An'
#  'Hải Phòng' 'Long An' 'Đồng Nai' 'Đà Nẵng' 'Hà Nội, Hưng Yên' 'Khánh Hoà'
#  'Gia Lai' 'Hưng Yên' 'Thanh Hoá' 'Hải Dương' 'Bình Dương'
#  'Hà Nội, Nghệ An' 'Thừa Thiên Huế' 'Hồ Chí Minh, Long An'
#  'Hà Nội, Vĩnh Phúc' 'Vĩnh Phúc' 'Bình Định' 'Hà Nội, Đà Nẵng'
#  'Quảng Ninh, Thanh Hoá' 'Hà Nội, Hải Phòng' 'Hà Nam' 'Bắc Ninh'
#  'Đà Nẵng, Hồ Chí Minh' 'Lâm Đồng' 'Bắc Giang' 'Ninh Bình' 'Cần Thơ'
#  'Nghệ An, Đà Nẵng' 'Phú Yên' '' 'Đồng Tháp' 'Bình Dương, Hồ Chí Minh']

# %%
# count print if null
print("Number of rows with null city_text:", df['city_text'].isnull().sum())
# Out:
# Number of rows with null city_text: 0

# %% [markdown]
# # PREPROCESS - XỬ LÝ CỘT DỮ LIỆU ĐẶC BIỆT
# - Lương
# - Kinh nghiệm

# %% [markdown]
# ## Salary

# %%
# print unique salary
print(df['title_salary'].unique())
# Out:
# ['10 - 18 triệu' '10 - 20 triệu' '12 - 15 triệu' '12 - 18 triệu'
#  '13 - 23 triệu' '15 - 20 triệu' '18 - 22 triệu' '20 - 27 triệu'
#  '20 - 40 triệu' '20 - 50 triệu' '25 - 35 triệu' '25 - 50 triệu'
#  '35 - 40 triệu' '4 - 6 triệu' '5 - 6 triệu' '8 - 12 triệu' '8 - 15 triệu'
#  '800 - 3,500 USD' 'Tới 1,500 USD' 'Tới 2 triệu' 'Tới 20 triệu'
#  'Tới 3 triệu' 'Tới 6,000 USD' 'Từ 1,200 USD' '20 - 35 triệu'
#  'Tới 25 triệu' 'Tới 35 triệu' '8 - 16 triệu' 'Tới 26 triệu'
#  '15 - 18 triệu' '28 - 33 triệu' '30 - 45 triệu' 'Tới 40 triệu'
#  '12 - 25 triệu' '35 - 55 triệu' '2,000 - 3,000 USD' '12 - 19 triệu'
#  '15 - 25 triệu' '18 - 25 triệu' 'Tới 30 triệu' 'Tới 60 triệu'
#  '13 - 15 triệu' 'Tới 1,000 USD' 'Tới 700 USD' '12 - 35 triệu'
#  '8 - 30 triệu' '9 - 15 triệu' 'Tới 50 triệu' '23 - 32 triệu'
#  '6.9 - 7.3 triệu' 'Từ 16 triệu' 'Từ 50 triệu' '14 - 17 triệu'
#  '12 - 20 triệu' '16 - 18 triệu' '9 - 11 triệu' '17 - 50 triệu'
#  '30 - 46 triệu' '8 - 10 triệu' '3 - 5 triệu' '9 - 14 triệu'
#  '15 - 50 triệu' '25 - 40 triệu' '15 - 30 triệu' '10 - 15 triệu'
#  '14 - 20 triệu' '30 - 60 triệu' '9 - 18 triệu' '12 - 16 triệu'
#  '20 - 30 triệu' 'Từ 2 triệu' '35 - 50 triệu' 'Tới 27 triệu'
#  '7 - 10 triệu' '7 - 8 triệu' '50 - 70 triệu' '10 - 12 triệu'
#  '10 - 14 triệu' '11 - 16 triệu' '13 - 18 triệu' '1.5 - 2 triệu'
#  '6 - 8 triệu' '25 - 27 triệu' 'Từ 5 triệu' '2 - 4 triệu' '7 - 12 triệu'
#  '14 - 15 triệu' '10 - 13 triệu' '15 - 35 triệu' '25 - 30 triệu'
#  '28 - 32 triệu' 'Tới 45 triệu' '14 - 25 triệu' 'Từ 30 triệu'
#  '18 - 30 triệu' '16 - 30 triệu' '17 - 21 triệu' '17 - 24 triệu'
#  '17 - 26 triệu' '17 - 40 triệu' '18 - 40 triệu' '20 - 25 triệu'
#  '20 - 28 triệu' '22 - 25.5 triệu' '25 - 28 triệu' '25 - 32 triệu'
#  '25 - 36 triệu' '25 - 46 triệu' '28 - 40 triệu' '30 - 36 triệu'
#  '30 - 40 triệu' '30 - 42 triệu' '40 - 60 triệu' 'Tới 24 triệu'
#  'Tới 25.5 triệu' 'Tới 28 triệu' 'Tới 36 triệu' 'Tới 39 triệu'
#  'Tới 40.5 triệu' '30 - 55 triệu' '800 - 1,200 USD' '35 - 70 triệu'
#  '3 - 8 triệu' '10 - 25 triệu' '500 - 850 USD' '22 - 32 triệu'
#  'Tới 80 triệu' '1 - 10 triệu' '30 - 50 triệu' '40 - 65 triệu'
#  '50 - 100 triệu' '10 - 30 triệu' '8 - 50 triệu' 'Tới 34 triệu'
#  '16 - 23 triệu' '5 - 10 triệu' '28 - 35 triệu' '15 - 22 triệu'
#  '17 - 30 triệu' '9 - 13 triệu' '12 - 30 triệu' '16 - 25 triệu'
#  '18 - 23 triệu' '18 - 28 triệu' '20 - 26 triệu' 'Tới 18 triệu'
#  'Tới 22 triệu' '11 - 13 triệu' '28 - 30 triệu' '12 - 17 triệu'
#  '8.5 - 15 triệu' '7 - 25 triệu' '8 - 20 triệu' '17 - 25 triệu'
#  '30 - 35 triệu' '25 - 45 triệu' '40 - 45 triệu' '12 - 14 triệu'
#  'Từ 9 triệu' '2 - 6 triệu' '4 - 8 triệu' '40 - 50 triệu' '15 - 23 triệu'
#  'Tới 17 triệu' 'Từ 20 triệu' '5 - 8 triệu' '8 - 18 triệu' '15 - 17 triệu'
#  '6 - 12 triệu' '1,000 - 1,600 USD' '1 - 3 triệu' '22 - 38 triệu'
#  '2 - 5 triệu' '40 - 55 triệu' 'Tới 55 triệu' '9 - 10 triệu' '3 - 4 triệu'
#  'Tới 2,000 USD' 'Từ 2.5 triệu' '15 - 27 triệu' '7 - 30 triệu'
#  '9 - 12 triệu' '1 - 7 triệu' '11 - 15 triệu' '6 - 7 triệu' '7 - 16 triệu'
#  '22 - 27 triệu' 'Tới 15 triệu' '13 - 20 triệu' '15 - 40 triệu'
#  '14 - 16 triệu' '23 - 30 triệu' '1 - 1.5 triệu' '10 - 17 triệu'
#  '50 - 60 triệu' '24 - 25 triệu' '3 - 10 triệu' 'Tới 12 triệu'
#  '6 - 10 triệu' '45 - 70 triệu' '10 - 16 triệu' '16 - 22 triệu'
#  '18 - 26 triệu' '11 - 18 triệu' '7 - 15 triệu' '9 - 20 triệu'
#  '16 - 20 triệu' '1,000 - 3,000 USD' '1,000 - 4,000 USD' '13 - 17 triệu'
#  '13 - 25 triệu' '800 - 1,000 USD' '1,000 - 1,500 USD' '20 - 22 triệu'
#  '30 - 34 triệu' '32 - 37 triệu' 'Từ 15 triệu' '7 - 18 triệu'
#  '7 - 20 triệu' '13 - 16 triệu' '2 - 3 triệu' 'Tới 4,000 USD'
#  '8 - 9 triệu' '18 - 35 triệu' '1,900 - 2,500 USD' '8 - 11 triệu'
#  'Từ 1 triệu' '8.1 - 15 triệu' 'Tới 65 triệu' '20 - 45 triệu'
#  '1,500 - 3,000 USD' '700 - 800 USD' 'Tới 4.8 triệu' '16 - 24 triệu'
#  '10 - 11 triệu' '9.5 - 10 triệu' 'Tới 31 triệu' '15 - 28 triệu'
#  'Tới 5 triệu' '30 - 38 triệu' '25 - 33 triệu' '700 - 1,000 USD'
#  '500 - 1,500 USD' '18 - 20 triệu' '4 - 20 triệu' 'Tới 37 triệu'
#  '16 - 32 triệu' '17 - 32 triệu' '18 - 32 triệu' '500 - 2,000 USD'
#  '1,000 - 2,500 USD' '8 - 25 triệu' '8.5 - 13 triệu' '500 - 1,000 USD'
#  'Tới 9 triệu' '6.5 - 12 triệu' '18 - 27 triệu' '7.5 - 10 triệu'
#  'Tới 16 triệu' '1,500 - 2,000 USD' '8 - 14 triệu' '2.5 - 3 triệu'
#  '14 - 18 triệu' 'Từ 1.5 triệu' '11 - 14 triệu' '7 - 9 triệu'
#  '20 - 23 triệu' '1,500 - 2,200 USD' '16 - 40 triệu' 'Tới 1,800 USD'
#  '0.8 - 10 triệu' '4 - 10 triệu' '8 - 8.5 triệu' '5 - 25 triệu'
#  '400 - 600 USD' '600 - 1,000 USD' 'Tới 800 USD' '20 - 31 triệu'
#  '30 - 70 triệu' '8.5 - 10 triệu' '10 - 40 triệu' '2,000 - 4,000 USD'
#  '3.5 - 6 triệu' '3,500 - 4,000 USD' 'Tới 42 triệu' 'Tới 10 triệu'
#  '75 - 100 triệu' 'Từ 60 triệu' '7 - 11 triệu' '40 - 70 triệu'
#  '0.5 - 1 triệu' '1,200 - 2,000 USD' 'Từ 3 triệu' '27 - 45 triệu'
#  'Từ 8 triệu' '19 - 24 triệu' '22 - 28 triệu' '45 - 60 triệu'
#  'Tới 2,500 USD' '12 - 50 triệu' 'Tới 0.5 triệu' '3 - 7 triệu'
#  '60 - 65 triệu' '50 - 65 triệu' '2,500 - 4,000 USD' '12 - 13 triệu'
#  '22 - 45 triệu' '8 - 13 triệu' '1 - 15 triệu' '11 - 30 triệu'
#  '5 - 15 triệu' '5 - 7 triệu' '7 - 7.5 triệu' '30 - 80 triệu' 'Từ 7 triệu'
#  'Tới 14 triệu' '19 - 20 triệu' '9.4 - 11 triệu' '15 - 22.0 triệu'
#  '35 - 45 triệu' '500 - 900 USD' '40 - 42 triệu' '4 - 5 triệu'
#  '23 - 35 triệu' 'Tới 33 triệu' 'Tới 45.7 triệu' '12 - 22 triệu'
#  '10 - 35 triệu' '3 - 3.5 triệu' '30 - 48 triệu' 'Từ 5.7 triệu'
#  '40 - 80 triệu' '4.2 - 6.9 triệu' '1,000 - 1,300 USD' '1,200 - 1,500 USD'
#  '10 - 50 triệu' '20 - 60 triệu' '60 - 100 triệu' '3,000 - 4,000 USD'
#  '1,000 - 2,000 USD' 'Tới 57 triệu' '16 - 28 triệu' '7 - 40 triệu'
#  'Từ 25 triệu' '40 - 43 triệu' 'Từ 0.0 triệu' 'Từ 1,000 USD'
#  '1,200 - 2,500 USD' '23 - 38 triệu' '2.3 - 2.5 triệu' '1,000 - 1,700 USD'
#  '1,200 - 1,600 USD' '1.5 - 3 triệu' 'Tới 1,200 USD' 'Tới 2,400 USD'
#  '2.5 - 5 triệu' '24 - 34 triệu' 'Từ 10 triệu' '10 - 32 triệu'
#  '12 - 24 triệu' '6.5 - 24 triệu' '8 - 24 triệu' '8 - 26 triệu'
#  '8.5 - 25 triệu' 'Từ 4 triệu' 'Tới 7 triệu' '6.4 - 25 triệu'
#  '8 - 32 triệu' '6 - 28 triệu' '1,200 - 1,800 USD' '45 - 55 triệu'
#  '16 - 19 triệu' '17 - 20 triệu' 'Tới 3,000 USD' 'Tới 55,000 USD'
#  '900 - 2,000 USD' 'Tới 14,000 USD' '32 - 50 triệu' '7 - 14 triệu'
#  '700 - 1,500 USD' '11 - 12 triệu' '1,000 - 5,000 USD' '1,800 - 2,500 USD'
#  '15 - 33 triệu' '22.5 - 37 triệu' '23 - 31 triệu' '4 - 7 triệu'
#  '21 - 35 triệu' '22 - 40 triệu' '1,500 - 3,300 USD' '12 - 45 triệu'
#  '35 - 60 triệu' '15 - 55 triệu' '700 - 1,200 USD' '700 - 5,000 USD'
#  '600 - 5,000 USD' '1,100 - 1,800 USD' '11 - 25 triệu' '6.5 - 7 triệu'
#  '9 - 40 triệu' '22 - 30 triệu']

# %%
# in title_salary, delete all after  Số lượng tuyển 
df['title_salary'] = df['title_salary'].apply(lambda x: x.split('Số lượng tuyển')[0] if 'Số lượng tuyển' in x else x)
# in title_salary, delete all before Thu nhập
df['title_salary'] = df['title_salary'].apply(lambda x: x.split('Thu nhập')[1] if 'Thu nhập' in x else x)
# delete blank
df['title_salary'] = df['title_salary'].apply(lambda x: x.strip())

# %%
# Hàm xử lý dữ liệu lương
def process_salary(text):
    # Loại bỏ khoảng trắng thừa
    text = text.strip()
    min_salary = max_salary = None

    # Nếu tìm thấy 'USD' thì nhân với 25485
    if 'USD' in text:
        salary_text = text.replace('USD', '').replace('usd', '').strip()
        # Xử lý trường hợp khoảng hoặc dấu gạch ngang
        if '-' in salary_text:
            parts = salary_text.split('-')
        elif '–' in salary_text:
            parts = salary_text.split('–')
        else:
            parts = [salary_text]
        parts = [p.replace('.', '').replace(',', '').strip() for p in parts]
        try:
            if len(parts) == 2:
                min_salary = int(float(parts[0])) * 25485
                max_salary = int(float(parts[1])) * 25485
            else:
                min_salary = max_salary = int(float(parts[0])) * 25485
        except Exception:
            min_salary = max_salary = None
    else:
        # Xử lý trường hợp triệu, tr, hoặc chỉ số
        salary_text = text.replace('triệu', '').replace('tr', '').strip()
        if '-' in salary_text:
            parts = salary_text.split('-')
        elif '–' in salary_text:
            parts = salary_text.split('–')
        else:
            parts = [salary_text]
        parts = [p.replace('.', '').replace(',', '').strip() for p in parts]
        try:
            if len(parts) == 2:
                min_salary = int(float(parts[0])) * 1000000
                max_salary = int(float(parts[1])) * 1000000
            else:
                min_salary = max_salary = int(float(parts[0])) * 1000000
        except Exception:
            min_salary = max_salary = None
    return min_salary, max_salary

# Áp dụng hàm cho toàn bộ cột 'title_salary'
df['min_salary'], df['max_salary'] = zip(*df['title_salary'].apply(process_salary))

# In kết quả
print(df[['min_salary', 'max_salary']])
# Out:
#       min_salary  max_salary
# 4     10000000.0  18000000.0
# 5     10000000.0  18000000.0
# 6     10000000.0  18000000.0
# 7     10000000.0  18000000.0
# 8     10000000.0  20000000.0
# ...          ...         ...
# 2364  18000000.0  35000000.0
# 2365  18000000.0  35000000.0
# 2366  22000000.0  30000000.0
# 2367   8000000.0  15000000.0
# 2368   8000000.0  16000000.0
#
# [2310 rows x 2 columns]

# %%
# in type của min_salary và max_salary
print(df['min_salary'].dtype)
# Out:
# float64

# %%
# if max_salary > 100000000, print min_salary, max_salary, title_salary
df.loc[df['max_salary'] > 100000000, ['min_salary', 'max_salary', 'title_salary']]
# Out:
#       min_salary   max_salary       title_salary
# 265   22000000.0  255000000.0    22 - 25.5 triệu
# 757   25485000.0  101940000.0  1,000 - 4,000 USD
# 1344  50970000.0  101940000.0  2,000 - 4,000 USD
# 1351  89197500.0  101940000.0  3,500 - 4,000 USD
# 1438  50970000.0  101940000.0  2,000 - 4,000 USD
# 1439  50970000.0  101940000.0  2,000 - 4,000 USD
# 1514  63712500.0  101940000.0  2,500 - 4,000 USD
# 1585  15000000.0  220000000.0    15 - 22.0 triệu
# 1656  63712500.0  101940000.0  2,500 - 4,000 USD
# 1787  76455000.0  101940000.0  3,000 - 4,000 USD
# 2241  25485000.0  127425000.0  1,000 - 5,000 USD
# 2324  17839500.0  127425000.0    700 - 5,000 USD
# 2325  15291000.0  127425000.0    600 - 5,000 USD
# 2326  15291000.0  127425000.0    600 - 5,000 USD

# %%
# if title_salary have '.', print min_salary, max_salary
df.loc[df['title_salary'].str.contains(r'\.'), ['min_salary', 'max_salary', 'title_salary']]
# Out:
#        min_salary   max_salary     title_salary
# 137    69000000.0   73000000.0  6.9 - 7.3 triệu
# 138    69000000.0   73000000.0  6.9 - 7.3 triệu
# 214    15000000.0    2000000.0    1.5 - 2 triệu
# 265    22000000.0  255000000.0  22 - 25.5 triệu
# 295           NaN          NaN   Tới 25.5 triệu
# 299           NaN          NaN   Tới 40.5 triệu
# 426    85000000.0   15000000.0   8.5 - 15 triệu
# 550           NaN          NaN     Từ 2.5 triệu
# 659     1000000.0   15000000.0    1 - 1.5 triệu
# 863    81000000.0   15000000.0   8.1 - 15 triệu
# 904           NaN          NaN    Tới 4.8 triệu
# 905           NaN          NaN    Tới 4.8 triệu
# 906           NaN          NaN    Tới 4.8 triệu
# 907           NaN          NaN    Tới 4.8 triệu
# 921    95000000.0   10000000.0   9.5 - 10 triệu
# 1057   85000000.0   13000000.0   8.5 - 13 triệu
# 1097   65000000.0   12000000.0   6.5 - 12 triệu
# 1098   65000000.0   12000000.0   6.5 - 12 triệu
# 1110   75000000.0   10000000.0   7.5 - 10 triệu
# 1156   25000000.0    3000000.0    2.5 - 3 triệu
# 1166          NaN          NaN     Từ 1.5 triệu
# 1231    8000000.0   10000000.0   0.8 - 10 triệu
# 1244    8000000.0   85000000.0    8 - 8.5 triệu
# 1322   85000000.0   10000000.0   8.5 - 10 triệu
# 1349   35000000.0    6000000.0    3.5 - 6 triệu
# 1383    5000000.0    1000000.0    0.5 - 1 triệu
# 1464          NaN          NaN    Tới 0.5 triệu
# 1551    7000000.0   75000000.0    7 - 7.5 triệu
# 1582   94000000.0   11000000.0   9.4 - 11 triệu
# 1585   15000000.0  220000000.0  15 - 22.0 triệu
# 1638          NaN          NaN   Tới 45.7 triệu
# 1663    3000000.0   35000000.0    3 - 3.5 triệu
# 1697          NaN          NaN     Từ 5.7 triệu
# 1703   42000000.0   69000000.0  4.2 - 6.9 triệu
# 1908          NaN          NaN     Từ 0.0 triệu
# 1941   23000000.0   25000000.0  2.3 - 2.5 triệu
# 1966   15000000.0    3000000.0    1.5 - 3 triệu
# 1999   25000000.0    5000000.0    2.5 - 5 triệu
# 2047   65000000.0   24000000.0   6.5 - 24 triệu
# 2059   85000000.0   25000000.0   8.5 - 25 triệu
# 2078   64000000.0   25000000.0   6.4 - 25 triệu
# 2145   15000000.0    2000000.0    1.5 - 2 triệu
# 2232   25000000.0    3000000.0    2.5 - 3 triệu
# 2254  225000000.0   37000000.0  22.5 - 37 triệu
# 2340   25000000.0    5000000.0    2.5 - 5 triệu
# 2357   65000000.0    7000000.0    6.5 - 7 triệu

# %%
# tính average_salary, (min + max) / 2
df['average_salary'] = (df['min_salary'] + df['max_salary']) / 2

# %%
# sort average_salary from min to max
df = df.sort_values(by='average_salary')
df.tail(10)
# Out:
#                                                   title  \
# 2329                   Automation Test (Java, Selenium)
# 2331                                        Data Tester
# 2332                                       Senior IT BA
# 2333                                          DevSecOps
# 2337  Chuyên Viên Phát Triển Hệ Thống Giáo Dục Số Ed...
# 2338  Chuyên Viên Lập Trình (Nghỉ Thứ 7 - Chủ Nhật, ...
# 2346                             Cộng Tác Viên Thiết Kế
# 2352                           Presale Network Engineer
# 2358                                    IT Communicator
# 2360                                     2D Game Artist
#
#                                            company_name  title_salary  \
# 2329                           Tp&p Technology Co. Ltd.  Tới 35 triệu
# 2331                           Tp&p Technology Co. Ltd.  Tới 30 triệu
# 2332                           Tp&p Technology Co. Ltd.  Tới 40 triệu
# 2333                           Tp&p Technology Co. Ltd.  Tới 40 triệu
# 2337  Trung Tâm Dịch Vụ Số Mobifone - Chi Nhánh Tổng...  Tới 20 triệu
# 2338  Trung Tâm Dịch Vụ Số Mobifone - Chi Nhánh Tổng...  Tới 20 triệu
# 2346                            Trường Đại Học Văn Lang   Tới 7 triệu
# 2352      Vdi - Công Ty Cổ Phần Đầu Tư Kỹ Thuật Số Việt  Tới 30 triệu
# 2358                                           Wanosoft  Tới 35 triệu
# 2360                                       Wayfu Studio  Tới 18 triệu
#
#         city_text         exp                             item_tag  \
# 2329       Hà Nội       2 năm                    Automation Tester
# 2331       Hà Nội       2 năm                        Manual Tester
# 2332       Hà Nội       3 năm  Chuyên môn Công nghệ thông tin khác
# 2333       Hà Nội       3 năm                      DevOps Engineer
# 2337       Hà Nội       1 năm  Chuyên môn Công nghệ thông tin khác
# 2338       Hà Nội       1 năm                  Fullstack Developer
# 2346  Hồ Chí Minh  Dưới 1 năm     Thiết kế đồ họa (Graphic Design)
# 2352  Hồ Chí Minh       2 năm                     Network Engineer
# 2358       Hà Nội       4 năm                            IT Comtor
# 2360       Hà Nội       1 năm     Thiết kế đồ họa (Graphic Design)
#
#                                            company_info  \
# 2329  TP&P Technology Co. Ltd.\n                \n  ...
# 2331  TP&P Technology Co. Ltd.\n                \n  ...
# 2332  TP&P Technology Co. Ltd.\n                \n  ...
# 2333  TP&P Technology Co. Ltd.\n                \n  ...
# 2337  Trung tâm Dịch vụ số MobiFone - Chi nhánh Tổng...
# 2338  Trung tâm Dịch vụ số MobiFone - Chi nhánh Tổng...
# 2346  Trường Đại học Văn Lang\n                \n   ...
# 2352  VDI - Công ty Cổ phần Đầu tư Kỹ thuật số Việt\...
# 2358  WanoSoft\n                \n                  ...
# 2360  WAYFU STUDIO\n                \n              ...
#
#                                                 job_des  \
# 2329  Mô tả công việc\n                    \n       ...
# 2331  Mô tả công việc\n                    \n       ...
# 2332  Mô tả công việc\n                    \n       ...
# 2333  Mô tả công việc\n                    \n       ...
# 2337  Mô tả công việc\n                    \n       ...
# 2338  Mô tả công việc\n                    \n       ...
# 2346  Mô tả công việc\n                    \n       ...
# 2352  Mô tả công việc\n                    \n       ...
# 2358  Mô tả công việc\n                    \n       ...
# 2360  Mô tả công việc\n                    \n       ...
#
#                                             job_require  \
# 2329  Yêu cầu ứng viên\n                    \n      ...
# 2331  Yêu cầu ứng viên\n                    \n      ...
# 2332  Yêu cầu ứng viên\n                    \n      ...
# 2333  Yêu cầu ứng viên\n                    \n      ...
# 2337  Yêu cầu ứng viên\n                    \n      ...
# 2338  Yêu cầu ứng viên\n                    \n      ...
# 2346  Yêu cầu ứng viên\n                    \n      ...
# 2352  Yêu cầu ứng viên\n                    \n      ...
# 2358  Yêu cầu ứng viên\n                    \n      ...
# 2360  Yêu cầu ứng viên\n                    \n      ...
#
#                                              other_info company_scale  \
# 2329  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2331  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2332  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2333  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2337  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2338  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2346  Thông tin chung\n    \n        \n    \n       ...   1000 - 2999
# 2352  Thông tin chung\n    \n        \n    \n       ...       100-499
# 2358  Thông tin chung\n    \n        \n    \n       ...         10-24
# 2360  Thông tin chung\n    \n        \n    \n       ...         25-99
#
#            company_field   position       work_type        education  \
# 2329       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2331       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2332       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2333       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2337       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2338       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2346  Giáo dục / Đào tạo  Nhân viên        Thực tập  Đại Học trở lên
# 2352       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2358       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
# 2360       IT - Phần mềm  Nhân viên  Toàn thời gian  Đại Học trở lên
#
#       min_salary  max_salary  average_salary
# 2329         NaN         NaN             NaN
# 2331         NaN         NaN             NaN
# 2332         NaN         NaN             NaN
# 2333         NaN         NaN             NaN
# 2337         NaN         NaN             NaN
# 2338         NaN         NaN             NaN
# 2346         NaN         NaN             NaN
# 2352         NaN         NaN             NaN
# 2358         NaN         NaN             NaN
# 2360         NaN         NaN             NaN

# %%
# print 10 dòng đầu tiên của 3 cột mới
print(df[['min_salary', 'max_salary', 'average_salary']].head(10))
# Out:
#       min_salary  max_salary  average_salary
# 1720   1000000.0   3000000.0       2000000.0
# 509    1000000.0   3000000.0       2000000.0
# 2094   2000000.0   3000000.0       2500000.0
# 819    2000000.0   3000000.0       2500000.0
# 1383   5000000.0   1000000.0       3000000.0
# 2281   2000000.0   4000000.0       3000000.0
# 2123   2000000.0   4000000.0       3000000.0
# 224    2000000.0   4000000.0       3000000.0
# 2280   2000000.0   4000000.0       3000000.0
# 2282   2000000.0   4000000.0       3000000.0

# %%
# if find "Trên" or "Tới" in title_salary, set min_salary = max_salary = average_salary = this number

def process_salary2(text):
    # Loại bỏ khoảng trắng thừa
    text = text.strip()
    
    # Nếu không tìm thấy 'Trên' hoặc 'Tới' thì trả về NaN
    if 'Trên' not in text and 'Tới' not in text:
        return np.nan, np.nan, np.nan
    
    # Loại bỏ các ký tự không phải là số
    number = re.sub(r'\D', '', text)
    
    # Kiểm tra nếu number rỗng
    if not number:
        return np.nan, np.nan, np.nan
    
    # Chuyển đổi thành số nguyên
    number = int(number)
    
    # Nếu tìm thấy 'triệu' hoặc 'tr' thì nhân với 1000000
    if any(unit in text.lower() for unit in ['triệu', 'tr']):
        number *= 1000000
    
    # Nếu tìm thấy 'USD' thì nhân với 25485
    elif 'USD' in text.upper():
        number *= 25485
    
    return number, number, number

# Áp dụng hàm cho các hàng đang bị NaN. nếu không thì bỏ qua
mask = df['min_salary'].isnull()
salary_df = df.loc[mask, 'title_salary'].apply(process_salary2).apply(pd.Series)
salary_df.columns = ['min_salary', 'max_salary', 'average_salary']
df.loc[mask, ['min_salary', 'max_salary', 'average_salary']] = salary_df.values

# %%
# xóa dấu cách thừa trong title_salary
df['title_salary'] = df['title_salary'].apply(lambda x: re.sub(r'\s+', ' ', x))
# if min_salary = Nan, print unique title_salary
print(df[df['min_salary'].isnull()]['title_salary'].unique())
# Out:
# ['Từ 1,200 USD' 'Từ 16 triệu' 'Từ 50 triệu' 'Từ 2 triệu' 'Từ 5 triệu'
#  'Từ 30 triệu' 'Từ 9 triệu' 'Từ 20 triệu' 'Từ 2.5 triệu' 'Từ 15 triệu'
#  'Từ 1 triệu' 'Từ 1.5 triệu' 'Từ 60 triệu' 'Từ 3 triệu' 'Từ 8 triệu'
#  'Từ 7 triệu' 'Từ 5.7 triệu' 'Từ 25 triệu' 'Từ 0.0 triệu' 'Từ 1,000 USD'
#  'Từ 10 triệu' 'Từ 4 triệu']

# %%
# print min_salary, max_salary, average_salary
print(df[['min_salary', 'max_salary', 'average_salary']].head(100))
# Out:
#       min_salary  max_salary  average_salary
# 1720   1000000.0   3000000.0       2000000.0
# 509    1000000.0   3000000.0       2000000.0
# 2094   2000000.0   3000000.0       2500000.0
# 819    2000000.0   3000000.0       2500000.0
# 1383   5000000.0   1000000.0       3000000.0
# ...          ...         ...             ...
# 2132   7000000.0  10000000.0       8500000.0
# 1026   7000000.0  10000000.0       8500000.0
# 749    7000000.0  10000000.0       8500000.0
# 2183   7000000.0  10000000.0       8500000.0
# 2012   8000000.0   9000000.0       8500000.0
#
# [100 rows x 3 columns]

# %%
#print null min_salary
print(df['min_salary'].isnull().sum())
# Out:
# 42

# %% [markdown]
# ## Experience

# %%
# duplicate cột exp -> exp_pro
df['exp_pro'] = df['exp']

# chỉ lấy số trong cột exp
def extract_experience(text):
    if pd.isna(text):
        return np.nan
    # Chuyển đổi sang chuỗi để tránh lỗi TypeError
    text = str(text)
    # Tìm kiếm các số trong chuỗi
    numbers = re.findall(r'\d+', text)
    if numbers:
        return int(numbers[0])  # Trả về số đầu tiên tìm thấy
    else:
        return np.nan  # Trả về NaN nếu không tìm thấy số

# Áp dụng hàm cho cột 'exp'
df['exp'] = df['exp'].apply(extract_experience)
# Out:
# [nan  1.  2.  3.  5.  4.]

# %%
# if exp = nan fill = 0
df['exp'] = df['exp'].fillna(0)
print(df['exp'].unique())
# Out:
# [0. 1. 2. 3. 5. 4.]

# %%
#print null experience
print(df['exp'].isnull().sum())
# Out:
# 0

# %% [markdown]
# # PREPROCESS - MISSING VALUES

# %% [markdown]
# ### Kiểm tra dữ liệu sau khi thêm cột

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1979 entries, 1720 to 265
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1976 non-null   object
#  1   company_name    1979 non-null   object
#  2   title_salary    1979 non-null   object
#  3   city_text       1979 non-null   object
#  4   exp             1979 non-null   float64
#  5   item_tag        1978 non-null   object
#  6   company_info    1979 non-null   object
#  7   job_des         1979 non-null   object
#  8   job_require     1979 non-null   object
#  9   other_info      1979 non-null   object
#  10  company_scale   1979 non-null   object
#  11  company_field   1979 non-null   object
#  12  position        1979 non-null   object
#  13  work_type       1979 non-null   object
#  14  education       1979 non-null   object
#  15  min_salary      1979 non-null   float64
#  16  max_salary      1979 non-null   float64
#  17  average_salary  1979 non-null   float64
#  18  exp_pro         1979 non-null   object
# dtypes: float64(4), object(15)
# memory usage: 309.2+ KB
# None
#                exp    min_salary    max_salary  average_salary
# count  1979.000000  1.979000e+03  1.979000e+03    1.979000e+03
# mean      1.769075  1.601289e+07  2.547210e+07    2.074250e+07
# std       1.194753  1.146908e+07  1.720006e+07    1.277675e+07
# min       0.000000  1.000000e+06  1.000000e+06    2.000000e+06
# 25%       1.000000  1.000000e+07  1.500000e+07    1.250000e+07
# 50%       2.000000  1.300000e+07  2.000000e+07    1.750000e+07
# 75%       2.000000  2.000000e+07  3.000000e+07    2.500000e+07
# max       5.000000  2.250000e+08  2.550000e+08    1.385000e+08
# title             3
# company_name      0
# title_salary      0
# city_text         0
# exp               0
# item_tag          1
# company_info      0
# job_des           0
# job_require       0
# other_info        0
# company_scale     0
# company_field     0
# position          0
# work_type         0
# education         0
# min_salary        0
# max_salary        0
# average_salary    0
# exp_pro           0
# dtype: int64

# %%
# Xóa các cột không cần thiết
df = df.drop(columns=['jobdetail', 'jobtitle', 'general_info', 'raw_salary', 'raw_experience', 'Unnamed: 0'])

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2233 entries, 4314 to 3427
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jobname         2233 non-null   object
#  1   companyscale    2233 non-null   object
#  2   company_field   2233 non-null   object
#  3   company_name    2233 non-null   object
#  4   skill_offer1    2233 non-null   object
#  5   skill_offer2    2233 non-null   object
#  6   skill_offer3    2233 non-null   object
#  7   skill_offer4    2233 non-null   object
#  8   Location        2233 non-null   object
#  9   position        2233 non-null   object
#  10  work_type       2233 non-null   object
#  11  min_salary      2233 non-null   float64
#  12  max_salary      2233 non-null   float64
#  13  average_salary  2233 non-null   float64
#  14  experience      2233 non-null   int64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 279.1+ KB
# None
#          min_salary    max_salary  average_salary   experience
# count  2.233000e+03  2.233000e+03    2.233000e+03  2233.000000
# mean   1.537382e+07  2.510725e+07    2.024053e+07     1.749216
# std    1.262084e+07  1.847066e+07    1.450069e+07     1.224299
# min    0.000000e+00  0.000000e+00    0.000000e+00     0.000000
# 25%    9.000000e+06  1.500000e+07    1.200000e+07     1.000000
# 50%    1.200000e+07  2.000000e+07    1.750000e+07     2.000000
# 75%    1.800000e+07  3.000000e+07    2.500000e+07     2.000000
# max    1.850000e+08  2.760000e+08    2.300000e+08     5.000000
# jobname           0
# companyscale      0
# company_field     0
# company_name      0
# skill_offer1      0
# skill_offer2      0
# skill_offer3      0
# skill_offer4      0
# Location          0
# position          0
# work_type         0
# min_salary        0
# max_salary        0
# average_salary    0
# experience        0
# dtype: int64

# %%
#Với mỗi cột, đếm xem có bao nhiêu giá trị ''
print((df == '').sum())
# Out:
# jobname             0
# companyscale        7
# company_field       0
# company_name        0
# skill_offer1      539
# skill_offer2      616
# skill_offer3      729
# skill_offer4      865
# Location           51
# position            0
# work_type          19
# min_salary          0
# max_salary          0
# average_salary      0
# experience          0
# dtype: int64

# %%
#delete all row have '' in company_scale, Location, work_type
df = df[df['companyscale'] != '']
df = df[df['Location'] != '']
df = df[df['work_type'] != '']
#detêt all row if min_salary = null
df = df[df['min_salary'].notnull()]

# %%
#print last 5 rows
print(df.tail())
# Out:
#                                     jobname companyscale  company_field  \
# 3161                            AI Engineer        25-99  It - Phần Mềm
# 3652                      Software Engineer        25-99  It - Phần Mềm
# 4164  Software Tester (Automation & Manual)        25-99  It - Phần Mềm
# 4146                          Manual Tester      100-499  It - Phần Mềm
# 3427                    Fullstack Developer      100-499  It - Phần Mềm
#
#                           company_name       skill_offer1  \
# 3161  Công Ty Tnhh Công Nghệ Blue Belt   Machine Learning
# 3652           Công Ty Tnhh Otani U.p.             Python
# 4164           Công Ty Tnhh Otani U.p.             Tester
# 4146        Công Ty Cổ Phần Its Global             Tester
# 3427        Cty Tnhh R Techno Việt Nam  Phân Tích Yêu Cầu
#
#               skill_offer2              skill_offer3        skill_offer4  \
# 3161  Large Language Model             Deep Learning  Tensorflow/pytorch
# 3652                 Vuejs  Chủ Động Trong Công Việc
# 4164         User Research
# 4146    Tiếng Nhật N2 - N1                       Api
# 3427   Phát Triển Ứng Dụng         Kiểm Thử Phần Mềm    Lập Trình Vb.net
#
#          Location   position       work_type   min_salary   max_salary  \
# 3161       Hà Nội  Nhân viên  Toàn thời gian   76455000.0  127425000.0
# 3652       Hà Nội  Nhân viên  Toàn thời gian  185000000.0   25000000.0
# 4164       Hà Nội  Nhân viên  Toàn thời gian  115000000.0  185000000.0
# 4146       Hà Nội  Nhân viên  Toàn thời gian  150000000.0  200000000.0
# 3427  Hồ Chí Minh  Nhân viên  Toàn thời gian  184000000.0  276000000.0
#
#       average_salary  experience
# 3161     101940000.0           3
# 3652     105000000.0           2
# 4164     150000000.0           2
# 4146     175000000.0           2
# 3427     230000000.0           1

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 4314 to 3427
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   jobname         2175 non-null   object
#  1   companyscale    2175 non-null   object
#  2   company_field   2175 non-null   object
#  3   company_name    2175 non-null   object
#  4   skill_offer1    2175 non-null   object
#  5   skill_offer2    2175 non-null   object
#  6   skill_offer3    2175 non-null   object
#  7   skill_offer4    2175 non-null   object
#  8   Location        2175 non-null   object
#  9   position        2175 non-null   object
#  10  work_type       2175 non-null   object
#  11  min_salary      2175 non-null   float64
#  12  max_salary      2175 non-null   float64
#  13  average_salary  2175 non-null   float64
#  14  experience      2175 non-null   int64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 271.9+ KB
# None
#          min_salary    max_salary  average_salary   experience
# count  2.175000e+03  2.175000e+03    2.175000e+03  2175.000000
# mean   1.525411e+07  2.489854e+07    2.007633e+07     1.749885
# std    1.214687e+07  1.748422e+07    1.369964e+07     1.217009
# min    0.000000e+00  0.000000e+00    0.000000e+00     0.000000
# 25%    9.000000e+06  1.500000e+07    1.200000e+07     1.000000
# 50%    1.200000e+07  2.000000e+07    1.750000e+07     2.000000
# 75%    1.800000e+07  3.000000e+07    2.500000e+07     2.000000
# max    1.850000e+08  2.760000e+08    2.300000e+08     5.000000
# jobname           0
# companyscale      0
# company_field     0
# company_name      0
# skill_offer1      0
# skill_offer2      0
# skill_offer3      0
# skill_offer4      0
# Location          0
# position          0
# work_type         0
# min_salary        0
# max_salary        0
# average_salary    0
# experience        0
# dtype: int64

# %% [markdown]
# # PREPROCESS - TRANSLATE TO ENGLISH

# %%
# %pip install googletrans==4.0.0-rc1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.7.4)
# Requirement already satisfied: hstspreload in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.9.1)
# Requirement already satisfied: sniffio in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\vthuy\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from googletrans import Translator
from tqdm import tqdm

# Các cột cần dịch
columns_to_translate = [
    "jobname",
    "company_field",
    "company_name",
    "skill_offer1",
    "skill_offer2",
    "skill_offer3",
    "skill_offer4",
    "position",
    "work_type"
]

# Khởi tạo đối tượng Translator
translator = Translator()

# Hàm dịch nội dung

def translate_text(text):
    try:
        if pd.notnull(text):  # Kiểm tra nếu ô không rỗng
            translation = translator.translate(text, src='auto', dest='en')
            return translation.text if translation and translation.text else text
        return text
    except Exception as e:
        print(text)
        return text

# Chỉ lấy 5 hàng đầu tiên để thử nghiệm
data_sample = df.head(5).copy()

# Dịch từng cột với tqdm để hiển thị tiến độ
for column in columns_to_translate:
    if column in data_sample.columns:
        print(f"Đang dịch cột: {column}")
        data_sample[column] = [translate_text(text) for text in tqdm(data_sample[column], desc=f"Dịch {column}")]

# Kiểm tra kết quả
print(data_sample)
# Out:
# Đang dịch cột: jobname
# Dịch jobname: 100%|██████████| 5/5 [00:06<00:00,  1.25s/it]
# Đang dịch cột: company_field
# Dịch company_field: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Đang dịch cột: company_name
# Dịch company_name: 100%|██████████| 5/5 [00:03<00:00,  1.47it/s]
# Đang dịch cột: skill_offer1
# Dịch skill_offer1:  40%|████      | 2/5 [00:01<00:01,  1.85it/s]
# Dịch skill_offer1:  60%|██████    | 3/5 [00:01<00:01,  1.87it/s]
# Dịch skill_offer1: 100%|██████████| 5/5 [00:02<00:00,  2.04it/s]
# Đang dịch cột: skill_offer2
# Dịch skill_offer2:  40%|████      | 2/5 [00:02<00:03,  1.21s/it]
# Dịch skill_offer2:  60%|██████    | 3/5 [00:03<00:02,  1.17s/it]
# Dịch skill_offer2: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Đang dịch cột: skill_offer3
# Dịch skill_offer3:  40%|████      | 2/5 [00:01<00:01,  1.76it/s]
# Dịch skill_offer3:  60%|██████    | 3/5 [00:01<00:01,  1.69it/s]
# Dịch skill_offer3: 100%|██████████| 5/5 [00:03<00:00,  1.61it/s]
# Đang dịch cột: skill_offer4
# Dịch skill_offer4:  60%|██████    | 3/5 [00:02<00:01,  1.55it/s]
# Dịch skill_offer4: 100%|██████████| 5/5 [00:03<00:00,  1.63it/s]
# Đang dịch cột: position
# Dịch position: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Đang dịch cột: work_type
# Dịch work_type: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
#                                     jobname companyscale  company_field  \
# 4314                      Software business        25-99        Finance
# 319                     Fullstack Developer     500-1000  IT - Software
# 332                          Game Developer        25-99  IT - Software
# 1233          Product Owner/Product Manager        25-99  IT - Software
# 3775  Software Tester (Automation & Manual)        25-99  IT - Software
#
#                                    company_name        skill_offer1  \
# 4314                Paytech Joint Stock Company             Present
# 319   CMC Technology & Solution Company Limited
# 332                              Gamify Studios
# 1233                             Gamify Studios               Agile
# 3775         Live Group Vietnam Company Limited  Project management
#
#                 skill_offer2      skill_offer3           skill_offer4  \
# 4314  Building relationships         Negotiate     Project management
# 319
# 332
# 1233                   Scrum  Product Strategy        Product Roadmap
# 3775        Software testing   Test check plan  Test case test design
#
#          Location                  position  work_type  min_salary  \
# 4314       Hà Nội          Head/Deputy Head  Full time         0.0
# 319        Hà Nội                     Staff  Full time         0.0
# 332   Hồ Chí Minh                     Staff  Full time         0.0
# 1233  Hồ Chí Minh                     Staff  Full time         0.0
# 3775  Hồ Chí Minh  Management / supervision  Full time         0.0
#
#       max_salary  average_salary  experience
# 4314         0.0             0.0           4
# 319          0.0             0.0           4
# 332          0.0             0.0           4
# 1233         0.0             0.0           1
# 3775         0.0             0.0           4

# %% [markdown]
# ## Translate Jobname

# %%
# Delete all in ( ) in jobname
df['jobname'] = df['jobname'].apply(lambda x: re.sub(r'\(.*\)', '', x).strip())

# %%
# save jobname to temp array
jobname_array = df['jobname'].unique()
jobname_array
# Out:
# array(['Kinh doanh phần mềm', 'Fullstack Developer', 'Game Developer',
#        'Product Owner/Product Manager', 'Software Tester', 'UI/UX Design',
#        'System Architect', 'Business Analyst', 'Công nghệ thông tin khác',
#        'Data Analyst', 'Thiết kế đồ họa', 'Mobile Developer',
#        'Frontend Developer', 'Bán hàng kỹ thuật IT', 'IT Consultant',
#        'Game Tester', 'Backend Developer', 'AI Engineer',
#        'Software Engineer', 'Automation Tester', 'Kỹ sư cầu nối BrSE',
#        'Sales IT Phần mềm khác', 'Database Administrator',
#        'Brand Marketing', 'DevOps Engineer',
#        'Kinh doanh Domain/Hosting/Server', 'System Engineer',
#        'Manual Tester', 'Data Scientist', 'Illustration', 'Game Design',
#        'Concept Artist', 'Embedded Engineer/Lập trình nhúng', 'Kỹ sư IoT',
#        'IT Helpdesk/IT support', 'Data Labeling', 'Kỹ thuật IT',
#        'Data Engineer', 'Cloud Engineer', 'Vị trí Game Development khác',
#        'Animation Design', 'Quản trị và vận hành bảo mật',
#        'System Administrator', 'QA Engineer', 'Giáo viên bộ môn khác',
#        'Giáo viên Tin học', 'Network Engineer',
#        'Process Quality Assurance', 'IT Project Manager',
#        'Sửa chữa/Bảo trì điện tử/viễn thông', 'Content Creator',
#        'Chuyên viên IT Security', 'Trợ lý/Thư ký', 'Chuyên viên pháp chế',
#        'Chuyên viên Cyber Security', 'Kiểm thử và đánh giá bảo mật',
#        'Software Architect', 'AR/VR Developer', 'Scrum Master',
#        'Quản lý Kinh doanh khác', 'Sales Điện/Điện tử/Viễn thông khác',
#        'AI Researcher', 'Phòng chống lừa đảo và an ninh mạng',
#        'Blockchain Engineer', 'BIM Engineer', 'Marketing', 'Tuyển dụng',
#        'Solution Architect', 'Bảo mật ứng dụng và phát triển',
#        'Chiến lược và phân tích bảo mật', 'Technical Leader',
#        'Technical Manager', 'Chief Technology Officer'], dtype=object)

# %%
# translate jobname_array
jobname_array = [translate_text(text) for text in tqdm(jobname_array, desc="Dịch jobname")]
# Out:
# Dịch jobname: 100%|██████████| 73/73 [00:48<00:00,  1.51it/s]

# %%
# create dictionary to save jobname_array
jobname_dict = dict(zip(df['jobname'].unique(), jobname_array))
# replace jobname by jobname_dict
df['jobname'] = df['jobname'].replace(jobname_dict)

# %%
# print unique jobname
print(df['jobname'].unique())
# Out:
# ['Software business' 'Fullstack Developer' 'Game Developer'
#  'Product Owner/Product Manager' 'Software tester' 'UI/UX Design'
#  'System Architect' 'Business Analyst' 'Other information technology'
#  'Data Analyst' 'Graphic design' 'Mobile Developer' 'Frontend Developer'
#  'IT technical sales' 'IT Consultant' 'Game Tester' 'Backend Developer'
#  'AI Engineer' 'Software Engineer' 'Automation Tester'
#  'Bridge Bridge Bridge Bridge' 'Sales IT other software'
#  'Database Administrator' 'Brand Marketing' 'DevOps Engineer'
#  'Domain/hosting/server business' 'System Engineer' 'Manual Tester'
#  'Data Scientist' 'Illustration' 'Game Design' 'Concept Artist'
#  'Embedded Engineer/Dip programming' 'IoT engineer'
#  'IT Helpdesk/IT support' 'Data Labeling' 'IT technique' 'Data Engineer'
#  'Cloud Engineer' 'Other Development game position' 'Animation Design'
#  'Management and operation of confidentiality' 'System Administrator'
#  'QA Engineer' 'Other subject teachers' 'Computer teacher'
#  'Network Engineer' 'Process Quality Assurance' 'IT Project Manager'
#  'Electronic/Telecommunications Repair/Telecommunication'
#  'Content Creator' 'IT Security Specialist' 'Assistant/Secretary'
#  'Legal specialist' 'Cyber \u200b\u200bSecurity Specialist'
#  'Test and security assessment' 'Software Architect' 'AR/VR Developer'
#  'Scrum Master' 'Other business management'
#  'Electrical/Electronic/Telecommunications Sales' 'AI Researcher'
#  'Prevention of fraud and network security' 'Blockchain Engineer'
#  'BIM Engineer' 'Marketing' 'Recruitment' 'Solution Architect'
#  'Application security and development' 'Strategy and security analysis'
#  'Technical Leader' 'Technical Manager' 'Chief Technology Officer']

# %% [markdown]
# ## Translate company_field

# %%
# save company_field to temp array
company_field_array = df['company_field'].unique()
company_field_array
# Out:
# array(['Tài Chính', 'It - Phần Mềm', 'Viễn Thông', 'Ngân Hàng',
#        'Bán Lẻ - Hàng Tiêu Dùng - Fmcg', 'Bất Động Sản',
#        'Internet / Online', 'Khác', 'Tư Vấn', 'Xuất Nhập Khẩu',
#        'Xây Dựng', 'Điện Tử / Điện Lạnh',
#        'Marketing / Truyền Thông / Quảng Cáo', 'Du Lịch',
#        'Giáo Dục / Đào Tạo', 'Thương Mại Điện Tử',
#        'Dược Phẩm / Y Tế / Công Nghệ Sinh Học',
#        'Agency (marketing/advertising)', 'Tự Động Hóa', 'Sản Xuất',
#        'Giải Trí', 'Nhân Sự', 'Nhà Hàng / Khách Sạn', 'In Ấn / Xuất Bản',
#        'It - Phần Cứng', 'Logistics - Vận Tải', 'Thời Trang',
#        'Chứng Khoán', 'Thiết Kế / Kiến Trúc', 'Kế Toán / Kiểm Toán',
#        'Nông Lâm Ngư Nghiệp', 'Bảo Trì / Sửa Chữa', 'Bảo Hiểm', 'Cơ Khí',
#        'Năng Lượng'], dtype=object)

# %%
# translate company_field_array
company_field_array = [translate_text(text) for text in tqdm(company_field_array, desc="Dịch company_field")]

# create dictionary to save company_field_array
company_field_dict = dict(zip(df['company_field'].unique(), company_field_array))
# replace company_field by company_field_dict
df['company_field'] = df['company_field'].replace(company_field_dict)
# Out:
# Dịch company_field: 100%|██████████| 35/35 [00:27<00:00,  1.27it/s]

# %%
df['company_field'].unique()
# Out:
# array(['Finance', 'IT - Software', 'Telecommunications', 'Bank',
#        'Retail - Consumer goods - FMCG', 'Real estate',
#        'Internet / Online', 'Other', 'Advise', 'Import and export',
#        'Build', 'Electronics / Refrigeration',
#        'Marketing / Communications / Advertising', 'Tourism',
#        'Education / Training', 'E -commerce',
#        'Pharmaceutical / Health / Biotechnology',
#        'Agency (marketing/advertising)', 'Automation', 'Manufacture',
#        'Entertainment', 'Personnel', 'Restaurant / hotel',
#        'Print / publish', 'IT - Hardware', 'Logistics - Transport',
#        'Fashion', 'Stock', 'Design / Architecture',
#        'Accounting / Auditing', 'Agriculture and forestry',
#        'Maintenance / Repair', 'Insurance', 'Mechanical', 'Energy'],
#       dtype=object)

# %% [markdown]
# ## Translate position

# %%
# save position to temp array
position_array = df['position'].unique()
position_array
# Out:
# array(['Trưởng/Phó phòng', 'Nhân viên', 'Quản lý / Giám sát',
#        'Thực tập sinh', 'Trưởng nhóm', 'Trưởng chi nhánh', 'Giám đốc',
#        'Phó giám đốc'], dtype=object)

# %%
#translate position_array
position_array = [translate_text(text) for text in tqdm(position_array, desc="Dịch position")]

# create dictionary to save position_array
position_dict = dict(zip(df['position'].unique(), position_array))
# replace position by position_dict
df['position'] = df['position'].replace(position_dict)
# Out:
# Dịch position: 100%|██████████| 8/8 [00:05<00:00,  1.36it/s]

# %%
df.head(10)
# Out:
#                             jobname companyscale       company_field  \
# 4314              Software business        25-99             Finance
# 319             Fullstack Developer     500-1000       IT - Software
# 332                  Game Developer        25-99       IT - Software
# 1233  Product Owner/Product Manager        25-99       IT - Software
# 3775                Software tester        25-99       IT - Software
# 4270                   UI/UX Design        25-99       IT - Software
# 3808               System Architect  5000 - 9999  Telecommunications
# 2867               Business Analyst        25-99       IT - Software
# 3643            Fullstack Developer      100-499       IT - Software
# 884    Other information technology  5000 - 9999                Bank
#
#                                            company_name  \
# 4314                            Công Ty Cổ Phần Paytech
# 319   Công Ty Tnhh Tổng Công Ty Công Nghệ & Giải Phá...
# 332                                      Gamify Studios
# 1233                                     Gamify Studios
# 3775                   Công Ty Tnhh Live Group Việt Nam
# 4270                                     Gamify Studios
# 3808                     Công Ty Cổ Phần Viễn Thông Fpt
# 2867                   Công Ty Tnhh Công Nghệ Blue Belt
# 3643                                 Opencommerce Group
# 884                  Ngân Hàng Tmcp An Bình Pro Company
#
#                             skill_offer1  \
# 4314                        Thuyết Trình
# 319
# 332
# 1233                               Agile
# 3775                       Quản Lý Dự Án
# 4270  Thiết Kế Giao Diện Người Dùng (ui)
# 3808                       Quản Lý Dự Án
# 2867                    Kỹ Năng Lãnh Đạo
# 3643                              Python
# 884
#
#                               skill_offer2               skill_offer3  \
# 4314                  Xây Dựng Mối Quan Hệ                   Đàm Phán
# 319
# 332
# 1233                                 Scrum           Product Strategy
# 3775                     Kiểm Thử Phần Mềm      Lập Kế Hoạch Kiểm Thử
# 4270  Thiết Kế Trải Nghiệm Người Dùng (ux)      Nghiên Cứu Người Dùng
# 3808                     Thiết Kế Hệ Thống  Lập Trình Hướng Đối Tượng
# 2867                         Quản Lý Dự Án        Phân Tích Nghiệp Vụ
# 3643                                 Vuejs        Product Development
# 884
#
#                                            skill_offer4     Location  \
# 4314                                      Quản Lý Dự Án       Hà Nội
# 319                                                           Hà Nội
# 332                                                      Hồ Chí Minh
# 1233                                    Product Roadmap  Hồ Chí Minh
# 3775                                 Thiết Kế Test Case  Hồ Chí Minh
# 4270  Sử Dụng Phần Mềm Thiết Kế (figma, Adobe Xd, Sk...  Hồ Chí Minh
# 3808                                Phát Triển Phần Mềm  Hồ Chí Minh
# 2867                                 Giao Tiếp Hiệu Quả       Hà Nội
# 3643                                          Sql/nosql       Hà Nội
# 884                                                           Hà Nội
#
#                       position       work_type  min_salary  max_salary  \
# 4314          Head/Deputy Head  Toàn thời gian         0.0         0.0
# 319                      Staff  Toàn thời gian         0.0         0.0
# 332                      Staff  Toàn thời gian         0.0         0.0
# 1233                     Staff  Toàn thời gian         0.0         0.0
# 3775  Management / supervision  Toàn thời gian         0.0         0.0
# 4270                     Staff  Toàn thời gian         0.0         0.0
# 3808                     Staff  Toàn thời gian         0.0         0.0
# 2867          Head/Deputy Head  Toàn thời gian         0.0         0.0
# 3643                     Staff  Toàn thời gian         0.0         0.0
# 884                      Staff  Toàn thời gian         0.0         0.0
#
#       average_salary  experience
# 4314             0.0           4
# 319              0.0           4
# 332              0.0           4
# 1233             0.0           1
# 3775             0.0           4
# 4270             0.0           3
# 3808             0.0           5
# 2867             0.0           5
# 3643             0.0           4
# 884              0.0           3

# %% [markdown]
# ## Translate work_type

# %%
# save work_type to temp array
work_type_array = df['work_type'].unique()
work_type_array
# Out:
# array(['Toàn thời gian', 'Thực tập', 'Bán thời gian'], dtype=object)

# %%
#translate work_type_array
work_type_array = [translate_text(text) for text in tqdm(work_type_array, desc="Dịch work_type")]

# create dictionary to save work_type_array
work_type_dict = dict(zip(df['work_type'].unique(), work_type_array))
# replace work_type by work_type_dict
df['work_type'] = df['work_type'].replace(work_type_dict)
# Out:
# Dịch work_type: 100%|██████████| 3/3 [00:02<00:00,  1.21it/s]

# %% [markdown]
# ## Skill offer

# %%
import json

# Đọc file JSON mới được tải lên
json_path = 'final_skill_groups.json'
with open(json_path, 'r', encoding='utf-8') as f:
    skill_groups = json.load(f)

# Tạo cột mới trong DataFrame để chứa nhóm kỹ năng
def classify_skill(skill):
    if pd.isna(skill) or skill == '':
        return ''
    for group, skills in skill_groups.items():
        if skill in skills:
            return group
    return 'Other'

# Áp dụng phân loại cho từng cột kỹ năng
for col in df.columns:
    df[f'{col}_group'] = df[col].apply(lambda x: classify_skill(x))

# Loại bỏ giá trị trùng lặp trong cùng một hàng
group_cols = [col for col in df.columns if '_group' in col]

# Xử lý từng hàng để loại bỏ giá trị trùng lặp
for index, row in df.iterrows():
    seen = set()
    for col in group_cols:
        if row[col] in seen:
            df.at[index, col] = ''  # Xóa giá trị trùng lặp
        else:
            seen.add(row[col])
 
# Xuất file CSV sau khi ghép nhóm kỹ năng
output_csv_path = 'cleanded_database.csv'
df.to_csv(output_csv_path, index=False)

output_csv_path
# Out:
# 'cleanded_database.csv'
